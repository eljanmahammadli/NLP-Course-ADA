# %%
import re
from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split
import numpy as np
import math

# %%
# Example Azerbaijani text
with open("/Users/eljan/Documents/NLP/NLP-Course-ADA/output/AKE.txt", 'r') as file:
    text = file.read()
text = text.lower()
# Function to clean and preprocess text
def preprocess_text(text):
    # Add end of sentence token
    text = text.replace(".", " <EOS>")
    # Tokenize and remove non-letter tokens
    tokens = [token for token in word_tokenize(text) if re.match("^[A-Za-zƏəĞğIıÖöŞşÜüÇç]+$", token)]
    return tokens

tokens = preprocess_text(text)

# Splitting data into training and test sets
train_tokens, test_tokens = train_test_split(tokens, test_size=0.2, random_state=42)

# %%
len(set(tokens))
# Out:
# 23749

# %%
from collections import Counter

def build_ngrams(tokens, n):
    ngrams = [tuple(tokens[i:i+n]) for i in range(len(tokens)-n+1)]
    return ngrams

unigrams = build_ngrams(train_tokens, 1)
bigrams = build_ngrams(train_tokens, 2)
trigrams = build_ngrams(train_tokens, 3)

# Count occurrences
unigram_counts = Counter(unigrams)
bigram_counts = Counter(bigrams)
trigram_counts = Counter(trigrams)

# %%
a = dict(trigram_counts)
sorted_a = dict(sorted(a.items(), key=lambda item: item[1], reverse=True))
sorted_a
# Out:
# {('EOS', 'EOS', 'EOS'): 102,
#  ('EOS', 'EOS', 'və'): 51,
#  ('və', 'EOS', 'EOS'): 42,
#  ('EOS', 'və', 'EOS'): 41,
#  ('EOS', 'və', 'və'): 21,
#  ('və', 'və', 'EOS'): 19,
#  ('EOS', 'ildə', 'EOS'): 15,
#  ('EOS', 'k', 'EOS'): 14,
#  ('EOS', 'EOS', 'k'): 12,
#  ('və', 'EOS', 'və'): 12,
#  ('EOS', 'və', 'ilə'): 11,
#  ('EOS', 'EOS', 'ilə'): 11,
#  ('EOS', 'bu', 'EOS'): 11,
#  ('və', 'və', 'və'): 11,
#  ('k', 'EOS', 'EOS'): 11,
#  ('EOS', 'informasiya', 'EOS'): 10,
#  ('EOS', 'EOS', 'n'): 10,
#  ('EOS', 'EOS', 'bu'): 10,
#  ('ildə', 'EOS', 'EOS'): 9,
#  ('EOS', 'EOS', 'bir'): 9,
#  ('EOS', 'EOS', 'nin'): 8,
#  ('ilə', 'EOS', 'EOS'): 8,
#  ('EOS', 'EOS', 'üçün'): 8,
#  ('mədəniyyət', 'EOS', 'EOS'): 8,
#  ('EOS', 'EOS', 'ist'): 8,
#  ('EOS', 'EOS', 'haqqında'): 8,
#  ('elmi', 'EOS', 'və'): 8,
#  ('EOS', 'ilə', 'EOS'): 8,
#  ('EOS', 'üçün', 'EOS'): 7,
#  ('və', 'EOS', 'azərbaycan'): 7,
#  ('ya', 'EOS', 'EOS'): 7,
#  ('EOS', 'ildən', 'EOS'): 7,
#  ('EOS', 'və', 'kitabxana'): 7,
#  ('EOS', 'EOS', 't'): 7,
#  ('edir', 'EOS', 'EOS'): 7,
#  ('EOS', 'EOS', 'ildə'): 7,
#  ('EOS', 'EOS', 'elmi'): 7,
#  ('EOS', 'kitabxana', 'EOS'): 7,
#  ('EOS', 'EOS', 'il'): 7,
#  ('EOS', 'EOS', 'ki'): 7,
#  ('EOS', 'EOS', 'informasiya'): 6,
#  ('və', 'haqqında', 'EOS'): 6,
#  ('EOS', 'kitab', 'EOS'): 6,
#  ('EOS', 'EOS', 'kitabxana'): 6,
#  ('EOS', 'və', 'üzrə'): 6,
#  ('kitabxana', 'EOS', 'və'): 6,
#  ('EOS', 'ist', 'EOS'): 6,
#  ('nin', 'EOS', 'EOS'): 6,
#  ('EOS', 'və', 'n'): 6,
#  ('EOS', 'EOS', 'kitab'): 6,
#  ('bir', 'EOS', 'EOS'): 6,
#  ('ilə', 'və', 'EOS'): 6,
#  ('haqqında', 'EOS', 'EOS'): 6,
#  ('bu', 'EOS', 'EOS'): 6,
#  ('EOS', 'milli', 'EOS'): 6,
#  ('EOS', 'ya', 'EOS'): 6,
#  ('də', 'və', 'EOS'): 5,
#  ('ildə', 'EOS', 'və'): 5,
#  ('EOS', 'ndən', 'EOS'): 5,
#  ('və', 'ildən', 'EOS'): 5,
#  ('EOS', 'EOS', 'kimi'): 5,
#  ('t', 'EOS', 'EOS'): 5,
#  ('bu', 'və', 'EOS'): 5,
#  ('EOS', 'olduğu', 'EOS'): 5,
#  ('və', 'EOS', 'k'): 5,
#  ('ildə', 'və', 'EOS'): 5,
#  ('EOS', 'b', 'EOS'): 5,
#  ('EOS', 'k', 'və'): 5,
#  ('EOS', 'EOS', 'azərbaycan'): 5,
#  ('EOS', 'EOS', 'da'): 5,
#  ('olan', 'EOS', 'EOS'): 5,
#  ('k', 'EOS', 'və'): 5,
#  ('EOS', 'təşkil', 'EOS'): 5,
#  ('EOS', 'dövlət', 'EOS'): 5,
#  ('informasiya', 'EOS', 'EOS'): 5,
#  ('onun', 'EOS', 'EOS'): 5,
#  ('EOS', 'kitab', 'və'): 5,
#  ('EOS', 'EOS', 'fəaliyyət'): 5,
#  ('EOS', 'EOS', 'milli'): 5,
#  ('və', 'EOS', 'fadə'): 5,
#  ('bu', 'EOS', 'və'): 5,
#  ('ən', 'və', 'EOS'): 5,
#  ('da', 'EOS', 'EOS'): 5,
#  ('EOS', 'EOS', 'ya'): 5,
#  ('kitab', 'EOS', 'EOS'): 5,
#  ('də', 'EOS', 'EOS'): 5,
#  ('EOS', 'bir', 'və'): 5,
#  ('b', 'EOS', 'EOS'): 4,
#  ('fəaliyyət', 'EOS', 'və'): 4,
#  ('və', 'ilə', 'EOS'): 4,
#  ('digər', 'və', 'EOS'): 4,
#  ('EOS', 'olan', 'və'): 4,
#  ('kitabxana', 'və', 'EOS'): 4,
#  ('EOS', 'ist', 'və'): 4,
#  ('EOS', 'EOS', 'uzun'): 4,
#  ('dövlət', 'EOS', 'EOS'): 4,
#  ('və', 'və', 'ist'): 4,
#  ('EOS', 'EOS', 'dövlət'): 4,
#  ('milli', 'və', 'EOS'): 4,
#  ('k', 'EOS', 'ildən'): 4,
#  ('EOS', 'böyük', 'EOS'): 4,
#  ('f', 'EOS', 'EOS'): 4,
#  ('EOS', 'EOS', 'nəşr'): 4,
#  ('və', 'EOS', 'üçün'): 4,
#  ('və', 'görə', 'EOS'): 4,
#  ('ist', 'və', 'EOS'): 4,
#  ('EOS', 'və', 'illərdə'): 4,
#  ('EOS', 'həmin', 'EOS'): 4,
#  ('EOS', 'EOS', 'görə'): 4,
#  ('EOS', 'EOS', 'həmin'): 4,
#  ('k', 'və', 'EOS'): 4,
#  ('EOS', 'kitab', 'k'): 4,
#  ('EOS', 'EOS', 's'): 4,
#  ('informasiya', 'və', 'EOS'): 4,
#  ('və', 'və', 'bu'): 4,
#  ('EOS', 'bir', 'EOS'): 4,
#  ('EOS', 'və', 'dövlət'): 4,
#  ('EOS', 'ya', 'və'): 4,
#  ('və', 't', 'EOS'): 4,
#  ('EOS', 'da', 'EOS'): 4,
#  ('n', 'EOS', 'EOS'): 4,
#  ('EOS', 'mədəniyyət', 'və'): 4,
#  ('və', 'EOS', 'kitab'): 4,
#  ('EOS', 'azərbaycan', 'EOS'): 4,
#  ('EOS', 'EOS', 'üzrə'): 4,
#  ('EOS', 'və', 'ildə'): 4,
#  ('EOS', 'kitabxana', 'və'): 4,
#  ('kitabxana', 'və', 'və'): 4,
#  ('kitabxana', 'EOS', 'EOS'): 4,
#  ('olan', 'EOS', 'və'): 4,
#  ('daxil', 'EOS', 'EOS'): 4,
#  ('EOS', 'EOS', 'də'): 4,
#  ('EOS', 'edilmişdir', 'EOS'): 4,
#  ('yeni', 'EOS', 'EOS'): 4,
#  ('belə', 'EOS', 'və'): 4,
#  ('inkişaf', 'EOS', 'EOS'): 4,
#  ('kitabxanası', 'və', 'EOS'): 4,
#  ('azərbaycan', 'EOS', 'EOS'): 4,
#  ('EOS', 'və', 'ndə'): 4,
#  ('EOS', 'EOS', 'çox'): 4,
#  ('EOS', 'və', 'bu'): 4,
#  ('EOS', 'də', 'EOS'): 4,
#  ('EOS', 'EOS', 'əsasında'): 4,
#  ('və', 'bu', 'EOS'): 4,
#  ('ildə', 'EOS', 'bu'): 4,
#  ('və', 'kitabxana', 'EOS'): 4,
#  ('EOS', 'et', 'EOS'): 4,
#  ('bir', 'və', 'EOS'): 4,
#  ('q', 'EOS', 'EOS'): 4,
#  ('milli', 'EOS', 'EOS'): 4,
#  ('və', 'EOS', 'bir'): 3,
#  ('EOS', 'ni', 'EOS'): 3,
#  ('EOS', 'və', 'üçün'): 3,
#  ('və', 'və', 'bilər'): 3,
#  ('EOS', 'malik', 'EOS'): 3,
#  ('ilk', 'EOS', 'EOS'): 3,
#  ('EOS', 'digər', 'EOS'): 3,
#  ('k', 'k', 'EOS'): 3,
#  ('ən', 'EOS', 'və'): 3,
#  ('EOS', 'EOS', 'o'): 3,
#  ('və', 'EOS', 'ist'): 3,
#  ('EOS', 'eht', 'EOS'): 3,
#  ('EOS', 'kimi', 'EOS'): 3,
#  ('yerinə', 'EOS', 'EOS'): 3,
#  ('EOS', 'EOS', 'ndən'): 3,
#  ('və', 'EOS', 'olmuşdur'): 3,
#  ('milli', 'EOS', 'və'): 3,
#  ('EOS', 'olan', 'EOS'): 3,
#  ('EOS', 'edilməsi', 'və'): 3,
#  ('üzrə', 'EOS', 'və'): 3,
#  ('və', 'EOS', 'vəsait'): 3,
#  ('kimi', 'EOS', 'ist'): 3,
#  ('EOS', 'fadə', 'EOS'): 3,
#  ('EOS', 'EOS', 'məqsədi'): 3,
#  ('EOS', 'əsasında', 'EOS'): 3,
#  ('təşkili', 'EOS', 'EOS'): 3,
#  ('EOS', 't', 'EOS'): 3,
#  ('böyük', 'EOS', 'və'): 3,
#  ('görə', 'EOS', 'EOS'): 3,
#  ('təhsil', 'EOS', 'EOS'): 3,
#  ('kimi', 'EOS', 'EOS'): 3,
#  ('və', 'EOS', 'ki'): 3,
#  ('EOS', 'edilməsi', 'EOS'): 3,
#  ('və', 'olmuşdur', 'EOS'): 3,
#  ('EOS', 'və', 'sahəsində'): 3,
#  ('ədəbiyyatla', 'EOS', 'EOS'): 3,
#  ('və', 'illərdə', 'və'): 3,
#  ('EOS', 'EOS', 'müxtəlif'): 3,
#  ('və', 'EOS', 'dövri'): 3,
#  ('EOS', 'müəyyən', 'EOS'): 3,
#  ('EOS', 'EOS', 'yeni'): 3,
#  ('və', 'kitabxanası', 'EOS'): 3,
#  ('və', 'EOS', 'öz'): 3,
#  ('EOS', 'EOS', 'b'): 3,
#  ('n', 'və', 'EOS'): 3,
#  ('EOS', 'texniki', 'EOS'): 3,
#  ('həm', 'EOS', 'EOS'): 3,
#  ('edilir', 'EOS', 'EOS'): 3,
#  ('həmin', 'EOS', 'EOS'): 3,
#  ('EOS', 'EOS', 'mədəniyyət'): 3,
#  ('vəsait', 'EOS', 'EOS'): 3,
#  ('mühüm', 'EOS', 'EOS'): 3,
#  ('EOS', 'tərt', 'EOS'): 3,
#  ('EOS', 'EOS', 'kitabların'): 3,
#  ('kimi', 'EOS', 'və'): 3,
#  ('və', 'EOS', 'ümumi'): 3,
#  ('EOS', 'edilmiş', 'və'): 3,
#  ('EOS', 'EOS', 'iş'): 3,
#  ('EOS', 'və', 'burada'): 3,
#  ('EOS', 'ən', 'EOS'): 3,
#  ('və', 'daxil', 'EOS'): 3,
#  ('EOS', 'EOS', 'şəkildə'): 3,
#  ('işlər', 'EOS', 'EOS'): 3,
#  ('EOS', 'm', 'və'): 3,
#  ('EOS', 'EOS', 'üzərində'): 3,
#  ('və', 'k', 'EOS'): 3,
#  ('EOS', 'EOS', 'yanaşı'): 3,
#  ('EOS', 'nin', 'EOS'): 3,
#  ('və', 'EOS', 'etdirən'): 3,
#  ('üçün', 'EOS', 'EOS'): 3,
#  ('kitablar', 'EOS', 'EOS'): 3,
#  ('və', 'digər', 'EOS'): 3,
#  ('adlanır', 'EOS', 'EOS'): 3,
#  ('EOS', 'hissəsi', 'EOS'): 3,
#  ('və', 'üzrə', 'EOS'): 3,
#  ('EOS', 'məlumat', 'EOS'): 3,
#  ('EOS', 'il', 'EOS'): 3,
#  ('digər', 'EOS', 'EOS'): 3,
#  ('n', 'k', 'EOS'): 3,
#  ('edilmişdir', 'EOS', 'EOS'): 3,
#  ('EOS', 'üzrə', 'EOS'): 3,
#  ('növü', 'EOS', 'EOS'): 3,
#  ('bir', 'EOS', 'və'): 3,
#  ('EOS', 'və', 'k'): 3,
#  ('və', 'ildə', 'EOS'): 3,
#  ('ildən', 'EOS', 'EOS'): 3,
#  ('EOS', 'EOS', 'digər'): 3,
#  ('EOS', 'və', 'haqqında'): 3,
#  ('sonra', 'EOS', 'EOS'): 3,
#  ('və', 'və', 'respublika'): 3,
#  ('EOS', 'bütün', 'EOS'): 3,
#  ('və', 'fəaliyyət', 'EOS'): 3,
#  ('EOS', 'ilə', 'və'): 3,
#  ('elmi', 'EOS', 'EOS'): 3,
#  ('EOS', 'əsas', 'və'): 3,
#  ('ilə', 'k', 'və'): 3,
#  ('edir', 'EOS', 'və'): 3,
#  ('EOS', 'mədəniyyət', 'EOS'): 3,
#  ('EOS', 'm', 'EOS'): 3,
#  ('kitabı', 'EOS', 'EOS'): 3,
#  ('EOS', 'EOS', 'olan'): 3,
#  ('həmin', 'EOS', 'və'): 3,
#  ('EOS', 'EOS', 'həmçinin'): 3,
#  ('isə', 'və', 'EOS'): 3,
#  ('EOS', 'EOS', 'cümlədən'): 3,
#  ('yanın', 'EOS', 'EOS'): 3,
#  ('k', 'ya', 'EOS'): 3,
#  ('üçün', 'EOS', 'informasiya'): 3,
#  ('EOS', 'EOS', 'təşkil'): 3,
#  ('və', 'EOS', 'edilir'): 3,
#  ('EOS', 'və', 'bütün'): 3,
#  ('ist', 'EOS', 'və'): 3,
#  ('il', 'EOS', 'EOS'): 3,
#  ('ya', 'və', 'EOS'): 3,
#  ('üzrə', 'və', 'və'): 3,
#  ('və', 'olan', 'EOS'): 3,
#  ('işt', 'EOS', 'EOS'): 3,
#  ('və', 'EOS', 'kimi'): 3,
#  ('ildə', 'k', 'EOS'): 3,
#  ('EOS', 'EOS', 'təhsil'): 3,
#  ('EOS', 'k', 'informasiya'): 3,
#  ('EOS', 'elmi', 'EOS'): 3,
#  ('yeni', 'ilə', 'EOS'): 3,
#  ('kitabxana', 'ilə', 'EOS'): 3,
#  ('respublika', 'EOS', 'EOS'): 3,
#  ('informasiya', 'k', 'EOS'): 3,
#  ('EOS', 'və', 'kitab'): 3,
#  ('həyata', 'EOS', 'EOS'): 3,
#  ('olunan', 'və', 'və'): 3,
#  ('EOS', 'EOS', 'beynəlxalq'): 3,
#  ('EOS', 'kitabxanaçı', 'və'): 3,
#  ('EOS', 'EOS', 'uşaq'): 3,
#  ('əsasında', 'EOS', 'EOS'): 3,
#  ('və', 'EOS', 'daha'): 3,
#  ('çap', 'və', 'EOS'): 3,
#  ('təmin', 'EOS', 'EOS'): 3,
#  ('fondu', 'EOS', 'EOS'): 3,
#  ('və', 'ndən', 'EOS'): 3,
#  ('EOS', 'sahəsində', 'EOS'): 3,
#  ('əks', 'EOS', 'EOS'): 3,
#  ('EOS', 'sonra', 'EOS'): 3,
#  ('EOS', 'n', 'EOS'): 3,
#  ('EOS', 'və', 'azərbaycan'): 3,
#  ('görə', 'EOS', 'və'): 3,
#  ('EOS', 'EOS', 'illərdə'): 3,
#  ('EOS', 'ali', 'EOS'): 3,
#  ('edilmiş', 'EOS', 'EOS'): 3,
#  ('EOS', 'kitabxananın', 'və'): 3,
#  ('və', 'EOS', 'nin'): 3,
#  ('və', 'və', 'mədəniyyət'): 3,
#  ('EOS', 'rayon', 'EOS'): 3,
#  ('EOS', 'EOS', 'v'): 3,
#  ('üçün', 'və', 'EOS'): 3,
#  ('və', 'EOS', 'elmi'): 3,
#  ('məlumatların', 'EOS', 'EOS'): 3,
#  ('EOS', 'EOS', 'xarici'): 3,
#  ('EOS', 'uzun', 'və'): 3,
#  ('EOS', 'EOS', 'öz'): 3,
#  ('xidmət', 'və', 'EOS'): 3,
#  ('və', 'azərbaycan', 'EOS'): 3,
#  ('azərbaycanı', 'EOS', 'EOS'): 3,
#  ('ya', 'EOS', 'və'): 3,
#  ('nəşr', 'EOS', 'EOS'): 3,
#  ('k', 'b', 'EOS'): 2,
#  ('və', 'haqqında', 'uşaq'): 2,
#  ('EOS', 'EOS', 'adı'): 2,
#  ('EOS', 'şəhər', 'edilən'): 2,
#  ('yet', 'EOS', 'EOS'): 2,
#  ('EOS', 'və', 'resursların'): 2,
#  ('EOS', 'ilk', 'EOS'): 2,
#  ('EOS', 'etməkdən', 'EOS'): 2,
#  ('və', 'yenidən', 'və'): 2,
#  ('EOS', 'və', 'təsdiq'): 2,
#  ('çap', 'EOS', 'haqqında'): 2,
#  ('indiki', 'ildə', 'və'): 2,
#  ('nin', 'informasiya', 'və'): 2,
#  ('ədəbiyyat', 'ndən', 'EOS'): 2,
#  ('informasiya', 'və', 'n'): 2,
#  ('k', 'yası', 'EOS'): 2,
#  ('k', 'EOS', 'olunmağa'): 2,
#  ('və', 'belə', 'EOS'): 2,
#  ('EOS', 'illərdə', 'EOS'): 2,
#  ('s', 'və', 'əsas'): 2,
#  ('burada', 'EOS', 'EOS'): 2,
#  ('EOS', 'kitabxana', 'n'): 2,
#  ('n', 'dövlət', 'EOS'): 2,
#  ('ildə', 'EOS', 'çap'): 2,
#  ('EOS', 'olduğu', 'və'): 2,
#  ('EOS', 'fondu', 'kitabxana'): 2,
#  ('də', 'EOS', 'və'): 2,
#  ('EOS', 'və', 'kütləvi'): 2,
#  ('ildən', 'və', 'EOS'): 2,
#  ('kimi', 'EOS', 'kitabxana'): 2,
#  ('ist', 'EOS', 'EOS'): 2,
#  ('EOS', 'daxildir', 'EOS'): 2,
#  ('k', 'EOS', 'kitabxana'): 2,
#  ('və', 'uyğun', 'n'): 2,
#  ('bir', 'EOS', 'sənədin'): 2,
#  ('adı', 'EOS', 'EOS'): 2,
#  ('EOS', 'il', 'şəhər'): 2,
#  ('EOS', 'əlyazma', 'və'): 2,
#  ('informasiya', 'və', 'ilə'): 2,
#  ('ilə', 'olan', 'EOS'): 2,
#  ('EOS', 'və', 'ya'): 2,
#  ('EOS', 't', 'avtomatlaşdırılmış'): 2,
#  ('də', 'EOS', 'n'): 2,
#  ('ildə', 'və', 'b'): 2,
#  ('təşkilat', 'EOS', 'EOS'): 2,
#  ('EOS', 'xv', 'EOS'): 2,
#  ('EOS', 'milli', 'başlayaraq'): 2,
#  ('EOS', 'EOS', 'yası'): 2,
#  ('kimi', 'EOS', 'nəşr'): 2,
#  ('gəlib', 'və', 'verilir'): 2,
#  ('kitabxana', 'təsviri', 'və'): 2,
#  ('m', 'EOS', 'bu'): 2,
#  ('bir', 's', 'EOS'): 2,
#  ('olmuşdur', 'üzrə', 'EOS'): 2,
#  ('kitabxananın', 's', 'EOS'): 2,
#  ('ilə', 'və', 'mədəniyyət'): 2,
#  ('EOS', 'ist', 'onların'): 2,
#  ('EOS', 'informasiya', 'və'): 2,
#  ('və', 'dilində', 'EOS'): 2,
#  ('dilində', 'EOS', 'və'): 2,
#  ('v', 'və', 'EOS'): 2,
#  ('elektron', 'və', 'fəaliyyət'): 2,
#  ('olunmuşdur', 'ilə', 'ilə'): 2,
#  ('ilə', 'və', 'kitab'): 2,
#  ('əsasən', 'və', 'kitabxana'): 2,
#  ('EOS', 'dövlət', 'min'): 2,
#  ('və', 'fadə', 'EOS'): 2,
#  ('EOS', 'ya', 'fadə'): 2,
#  ('ümumi', 'EOS', 'EOS'): 2,
#  ('adına', 'EOS', 'EOS'): 2,
#  ('də', 'ilə', 'EOS'): 2,
#  ('EOS', 'və', 'müəllif'): 2,
#  ('və', 'müəllif', 'EOS'): 2,
#  ('bu', 'və', 'ilə'): 2,
#  ('EOS', 'edilən', 'EOS'): 2,
#  ('EOS', 'EOS', 'əlaqəyə'): 2,
#  ('əlyazma', 'EOS', 'EOS'): 2,
#  ('hər', 'EOS', 'EOS'): 2,
#  ('EOS', 'və', 'bir'): 2,
#  ('EOS', 'ibarət', 'və'): 2,
#  ('ilk', 'k', 'EOS'): 2,
#  ('ibarət', 'EOS', 'və'): 2,
#  ('EOS', 'az', 'EOS'): 2,
#  ('özündə', 'EOS', 'EOS'): 2,
#  ('EOS', 'və', 'qravür'): 2,
#  ('EOS', 'ilk', 'və'): 2,
#  ('k', 'n', 'olan'): 2,
#  ('yaradılmış', 'EOS', 'nın'): 2,
#  ('qaydada', 'EOS', 'EOS'): 2,
#  ('EOS', 'analit', 'informasiya'): 2,
#  ('s', 'və', 'EOS'): 2,
#  ('EOS', 'və', 'görə'): 2,
#  ('və', 'edir', 'azərbaycan'): 2,
#  ('və', 'ist', 'edir'): 2,
#  ('EOS', 'sonralar', 'EOS'): 2,
#  ('ndə', 'EOS', 'EOS'): 2,
#  ('idarə', 'EOS', 'EOS'): 2,
#  ('və', 'və', 'nin'): 2,
#  ('mədəniyyət', 'və', 'və'): 2,
#  ('və', 'və', 'əsərlərinin'): 2,
#  ('və', 'onun', 'EOS'): 2,
#  ('ildən', 'EOS', 'və'): 2,
#  ('audiovizual', 'EOS', 'EOS'): 2,
#  ('EOS', 'EOS', 'edilməsi'): 2,
#  ('k', 'fəaliyyət', 'EOS'): 2,
#  ('olan', 'min', 'və'): 2,
#  ('kitabxana', 'olan', 'EOS'): 2,
#  ('bu', 'yaradılması', 'EOS'): 2,
#  ('k', 'EOS', 'v'): 2,
#  ('üçün', 'EOS', 'də'): 2,
#  ('maşınla', 'EOS', 'EOS'): 2,
#  ('çox', 'və', 'EOS'): 2,
#  ('və', 'EOS', 'da'): 2,
#  ('ibarətdir', 'və', 'EOS'): 2,
#  ('və', 'EOS', 'müstəqil'): 2,
#  ('biliklərin', 'EOS', 'EOS'): 2,
#  ('EOS', 'maddi', 'EOS'): 2,
#  ('mərkəzi', 'və', 'EOS'): 2,
#  ('EOS', 'fəaliyyət', 'və'): 2,
#  ('və', 'əsərləri', 'və'): 2,
#  ('EOS', 'EOS', 'yaradılmış'): 2,
#  ('klaviatura', 'EOS', 'EOS'): 2,
#  ('EOS', 'və', 'dair'): 2,
#  ('dövri', 'EOS', 'EOS'): 2,
#  ('EOS', 'şəxsi', 'EOS'): 2,
#  ('və', 'ki', 'EOS'): 2,
#  ('mindən', 'EOS', 'EOS'): 2,
#  ('rilməsi', 'və', 'EOS'): 2,
#  ('EOS', 'tədqiq', 'EOS'): 2,
#  ('EOS', 'bu', 'və'): 2,
#  ('və', 'ilə', 'kitabxanasından'): 2,
#  ('uşaq', 'EOS', 'EOS'): 2,
#  ('dissertasiyalar', 'EOS', 'EOS'): 2,
#  ('kitab', 'ist', 'EOS'): 2,
#  ('EOS', 'olunur', 'və'): 2,
#  ('və', 'EOS', 'i'): 2,
#  ('və', 'olar', 'EOS'): 2,
#  ('ki', 'EOS', 'EOS'): 2,
#  ('EOS', 'yeni', 'EOS'): 2,
#  ('ndən', 'milli', 'və'): 2,
#  ('və', 'əks', 'EOS'): 2,
#  ('EOS', 'ildə', 'və'): 2,
#  ('lazımdır', 'EOS', 'EOS'): 2,
#  ('kitabxanaları', 'EOS', 'EOS'): 2,
#  ('EOS', 'EOS', 'tədris'): 2,
#  ('akademik', 'EOS', 'EOS'): 2,
#  ('EOS', 'və', 'daha'): 2,
#  ('və', 'nəzərdə', 'n'): 2,
#  ('EOS', 'EOS', 'adlı'): 2,
#  ('EOS', 'EOS', 'vəsaitlər'): 2,
#  ('və', 'və', 'informasiya'): 2,
#  ('və', 'informasiya', 'ilə'): 2,
#  ('EOS', 'EOS', 'xüsusi'): 2,
#  ('EOS', 'haqqında', 'və'): 2,
#  ('kitabxana', 'qeyd', 'EOS'): 2,
#  ('və', 'EOS', 'adına'): 2,
#  ('EOS', 'dissertasiya', 'EOS'): 2,
#  ('davam', 'EOS', 'k'): 2,
#  ('k', 'və', 'mürəkkəb'): 2,
#  ('EOS', 'informasiyanın', 'EOS'): 2,
#  ('EOS', 'ərzində', 'EOS'): 2,
#  ('EOS', 'mədəniyyət', 'kimi'): 2,
#  ('olmuşdur', 'ilə', 'EOS'): 2,
#  ('və', 'EOS', 'yeni'): 2,
#  ('kitabxana', 'EOS', 'n'): 2,
#  ('EOS', 'ilə', 'bir'): 2,
#  ('informasiyanın', 'və', 'və'): 2,
#  ('EOS', 'və', 'da'): 2,
#  ('və', 'EOS', 'müdiri'): 2,
#  ('EOS', 'EOS', 'mütaliə'): 2,
#  ('EOS', 'illərdə', 'milli'): 2,
#  ('EOS', 'EOS', 'q'): 2,
#  ('EOS', 'EOS', 'ə'): 2,
#  ('ilə', 'EOS', 'olunmuşdur'): 2,
#  ('EOS', 'azərbaycan', 'o'): 2,
#  ('xidmət', 'EOS', 'və'): 2,
#  ('lazımdır', 'EOS', 'haqqında'): 2,
#  ('EOS', 'və', 'xarici'): 2,
#  ('kimi', 'fadə', 'EOS'): 2,
#  ('nin', 'milli', 'EOS'): 2,
#  ('EOS', 'ya', 'na'): 2,
#  ('çap', 'EOS', 'EOS'): 2,
#  ('EOS', 'elektron', 'EOS'): 2,
#  ('k', 'EOS', 'bağlı'): 2,
#  ('və', 'ndə', 'və'): 2,
#  ('və', 'EOS', 'ədəbiyyat'): 2,
#  ('yası', 'EOS', 'EOS'): 2,
#  ('və', 'burada', 'və'): 2,
#  ('EOS', 'bütün', 'bir'): 2,
#  ('üzrə', 'son', 'EOS'): 2,
#  ('yası', 'EOS', 'kitabxana'): 2,
#  ('EOS', 'n', 'azərbaycan'): 2,
#  ('EOS', 'EOS', 'kitabxanaçılıq'): 2,
#  ('EOS', 'EOS', 'tərtər'): 2,
#  ('mk', 'EOS', 'və'): 2,
#  ('EOS', 'və', 'daxil'): 2,
#  ('olan', 'və', 'EOS'): 2,
#  ('xüsusi', 'EOS', 'EOS'): 2,
#  ('EOS', 'min', 'EOS'): 2,
#  ('isə', 'EOS', 'və'): 2,
#  ('EOS', 'və', 'çox'): 2,
#  ('EOS', 'EOS', 'malik'): 2,
#  ('və', 'bilər', 'və'): 2,
#  ('texniki', 'və', 'EOS'): 2,
#  ('EOS', 'obyekt', 'bir'): 2,
#  ('və', 'və', 'is'): 2,
#  ('EOS', 'vəzifələri', 't'): 2,
#  ('EOS', 'EOS', 'ali'): 2,
#  ('k', 'ildə', 'ilə'): 2,
#  ('sənədlər', 'EOS', 'EOS'): 2,
#  ('EOS', 'EOS', 'etməyə'): 2,
#  ('EOS', 'sadi', 'EOS'): 2,
#  ('mərkəzi', 'EOS', 'ilə'): 2,
#  ('EOS', 'ərəb', 'EOS'): 2,
#  ('k', 'kitabxana', 'və'): 2,
#  ('olunur', 'nin', 'və'): 2,
#  ('EOS', 'EOS', 'olunmuş'): 2,
#  ('EOS', 'ildə', 'ümumi'): 2,
#  ('v', 'olaraq', 'EOS'): 2,
#  ('olaraq', 'EOS', 'EOS'): 2,
#  ('əsasında', 'ya', 'ilə'): 2,
#  ('EOS', 'EOS', 'sənədin'): 2,
#  ('EOS', 'və', 'axtarışın'): 2,
#  ('nəzərdə', 'EOS', 'EOS'): 2,
#  ('təhlil', 'EOS', 'EOS'): 2,
#  ('şəkildə', 'üzrə', 'EOS'): 2,
#  ('tərt', 'və', 'başqa'): 2,
#  ('EOS', 'n', 'bir'): 2,
#  ('bütün', 'və', 'EOS'): 2,
#  ('və', 'üçün', 'kitabxana'): 2,
#  ('EOS', 'idi', 'və'): 2,
#  ('sənədlərin', 'kitabxana', 'EOS'): 2,
#  ('EOS', 't', 'informasiya'): 2,
#  ('EOS', 'olmuş', 'və'): 2,
#  ('və', 'indiki', 'EOS'): 2,
#  ('EOS', 'və', 'azərbaycanda'): 2,
#  ('yasının', 'və', 'EOS'): 2,
#  ('EOS', 'və', 'ölkədə'): 2,
#  ('EOS', 't', 'nin'): 2,
#  ('əsrin', 'EOS', 'və'): 2,
#  ('EOS', 'bir', 'ildə'): 2,
#  ('ist', 'EOS', 'bu'): 2,
#  ('EOS', 'və', 't'): 2,
#  ('eht', 'və', 'EOS'): 2,
#  ('və', 'EOS', 'tərt'): 2,
#  ('ndən', 'və', 'və'): 2,
#  ('bu', 'EOS', 'jurnal'): 2,
#  ('ildə', 'EOS', 'k'): 2,
#  ('illərdə', 'EOS', 'EOS'): 2,
#  ('bütün', 'EOS', 'EOS'): 2,
#  ('k', 'EOS', 'informasiya'): 2,
#  ('və', 'ilə', 'ist'): 2,
#  ('bir', 'kitabxana', 'EOS'): 2,
#  ('və', 'yeni', 'EOS'): 2,
#  ('bütün', 'EOS', 'və'): 2,
#  ('edərək', 'EOS', 'və'): 2,
#  ('əsərləri', 'və', 'üzrə'): 2,
#  ('EOS', 'asılı', 'edərək'): 2,
#  ('EOS', 'EOS', 'asılı'): 2,
#  ('və', 'öz', 'EOS'): 2,
#  ('yüksək', 'və', 'və'): 2,
#  ('EOS', 'EOS', 'olmuşdur'): 2,
#  ('EOS', 'üçün', 'ya'): 2,
#  ('EOS', 'və', 'analit'): 2,
#  ('EOS', 'öyrənilməsi', 'milli'): 2,
#  ('s', 'və', 'ilə'): 2,
#  ('sahəvi', 'EOS', 'EOS'): 2,
#  ('ki', 'kitab', 'və'): 2,
#  ('EOS', 'EOS', 'dünyanın'): 2,
#  ('kütləvi', 'EOS', 'EOS'): 2,
#  ('kollekt', 'EOS', 'və'): 2,
#  ('məqsədilə', 'EOS', 'EOS'): 2,
#  ('konkret', 'EOS', 'EOS'): 2,
#  ('ya', 'üzrə', 'EOS'): 2,
#  ('dair', 'EOS', 'və'): 2,
#  ('EOS', 'və', 'ölkələri'): 2,
#  ('EOS', 'EOS', 'yerinə'): 2,
#  ('ist', 'yaradılmışdır', 'EOS'): 2,
#  ('müxtəlif', 'olan', 'EOS'): 2,
#  ('EOS', 'nəşri', 'bir'): 2,
#  ('nəşri', 'bir', 'EOS'): 2,
#  ('k', 'ilə', 'EOS'): 2,
#  ('ildə', 'ya', 'EOS'): 2,
#  ('olunmuş', 'təcrübi', 'EOS'): 2,
#  ('EOS', 'EOS', 'gələcək'): 2,
#  ('a', 'EOS', 'və'): 2,
#  ('və', 'EOS', 'bütün'): 2,
#  ('mk', 'EOS', 'EOS'): 2,
#  ('və', 'EOS', 'stat'): 2,
#  ('xidmət', 'ya', 'EOS'): 2,
#  ('və', 'EOS', 'olan'): 2,
#  ('EOS', 'və', 'əməkdaşlıq'): 2,
#  ('əsrin', 'və', 'kitab'): 2,
#  ('EOS', 'edir', 'EOS'): 2,
#  ('EOS', 'və', 'q'): 2,
#  ('EOS', 'k', 'olan'): 2,
#  ('və', 'qeyd', 'bib'): 2,
#  ('min', 'EOS', 'EOS'): 2,
#  ('çap', 'uşaq', 'EOS'): 2,
#  ('eləcə', 'və', 'EOS'): 2,
#  ('nin', 'bu', 'EOS'): 2,
#  ('üçün', 'ya', 'respublikasının'): 2,
#  ('EOS', 'haqqında', 'EOS'): 2,
#  ('EOS', 'EOS', 'keçirilir'): 2,
#  ('k', 'yet', 'isə'): 2,
#  ('EOS', 'azərbaycanda', 'EOS'): 2,
#  ('k', 'EOS', 'həm'): 2,
#  ('bakı', 'EOS', 'EOS'): 2,
#  ('inkişaf', 'EOS', 'və'): 2,
#  ('EOS', 'həmin', 'və'): 2,
#  ('s', 'kitabxana', 'EOS'): 2,
#  ('çox', 'EOS', 'əlavə'): 2,
#  ('t', 'nin', 'EOS'): 2,
#  ('azərbaycan', 'EOS', 'və'): 2,
#  ('və', 'ilk', 'EOS'): 2,
#  ('EOS', 'aid', 'üzrə'): 2,
#  ('EOS', 'çox', 'EOS'): 2,
#  ('EOS', 'EOS', 'təsvir'): 2,
#  ('EOS', 'həyata', 'mədəniyyət'): 2,
#  ('maarifpərvər', 'EOS', 'EOS'): 2,
#  ('EOS', 'respublika', 'təşkil'): 2,
#  ('və', 'azərbaycanda', 'EOS'): 2,
#  ('və', 'tərkibinə', 'müxtəlif'): 2,
#  ('və', 'ist', 'və'): 2,
#  ('EOS', 'əsas', 'EOS'): 2,
#  ('EOS', 'k', 'illərdə'): 2,
#  ('EOS', 'kitabxananın', 'EOS'): 2,
#  ('na', 'bu', 'kimi'): 2,
#  ('müəyyən', 'EOS', 'EOS'): 2,
#  ('EOS', 'v', 'ölkələrin'): 2,
#  ('uzun', 'EOS', 'EOS'): 2,
#  ('EOS', 'bu', 'milli'): 2,
#  ('EOS', 'EOS', 'sahəsində'): 2,
#  ('alim', 'EOS', 'və'): 2,
#  ('k', 'EOS', 'üçün'): 2,
#  ('EOS', 'dünya', 'ilə'): 2,
#  ('və', 'bir', 'EOS'): 2,
#  ('tərt', 'və', 'EOS'): 2,
#  ('EOS', 'informasiya', 'ist'): 2,
#  ('k', 'a', 'EOS'): 2,
#  ('kitabxanalar', 'EOS', 'və'): 2,
#  ('və', 'kitabxana', 'və'): 2,
#  ('ildə', 'EOS', 'kitabxananın'): 2,
#  ('EOS', 'EOS', 'mərkəzi'): 2,
#  ('üçün', 'ki', 'EOS'): 2,
#  ('kitab', 'EOS', 'ildən'): 2,
#  ('EOS', 'və', 'na'): 2,
#  ('dövlət', 'EOS', 'və'): 2,
#  ('EOS', 'belə', 'nin'): 2,
#  ('EOS', 'ilə', 'olaraq'): 2,
#  ('ildən', 'və', 'və'): 2,
#  ('və', 'və', 'üzrə'): 2,
#  ('EOS', 'nüsxə', 'ki'): 2,
#  ('EOS', 'qanuna', 'və'): 2,
#  ('EOS', 'p', 'EOS'): 2,
#  ('da', 'fəaliyyət', 'EOS'): 2,
#  ('sənədlərin', 'EOS', 'k'): 2,
#  ('yazının', 'dövlət', 'EOS'): 2,
#  ('üçün', 'bir', 'EOS'): 2,
#  ('EOS', 'bu', 'elmi'): 2,
#  ('və', 'EOS', 'olduğu'): 2,
#  ('EOS', 'təcrübəsi', 'EOS'): 2,
#  ('EOS', 'EOS', 'ni'): 2,
#  ('EOS', 'və', 'də'): 2,
#  ('EOS', 'bir', 'ist'): 2,
#  ('həmin', 'informasiya', 'EOS'): 2,
#  ('EOS', 'EOS', 'mai'): 2,
#  ('tədris', 'EOS', 'və'): 2,
#  ('və', 'EOS', 'dövlət'): 2,
#  ('bir', 'metodik', 'milli'): 2,
#  ('və', 'universitet', 'dair'): 2,
#  ('göstəricinin', 'bir', 'EOS'): 2,
#  ('EOS', 'aid', 'EOS'): 2,
#  ('isə', 'EOS', 'EOS'): 2,
#  ('daxili', 'və', 'n'): 2,
#  ('üçün', 'EOS', 'ilə'): 2,
#  ('müəyyən', 'EOS', 'və'): 2,
#  ('EOS', 'və', 'bazalarının'): 2,
#  ('və', 'n', 'informasiya'): 2,
#  ('işinin', 'EOS', 'EOS'): 2,
#  ('EOS', 'EOS', 'məlumat'): 2,
#  ('keçirilir', 'EOS', 'EOS'): 2,
#  ('elmi', 'n', 'EOS'): 2,
#  ('EOS', 'EOS', 'əhatə'): 2,
#  ('EOS', 'ilə', 'çap'): 2,
#  ('ki', 'b', 'EOS'): 2,
#  ('s', 'EOS', 'EOS'): 2,
#  ('üçün', 'EOS', 'bu'): 2,
#  ('adda', 'EOS', 'və'): 2,
#  ('EOS', 'və', 'fondunun'): 2,
#  ('EOS', 'və', 'yaradılmış'): 2,
#  ('EOS', 'fondu', 'çox'): 2,
#  ('EOS', 'mövzu', 'və'): 2,
#  ('EOS', 'adına', 'EOS'): 2,
#  ('k', 'EOS', 'ildə'): 2,
#  ('bütün', 'EOS', 'e'): 2,
#  ('kitab', 'bir', 'EOS'): 2,
#  ('hökmdarı', 'EOS', 'EOS'): 2,
#  ('və', 'EOS', 'yunesko'): 2,
#  ('və', 'ist', 'EOS'): 2,
#  ('lövhə', 'EOS', 'EOS'): 2,
#  ('EOS', 'EOS', 'verilənlər'): 2,
#  ('EOS', 'və', 'hər'): 2,
#  ('tərt', 'EOS', 'və'): 2,
#  ('və', 'də', 'EOS'): 2,
#  ('ya', 'EOS', 'k'): 2,
#  ('göstəricilər', 'EOS', 'EOS'): 2,
#  ('EOS', 'və', 'göstərir'): 2,
#  ('adına', 'n', 'EOS'): 2,
#  ('EOS', 'sıra', 'EOS'): 2,
#  ('malikdir', 'EOS', 'da'): 2,
#  ('EOS', 'cəmiyyət', 'informasiya'): 2,
#  ('əsr', 'EOS', 'EOS'): 2,
#  ('kitabxanalarının', 'və', 'EOS'): 2,
#  ('EOS', 'təşkil', 'edilmişdir'): 2,
#  ('ki', 'ndən', 'EOS'): 2,
#  ('daxil', 'və', 'EOS'): 2,
#  ('EOS', 'üçün', 'və'): 2,
#  ('EOS', 'kənd', 'bir'): 2,
#  ('materialların', 'EOS', 'EOS'): 2,
#  ('yanaşı', 'EOS', 'EOS'): 2,
#  ('EOS', 'alimi', 'EOS'): 2,
#  ('ya', 'kitab', 'n'): 2,
#  ('EOS', 'beynəlxalq', 'EOS'): 2,
#  ('EOS', 'bir', 'idi'): 2,
#  ('EOS', 'kitab', 'görə'): 2,
#  ('EOS', 'EOS', 'dövri'): 2,
#  ('bütün', 'EOS', 'kitabxana'): 2,
#  ('elmləri', 'EOS', 'EOS'): 2,
#  ('imkan', 'bütün', 'EOS'): 2,
#  ('EOS', 'və', 'yaradılması'): 2,
#  ('EOS', 'çap', 'EOS'): 2,
#  ('EOS', 'EOS', 'komitəsinin'): 2,
#  ('kitabxana', 'EOS', 'kitab'): 2,
#  ('EOS', 'jurnalı', 'EOS'): 2,
#  ('EOS', 'son', 'EOS'): 2,
#  ('infor', 'EOS', 'EOS'): 2,
#  ('EOS', 'etdirən', 'EOS'): 2,
#  ('k', 'EOS', 'adına'): 2,
#  ('EOS', 'milli', 'münasibət'): 2,
#  ('EOS', 'və', 'məcburi'): 2,
#  ('kitab', 'prezident', 'EOS'): 2,
#  ('EOS', 'kitab', 'ildə'): 2,
#  ('EOS', 'bakı', 'EOS'): 2,
#  ('beynəlxalq', 'etmişdir', 'EOS'): 2,
#  ('prosesi', 'EOS', 'və'): 2,
#  ('EOS', 'və', 'qısa'): 2,
#  ('ildə', 'və', 'görə'): 2,
#  ('dünyanın', 'EOS', 'EOS'): 2,
#  ('EOS', 'həyata', 'EOS'): 2,
#  ('və', 'EOS', 'q'): 2,
#  ('tərt', 'və', 'k'): 2,
#  ('EOS', 'EOS', 'olaraq'): 2,
#  ('nət', 'EOS', 'və'): 2,
#  ('k', 'EOS', 'jurnal'): 2,
#  ('EOS', 'kitab', 'nail'): 2,
#  ('ildə', 't', 'EOS'): 2,
#  ('yası', 'və', 'EOS'): 2,
#  ('son', 'və', 'EOS'): 2,
#  ('həm', 'və', 'və'): 2,
#  ('EOS', 'nın', 'EOS'): 2,
#  ('kitabxanaşünaslıq', 'EOS', 'EOS'): 2,
#  ('nəşrlərinin', 'EOS', 'EOS'): 2,
#  ('bütün', 'EOS', 'bu'): 2,
#  ('EOS', 'EOS', 'tutan'): 2,
#  ('fadə', 'EOS', 'EOS'): 2,
#  ('EOS', 'və', 'bunlar'): 2,
#  ('EOS', 'olunmuşdur', 'EOS'): 2,
#  ('kafedrasının', 'k', 'EOS'): 2,
#  ('və', 'üçün', 'və'): 2,
#  ('ildə', 'o', 'EOS'): 2,
#  ('EOS', 'əsasında', 'kitabxana'): 2,
#  ('EOS', 'də', 'da'): 2,
#  ('EOS', 'olunan', 'EOS'): 2,
#  ('onun', 'edən', 'və'): 2,
#  ('EOS', 'nəşr', 'yaradılmışdır'): 2,
#  ('EOS', 'elektron', 'və'): 2,
#  ('EOS', 'və', 'metodik'): 2,
#  ('nəşrin', 'EOS', 'EOS'): 2,
#  ('EOS', 'azərbaycan', 'və'): 2,
#  ('və', 'EOS', 'mədəni'): 2,
#  ('library', 'EOS', 'EOS'): 2,
#  ('çap', 'EOS', 'k'): 2,
#  ('k', 'təyin', 'EOS'): 2,
#  ('EOS', 'ya', 'əlavə'): 2,
#  ('EOS', 'illərdə', 'və'): 2,
#  ('EOS', 'EOS', 'kütləvi'): 2,
#  ('və', 'ildə', 'işlənməsi'): 2,
#  ('və', 'ndən', 'və'): 2,
#  ('ist', 'EOS', 'ali'): 2,
#  ('və', 'yasının', 'və'): 2,
#  ('k', 'EOS', 'k'): 2,
#  ('EOS', 'zaman', 'EOS'): 2,
#  ('və', 'elmi', 'EOS'): 2,
#  ('idi', 'və', 'fərdi'): 2,
#  ('və', 'edilir', 'və'): 2,
#  ('EOS', 'əsas', 'təhsil'): 2,
#  ('EOS', 'də', 'və'): 2,
#  ('EOS', 'sonra', 'rus'): 2,
#  ('EOS', 'a', 'ölkəşünaslıq'): 2,
#  ('EOS', 'a', 'EOS'): 2,
#  ('və', 'ilə', 'ilə'): 2,
#  ('üzrə', 'EOS', 'EOS'): 2,
#  ('EOS', 'EOS', 'p'): 2,
#  ('və', 'EOS', 'yolu'): 2,
#  ('ilə', 'EOS', 'bu'): 2,
#  ('digər', 'EOS', 'və'): 2,
#  ('EOS', 'EOS', 'daha'): 2,
#  ('nin', 'və', 'EOS'): 2,
#  ('EOS', 'və', 'kitabxanalarının'): 2,
#  ('azərbaycan', 'və', 'kimi'): 2,
#  ('k', 'EOS', 'oxucuların'): 2,
#  ('məsələn', 'EOS', 'və'): 2,
#  ('və', 'k', 'yaradılmış'): 2,
#  ('həyata', 'və', 'EOS'): 2,
#  ('EOS', 'ilə', 'dəfə'): 2,
#  ('EOS', 'EOS', 'verilir'): 2,
#  ('dəqiq', 'EOS', 'EOS'): 2,
#  ('EOS', 'EOS', 'bütün'): 2,
#  ('EOS', 'EOS', 'proqram'): 2,
#  ('EOS', 'ildə', 'illərdə'): 2,
#  ('işçi', 'EOS', 'EOS'): 2,
#  ('EOS', 'EOS', 'təşkilatlar'): 2,
#  ('kitabşünaslıq', 'EOS', 'EOS'): 2,
#  ('ildə', 'EOS', 'olunan'): 2,
#  ('və', 'EOS', 'mühüm'): 2,
#  ('və', 'da', 'EOS'): 2,
#  ('ya', 'EOS', 'informasiya'): 2,
#  ('EOS', 'informasiya', 'üçün'): 2,
#  ('informasiyanı', 'EOS', 'EOS'): 2,
#  ('fəaliyyət', 'EOS', 'EOS'): 2,
#  ('EOS', 'biridir', 'EOS'): 2,
#  ('EOS', 'EOS', 'anadan'): 2,
#  ('kitabxanaları', 'ə', 'EOS'): 2,
#  ('EOS', 'EOS', 'dəfə'): 2,
#  ('EOS', 'm', 'daxil'): 2,
#  ('EOS', 'EOS', 'əsrin'): 2,
#  ('və', 'EOS', 'b'): 2,
#  ('EOS', 'internet', 'EOS'): 2,
#  ('adı', 'əsasında', 'ildə'): 2,
#  ('kitab', 'və', 'EOS'): 2,
#  ('sıra', 'var', 'EOS'): 2,
#  ('EOS', 'edir', 'nin'): 2,
#  ('EOS', 'və', 'ist'): 2,
#  ('və', 'ist', 'də'): 2,
#  ('kataloq', 'EOS', 'EOS'): 2,
#  ('olan', 'azərbaycan', 'ilə'): 2,
#  ('EOS', 'və', 'ədəbiyyat'): 2,
#  ('və', 'ildə', 'çapdan'): 2,
#  ('hansı', 'və', 'və'): 2,
#  ('və', 'azərbaycan', 'edilən'): 2,
#  ('EOS', 'EOS', 'sənəd'): 2,
#  ('EOS', 'sənəd', 'k'): 2,
#  ('EOS', 'EOS', 'fondu'): 2,
#  ('EOS', 'nəzərdə', 'EOS'): 2,
#  ('EOS', 'EOS', 'zaman'): 2,
#  ('onun', 'çap', 'EOS'): 2,
#  ('EOS', 'EOS', 'keçirilən'): 2,
#  ('ildə', 'üzrə', 'və'): 2,
#  ('əsas', 'və', 'n'): 2,
#  ('sənədlərin', 'EOS', 'EOS'): 2,
#  ('EOS', 'EOS', 'onlara'): 2,
#  ('azərbaycan', 'bir', 'EOS'): 2,
#  ('ilə', 'edir', 'EOS'): 2,
#  ('zamanda', 'EOS', 'EOS'): 2,
#  ('EOS', 'və', 'yeni'): 2,
#  ('EOS', 'EOS', 'kitabxanası'): 2,
#  ('və', 'EOS', 'yazılmış'): 2,
#  ('EOS', 'üzrə', 'bütün'): 2,
#  ('EOS', 'cəmiyyət', 'EOS'): 2,
#  ('təşkil', 'və', 'il'): 2,
#  ('EOS', 'EOS', 'işinin'): 2,
#  ('və', 'EOS', 'ilk'): 2,
#  ('fadə', 'EOS', 'bu'): 2,
#  ('EOS', 'EOS', 'kitabı'): 2,
#  ('üzrə', 'ilə', 'EOS'): 2,
#  ('EOS', 'və', 'ndən'): 2,
#  ('EOS', 'olaraq', 'n'): 2,
#  ('asılı', 'EOS', 'dövlət'): 2,
#  ('tarixi', 'EOS', 'və'): 2,
#  ('EOS', 'xüsusi', 'EOS'): 2,
#  ('və', 's', 'EOS'): 2,
#  ('və', 'EOS', 'respublika'): 2,
#  ('arasında', 'EOS', 'EOS'): 2,
#  ('EOS', 'keçmiş', 'EOS'): 2,
#  ('və', 'və', 'tərt'): 2,
#  ('EOS', 'informasiya', 'k'): 2,
#  ('referat', 'EOS', 'EOS'): 2,
#  ('və', 'n', 'EOS'): 2,
#  ('olmuşdur', 'EOS', 'ya'): 2,
#  ('EOS', 'rusiya', 'bu'): 2,
#  ('EOS', 'nət', 'EOS'): 2,
#  ('və', 'nəzərdə', 'EOS'): 2,
#  ('və', 'EOS', 'üzrə'): 2,
#  ('EOS', 'və', 'xarakterli'): 2,
#  ('EOS', 'EOS', 'doktoru'): 2,
#  ('EOS', 'EOS', 'işt'): 2,
#  ('EOS', 'kitabxanalar', 'EOS'): 2,
#  ('və', 'EOS', 'bi'): 2,
#  ('də', 'EOS', 'fəaliyyət'): 2,
#  ('k', 'respublikası', 'və'): 2,
#  ('azərbaycan', 'və', 'və'): 2,
#  ('EOS', 'EOS', 'çap'): 2,
#  ('fadə', 'EOS', 'azərbaycan'): 2,
#  ('EOS', 'kitabxanası', 'azərbaycan'): 2,
#  ('EOS', 'küçəsində', 'EOS'): 2,
#  ('EOS', 'əmək', 'ilə'): 2,
#  ('EOS', 'bax', 'və'): 2,
#  ('edir', 'növlərindən', 'EOS'): 2,
#  ('EOS', 'k', 'ildən'): 2,
#  ('və', 'EOS', 's'): 2,
#  ('EOS', 'EOS', 'kitabxanasının'): 2,
#  ('nə', 'ildə', 'EOS'): 2,
#  ('k', 'və', 'k'): 2,
#  ('məzmunu', 'EOS', 'də'): 2,
#  ('EOS', 'bürosu', 'EOS'): 2,
#  ('ən', 'EOS', 'EOS'): 2,
#  ('bir', 'EOS', 'tərt'): 2,
#  ('informasiya', 'EOS', 'ildə'): 2,
#  ('ildə', 'EOS', 'respublika'): 2,
#  ('və', 'və', 'ilə'): 2,
#  ('EOS', 'EOS', 'respublikanın'): 2,
#  ('və', 'və', 'növüdür'): 2,
#  ('öz', 'EOS', 'EOS'): 2,
#  ('və', 'üçün', 'f'): 2,
#  ('EOS', 'zamanı', 'EOS'): 2,
#  ('EOS', 'EOS', 'rəhbər'): 2,
#  ('nin', 'əsas', 'göstəricisi'): 2,
#  ('EOS', 'bir', 'kitabxana'): 2,
#  ('ya', 'k', 'və'): 2,
#  ('haqqında', 'EOS', 'informasiya'): 2,
#  ('və', 'inkişaf', 'EOS'): 2,
#  ('kimi', 'nəşr', 'EOS'): 2,
#  ('də', 'EOS', 'k'): 2,
#  ('məsələn', 'EOS', 'EOS'): 2,
#  ('EOS', 'EOS', 'fadə'): 2,
#  ('kitabxana', 'bu', 'böyük'): 2,
#  ('və', 'və', 'bir'): 2,
#  ('EOS', 'kitabxanalar', 'na'): 2,
#  ('EOS', 'beynəlxalq', 'universitet'): 2,
#  ('EOS', 'mü', 'və'): 2,
#  ('EOS', 'k', 'türk'): 2,
#  ('EOS', 'EOS', 'pli'): 2,
#  ('fadə', 'üzrə', 'və'): 2,
#  ('EOS', 'və', 'əsrin'): 2,
#  ('kitabxana', 'k', 'və'): 2,
#  ('EOS', 'q', 'ilə'): 2,
#  ('EOS', 'EOS', 'oxucu'): 2,
#  ('EOS', 'zaman', 'və'): 2,
#  ('EOS', 'xarici', 'k'): 2,
#  ('EOS', 'EOS', 'nət'): 2,
#  ('EOS', 'və', 'a'): 2,
#  ('EOS', 'əsərlər', 'olan'): 2,
#  ('EOS', 'n', 'şəhərində'): 2,
#  ('üçün', 'bu', 'EOS'): 2,
#  ('ilə', 'EOS', 'ildən'): 2,
#  ('EOS', 'ə', 'və'): 2,
#  ('onların', 'və', 'EOS'): 2,
#  ('EOS', 'üzrə', 'n'): 2,
#  ('ilə', 'də', 'dövlət'): 2,
#  ('rus', 'və', 'qeyd'): 2,
#  ('çox', 'EOS', 'EOS'): 2,
#  ('də', 'EOS', 'edilir'): 2,
#  ('hələ', 'EOS', 'EOS'): 2,
#  ('EOS', 'ndə', 'EOS'): 2,
#  ('və', 'edilməsi', 'EOS'): 2,
#  ('dünya', 'EOS', 'EOS'): 2,
#  ('EOS', 'biri', 'EOS'): 2,
#  ('EOS', 'EOS', 'yaradılması'): 2,
#  ('q', 'EOS', 'və'): 2,
#  ('EOS', 'EOS', 'universitet'): 2,
#  ('EOS', 's', 'EOS'): 2,
#  ('EOS', 'EOS', 'növləri'): 2,
#  ('EOS', 'onun', 'və'): 2,
#  ('ilə', 'edilir', 'və'): 2,
#  ('tə', 'EOS', 'EOS'): 2,
#  ('EOS', 'olaraq', 'olar'): 2,
#  ('mədəni', 'EOS', 'EOS'): 2,
#  ('adlı', 'EOS', 'ildən'): 2,
#  ('EOS', 'k', 'kimi'): 2,
#  ('daha', 'və', 'və'): 2,
#  ('şərh', 'EOS', 'bu'): 2,
#  ('EOS', 'də', 'kimi'): 2,
#  ('universal', 'EOS', 'və'): 2,
#  ('EOS', 'bu', 'ist'): 2,
#  ('kitabxana', 'və', 'ilə'): 2,
#  ('ümumi', 'EOS', 'və'): 2,
#  ...}

# %%
unigram_counts
bigram_counts
trigram_counts
# Out:
# Counter({('EOS', 'EOS', 'EOS'): 102,
#          ('EOS', 'EOS', 'və'): 51,
#          ('və', 'EOS', 'EOS'): 42,
#          ('EOS', 'və', 'EOS'): 41,
#          ('EOS', 'və', 'və'): 21,
#          ('və', 'və', 'EOS'): 19,
#          ('EOS', 'ildə', 'EOS'): 15,
#          ('EOS', 'k', 'EOS'): 14,
#          ('EOS', 'EOS', 'k'): 12,
#          ('və', 'EOS', 'və'): 12,
#          ('EOS', 'və', 'ilə'): 11,
#          ('EOS', 'EOS', 'ilə'): 11,
#          ('EOS', 'bu', 'EOS'): 11,
#          ('və', 'və', 'və'): 11,
#          ('k', 'EOS', 'EOS'): 11,
#          ('EOS', 'informasiya', 'EOS'): 10,
#          ('EOS', 'EOS', 'n'): 10,
#          ('EOS', 'EOS', 'bu'): 10,
#          ('ildə', 'EOS', 'EOS'): 9,
#          ('EOS', 'EOS', 'bir'): 9,
#          ('EOS', 'EOS', 'nin'): 8,
#          ('ilə', 'EOS', 'EOS'): 8,
#          ('EOS', 'EOS', 'üçün'): 8,
#          ('mədəniyyət', 'EOS', 'EOS'): 8,
#          ('EOS', 'EOS', 'ist'): 8,
#          ('EOS', 'EOS', 'haqqında'): 8,
#          ('elmi', 'EOS', 'və'): 8,
#          ('EOS', 'ilə', 'EOS'): 8,
#          ('EOS', 'üçün', 'EOS'): 7,
#          ('və', 'EOS', 'azərbaycan'): 7,
#          ('ya', 'EOS', 'EOS'): 7,
#          ('EOS', 'ildən', 'EOS'): 7,
#          ('EOS', 'və', 'kitabxana'): 7,
#          ('EOS', 'EOS', 't'): 7,
#          ('edir', 'EOS', 'EOS'): 7,
#          ('EOS', 'EOS', 'ildə'): 7,
#          ('EOS', 'EOS', 'elmi'): 7,
#          ('EOS', 'kitabxana', 'EOS'): 7,
#          ('EOS', 'EOS', 'il'): 7,
#          ('EOS', 'EOS', 'ki'): 7,
#          ('EOS', 'EOS', 'informasiya'): 6,
#          ('və', 'haqqında', 'EOS'): 6,
#          ('EOS', 'kitab', 'EOS'): 6,
#          ('EOS', 'EOS', 'kitabxana'): 6,
#          ('EOS', 'və', 'üzrə'): 6,
#          ('kitabxana', 'EOS', 'və'): 6,
#          ('EOS', 'ist', 'EOS'): 6,
#          ('nin', 'EOS', 'EOS'): 6,
#          ('EOS', 'və', 'n'): 6,
#          ('EOS', 'EOS', 'kitab'): 6,
#          ('bir', 'EOS', 'EOS'): 6,
#          ('ilə', 'və', 'EOS'): 6,
#          ('haqqında', 'EOS', 'EOS'): 6,
#          ('bu', 'EOS', 'EOS'): 6,
#          ('EOS', 'milli', 'EOS'): 6,
#          ('EOS', 'ya', 'EOS'): 6,
#          ('də', 'və', 'EOS'): 5,
#          ('ildə', 'EOS', 'və'): 5,
#          ('EOS', 'ndən', 'EOS'): 5,
#          ('və', 'ildən', 'EOS'): 5,
#          ('EOS', 'EOS', 'kimi'): 5,
#          ('t', 'EOS', 'EOS'): 5,
#          ('bu', 'və', 'EOS'): 5,
#          ('EOS', 'olduğu', 'EOS'): 5,
#          ('və', 'EOS', 'k'): 5,
#          ('ildə', 'və', 'EOS'): 5,
#          ('EOS', 'b', 'EOS'): 5,
#          ('EOS', 'k', 'və'): 5,
#          ('EOS', 'EOS', 'azərbaycan'): 5,
#          ('EOS', 'EOS', 'da'): 5,
#          ('olan', 'EOS', 'EOS'): 5,
#          ('k', 'EOS', 'və'): 5,
#          ('EOS', 'təşkil', 'EOS'): 5,
#          ('EOS', 'dövlət', 'EOS'): 5,
#          ('informasiya', 'EOS', 'EOS'): 5,
#          ('onun', 'EOS', 'EOS'): 5,
#          ('EOS', 'kitab', 'və'): 5,
#          ('EOS', 'EOS', 'fəaliyyət'): 5,
#          ('EOS', 'EOS', 'milli'): 5,
#          ('və', 'EOS', 'fadə'): 5,
#          ('bu', 'EOS', 'və'): 5,
#          ('ən', 'və', 'EOS'): 5,
#          ('da', 'EOS', 'EOS'): 5,
#          ('EOS', 'EOS', 'ya'): 5,
#          ('kitab', 'EOS', 'EOS'): 5,
#          ('də', 'EOS', 'EOS'): 5,
#          ('EOS', 'bir', 'və'): 5,
#          ('b', 'EOS', 'EOS'): 4,
#          ('fəaliyyət', 'EOS', 'və'): 4,
#          ('və', 'ilə', 'EOS'): 4,
#          ('digər', 'və', 'EOS'): 4,
#          ('EOS', 'olan', 'və'): 4,
#          ('kitabxana', 'və', 'EOS'): 4,
#          ('EOS', 'ist', 'və'): 4,
#          ('EOS', 'EOS', 'uzun'): 4,
#          ('dövlət', 'EOS', 'EOS'): 4,
#          ('və', 'və', 'ist'): 4,
#          ('EOS', 'EOS', 'dövlət'): 4,
#          ('milli', 'və', 'EOS'): 4,
#          ('k', 'EOS', 'ildən'): 4,
#          ('EOS', 'böyük', 'EOS'): 4,
#          ('f', 'EOS', 'EOS'): 4,
#          ('EOS', 'EOS', 'nəşr'): 4,
#          ('və', 'EOS', 'üçün'): 4,
#          ('və', 'görə', 'EOS'): 4,
#          ('ist', 'və', 'EOS'): 4,
#          ('EOS', 'və', 'illərdə'): 4,
#          ('EOS', 'həmin', 'EOS'): 4,
#          ('EOS', 'EOS', 'görə'): 4,
#          ('EOS', 'EOS', 'həmin'): 4,
#          ('k', 'və', 'EOS'): 4,
#          ('EOS', 'kitab', 'k'): 4,
#          ('EOS', 'EOS', 's'): 4,
#          ('informasiya', 'və', 'EOS'): 4,
#          ('və', 'və', 'bu'): 4,
#          ('EOS', 'bir', 'EOS'): 4,
#          ('EOS', 'və', 'dövlət'): 4,
#          ('EOS', 'ya', 'və'): 4,
#          ('və', 't', 'EOS'): 4,
#          ('EOS', 'da', 'EOS'): 4,
#          ('n', 'EOS', 'EOS'): 4,
#          ('EOS', 'mədəniyyət', 'və'): 4,
#          ('və', 'EOS', 'kitab'): 4,
#          ('EOS', 'azərbaycan', 'EOS'): 4,
#          ('EOS', 'EOS', 'üzrə'): 4,
#          ('EOS', 'və', 'ildə'): 4,
#          ('EOS', 'kitabxana', 'və'): 4,
#          ('kitabxana', 'və', 'və'): 4,
#          ('kitabxana', 'EOS', 'EOS'): 4,
#          ('olan', 'EOS', 'və'): 4,
#          ('daxil', 'EOS', 'EOS'): 4,
#          ('EOS', 'EOS', 'də'): 4,
#          ('EOS', 'edilmişdir', 'EOS'): 4,
#          ('yeni', 'EOS', 'EOS'): 4,
#          ('belə', 'EOS', 'və'): 4,
#          ('inkişaf', 'EOS', 'EOS'): 4,
#          ('kitabxanası', 'və', 'EOS'): 4,
#          ('azərbaycan', 'EOS', 'EOS'): 4,
#          ('EOS', 'və', 'ndə'): 4,
#          ('EOS', 'EOS', 'çox'): 4,
#          ('EOS', 'və', 'bu'): 4,
#          ('EOS', 'də', 'EOS'): 4,
#          ('EOS', 'EOS', 'əsasında'): 4,
#          ('və', 'bu', 'EOS'): 4,
#          ('ildə', 'EOS', 'bu'): 4,
#          ('və', 'kitabxana', 'EOS'): 4,
#          ('EOS', 'et', 'EOS'): 4,
#          ('bir', 'və', 'EOS'): 4,
#          ('q', 'EOS', 'EOS'): 4,
#          ('milli', 'EOS', 'EOS'): 4,
#          ('və', 'EOS', 'bir'): 3,
#          ('EOS', 'ni', 'EOS'): 3,
#          ('EOS', 'və', 'üçün'): 3,
#          ('və', 'və', 'bilər'): 3,
#          ('EOS', 'malik', 'EOS'): 3,
#          ('ilk', 'EOS', 'EOS'): 3,
#          ('EOS', 'digər', 'EOS'): 3,
#          ('k', 'k', 'EOS'): 3,
#          ('ən', 'EOS', 'və'): 3,
#          ('EOS', 'EOS', 'o'): 3,
#          ('və', 'EOS', 'ist'): 3,
#          ('EOS', 'eht', 'EOS'): 3,
#          ('EOS', 'kimi', 'EOS'): 3,
#          ('yerinə', 'EOS', 'EOS'): 3,
#          ('EOS', 'EOS', 'ndən'): 3,
#          ('və', 'EOS', 'olmuşdur'): 3,
#          ('milli', 'EOS', 'və'): 3,
#          ('EOS', 'olan', 'EOS'): 3,
#          ('EOS', 'edilməsi', 'və'): 3,
#          ('üzrə', 'EOS', 'və'): 3,
#          ('və', 'EOS', 'vəsait'): 3,
#          ('kimi', 'EOS', 'ist'): 3,
#          ('EOS', 'fadə', 'EOS'): 3,
#          ('EOS', 'EOS', 'məqsədi'): 3,
#          ('EOS', 'əsasında', 'EOS'): 3,
#          ('təşkili', 'EOS', 'EOS'): 3,
#          ('EOS', 't', 'EOS'): 3,
#          ('böyük', 'EOS', 'və'): 3,
#          ('görə', 'EOS', 'EOS'): 3,
#          ('təhsil', 'EOS', 'EOS'): 3,
#          ('kimi', 'EOS', 'EOS'): 3,
#          ('və', 'EOS', 'ki'): 3,
#          ('EOS', 'edilməsi', 'EOS'): 3,
#          ('və', 'olmuşdur', 'EOS'): 3,
#          ('EOS', 'və', 'sahəsində'): 3,
#          ('ədəbiyyatla', 'EOS', 'EOS'): 3,
#          ('və', 'illərdə', 'və'): 3,
#          ('EOS', 'EOS', 'müxtəlif'): 3,
#          ('və', 'EOS', 'dövri'): 3,
#          ('EOS', 'müəyyən', 'EOS'): 3,
#          ('EOS', 'EOS', 'yeni'): 3,
#          ('və', 'kitabxanası', 'EOS'): 3,
#          ('və', 'EOS', 'öz'): 3,
#          ('EOS', 'EOS', 'b'): 3,
#          ('n', 'və', 'EOS'): 3,
#          ('EOS', 'texniki', 'EOS'): 3,
#          ('həm', 'EOS', 'EOS'): 3,
#          ('edilir', 'EOS', 'EOS'): 3,
#          ('həmin', 'EOS', 'EOS'): 3,
#          ('EOS', 'EOS', 'mədəniyyət'): 3,
#          ('vəsait', 'EOS', 'EOS'): 3,
#          ('mühüm', 'EOS', 'EOS'): 3,
#          ('EOS', 'tərt', 'EOS'): 3,
#          ('EOS', 'EOS', 'kitabların'): 3,
#          ('kimi', 'EOS', 'və'): 3,
#          ('və', 'EOS', 'ümumi'): 3,
#          ('EOS', 'edilmiş', 'və'): 3,
#          ('EOS', 'EOS', 'iş'): 3,
#          ('EOS', 'və', 'burada'): 3,
#          ('EOS', 'ən', 'EOS'): 3,
#          ('və', 'daxil', 'EOS'): 3,
#          ('EOS', 'EOS', 'şəkildə'): 3,
#          ('işlər', 'EOS', 'EOS'): 3,
#          ('EOS', 'm', 'və'): 3,
#          ('EOS', 'EOS', 'üzərində'): 3,
#          ('və', 'k', 'EOS'): 3,
#          ('EOS', 'EOS', 'yanaşı'): 3,
#          ('EOS', 'nin', 'EOS'): 3,
#          ('və', 'EOS', 'etdirən'): 3,
#          ('üçün', 'EOS', 'EOS'): 3,
#          ('kitablar', 'EOS', 'EOS'): 3,
#          ('və', 'digər', 'EOS'): 3,
#          ('adlanır', 'EOS', 'EOS'): 3,
#          ('EOS', 'hissəsi', 'EOS'): 3,
#          ('və', 'üzrə', 'EOS'): 3,
#          ('EOS', 'məlumat', 'EOS'): 3,
#          ('EOS', 'il', 'EOS'): 3,
#          ('digər', 'EOS', 'EOS'): 3,
#          ('n', 'k', 'EOS'): 3,
#          ('edilmişdir', 'EOS', 'EOS'): 3,
#          ('EOS', 'üzrə', 'EOS'): 3,
#          ('növü', 'EOS', 'EOS'): 3,
#          ('bir', 'EOS', 'və'): 3,
#          ('EOS', 'və', 'k'): 3,
#          ('və', 'ildə', 'EOS'): 3,
#          ('ildən', 'EOS', 'EOS'): 3,
#          ('EOS', 'EOS', 'digər'): 3,
#          ('EOS', 'və', 'haqqında'): 3,
#          ('sonra', 'EOS', 'EOS'): 3,
#          ('və', 'və', 'respublika'): 3,
#          ('EOS', 'bütün', 'EOS'): 3,
#          ('və', 'fəaliyyət', 'EOS'): 3,
#          ('EOS', 'ilə', 'və'): 3,
#          ('elmi', 'EOS', 'EOS'): 3,
#          ('EOS', 'əsas', 'və'): 3,
#          ('ilə', 'k', 'və'): 3,
#          ('edir', 'EOS', 'və'): 3,
#          ('EOS', 'mədəniyyət', 'EOS'): 3,
#          ('EOS', 'm', 'EOS'): 3,
#          ('kitabı', 'EOS', 'EOS'): 3,
#          ('EOS', 'EOS', 'olan'): 3,
#          ('həmin', 'EOS', 'və'): 3,
#          ('EOS', 'EOS', 'həmçinin'): 3,
#          ('isə', 'və', 'EOS'): 3,
#          ('EOS', 'EOS', 'cümlədən'): 3,
#          ('yanın', 'EOS', 'EOS'): 3,
#          ('k', 'ya', 'EOS'): 3,
#          ('üçün', 'EOS', 'informasiya'): 3,
#          ('EOS', 'EOS', 'təşkil'): 3,
#          ('və', 'EOS', 'edilir'): 3,
#          ('EOS', 'və', 'bütün'): 3,
#          ('ist', 'EOS', 'və'): 3,
#          ('il', 'EOS', 'EOS'): 3,
#          ('ya', 'və', 'EOS'): 3,
#          ('üzrə', 'və', 'və'): 3,
#          ('və', 'olan', 'EOS'): 3,
#          ('işt', 'EOS', 'EOS'): 3,
#          ('və', 'EOS', 'kimi'): 3,
#          ('ildə', 'k', 'EOS'): 3,
#          ('EOS', 'EOS', 'təhsil'): 3,
#          ('EOS', 'k', 'informasiya'): 3,
#          ('EOS', 'elmi', 'EOS'): 3,
#          ('yeni', 'ilə', 'EOS'): 3,
#          ('kitabxana', 'ilə', 'EOS'): 3,
#          ('respublika', 'EOS', 'EOS'): 3,
#          ('informasiya', 'k', 'EOS'): 3,
#          ('EOS', 'və', 'kitab'): 3,
#          ('həyata', 'EOS', 'EOS'): 3,
#          ('olunan', 'və', 'və'): 3,
#          ('EOS', 'EOS', 'beynəlxalq'): 3,
#          ('EOS', 'kitabxanaçı', 'və'): 3,
#          ('EOS', 'EOS', 'uşaq'): 3,
#          ('əsasında', 'EOS', 'EOS'): 3,
#          ('və', 'EOS', 'daha'): 3,
#          ('çap', 'və', 'EOS'): 3,
#          ('təmin', 'EOS', 'EOS'): 3,
#          ('fondu', 'EOS', 'EOS'): 3,
#          ('və', 'ndən', 'EOS'): 3,
#          ('EOS', 'sahəsində', 'EOS'): 3,
#          ('əks', 'EOS', 'EOS'): 3,
#          ('EOS', 'sonra', 'EOS'): 3,
#          ('EOS', 'n', 'EOS'): 3,
#          ('EOS', 'və', 'azərbaycan'): 3,
#          ('görə', 'EOS', 'və'): 3,
#          ('EOS', 'EOS', 'illərdə'): 3,
#          ('EOS', 'ali', 'EOS'): 3,
#          ('edilmiş', 'EOS', 'EOS'): 3,
#          ('EOS', 'kitabxananın', 'və'): 3,
#          ('və', 'EOS', 'nin'): 3,
#          ('və', 'və', 'mədəniyyət'): 3,
#          ('EOS', 'rayon', 'EOS'): 3,
#          ('EOS', 'EOS', 'v'): 3,
#          ('üçün', 'və', 'EOS'): 3,
#          ('və', 'EOS', 'elmi'): 3,
#          ('məlumatların', 'EOS', 'EOS'): 3,
#          ('EOS', 'EOS', 'xarici'): 3,
#          ('EOS', 'uzun', 'və'): 3,
#          ('EOS', 'EOS', 'öz'): 3,
#          ('xidmət', 'və', 'EOS'): 3,
#          ('və', 'azərbaycan', 'EOS'): 3,
#          ('azərbaycanı', 'EOS', 'EOS'): 3,
#          ('ya', 'EOS', 'və'): 3,
#          ('nəşr', 'EOS', 'EOS'): 3,
#          ('k', 'b', 'EOS'): 2,
#          ('və', 'haqqında', 'uşaq'): 2,
#          ('EOS', 'EOS', 'adı'): 2,
#          ('EOS', 'şəhər', 'edilən'): 2,
#          ('yet', 'EOS', 'EOS'): 2,
#          ('EOS', 'və', 'resursların'): 2,
#          ('EOS', 'ilk', 'EOS'): 2,
#          ('EOS', 'etməkdən', 'EOS'): 2,
#          ('və', 'yenidən', 'və'): 2,
#          ('EOS', 'və', 'təsdiq'): 2,
#          ('çap', 'EOS', 'haqqında'): 2,
#          ('indiki', 'ildə', 'və'): 2,
#          ('nin', 'informasiya', 'və'): 2,
#          ('ədəbiyyat', 'ndən', 'EOS'): 2,
#          ('informasiya', 'və', 'n'): 2,
#          ('k', 'yası', 'EOS'): 2,
#          ('k', 'EOS', 'olunmağa'): 2,
#          ('və', 'belə', 'EOS'): 2,
#          ('EOS', 'illərdə', 'EOS'): 2,
#          ('s', 'və', 'əsas'): 2,
#          ('burada', 'EOS', 'EOS'): 2,
#          ('EOS', 'kitabxana', 'n'): 2,
#          ('n', 'dövlət', 'EOS'): 2,
#          ('ildə', 'EOS', 'çap'): 2,
#          ('EOS', 'olduğu', 'və'): 2,
#          ('EOS', 'fondu', 'kitabxana'): 2,
#          ('də', 'EOS', 'və'): 2,
#          ('EOS', 'və', 'kütləvi'): 2,
#          ('ildən', 'və', 'EOS'): 2,
#          ('kimi', 'EOS', 'kitabxana'): 2,
#          ('ist', 'EOS', 'EOS'): 2,
#          ('EOS', 'daxildir', 'EOS'): 2,
#          ('k', 'EOS', 'kitabxana'): 2,
#          ('və', 'uyğun', 'n'): 2,
#          ('bir', 'EOS', 'sənədin'): 2,
#          ('adı', 'EOS', 'EOS'): 2,
#          ('EOS', 'il', 'şəhər'): 2,
#          ('EOS', 'əlyazma', 'və'): 2,
#          ('informasiya', 'və', 'ilə'): 2,
#          ('ilə', 'olan', 'EOS'): 2,
#          ('EOS', 'və', 'ya'): 2,
#          ('EOS', 't', 'avtomatlaşdırılmış'): 2,
#          ('də', 'EOS', 'n'): 2,
#          ('ildə', 'və', 'b'): 2,
#          ('təşkilat', 'EOS', 'EOS'): 2,
#          ('EOS', 'xv', 'EOS'): 2,
#          ('EOS', 'milli', 'başlayaraq'): 2,
#          ('EOS', 'EOS', 'yası'): 2,
#          ('kimi', 'EOS', 'nəşr'): 2,
#          ('gəlib', 'və', 'verilir'): 2,
#          ('kitabxana', 'təsviri', 'və'): 2,
#          ('m', 'EOS', 'bu'): 2,
#          ('bir', 's', 'EOS'): 2,
#          ('olmuşdur', 'üzrə', 'EOS'): 2,
#          ('kitabxananın', 's', 'EOS'): 2,
#          ('ilə', 'və', 'mədəniyyət'): 2,
#          ('EOS', 'ist', 'onların'): 2,
#          ('EOS', 'informasiya', 'və'): 2,
#          ('və', 'dilində', 'EOS'): 2,
#          ('dilində', 'EOS', 'və'): 2,
#          ('v', 'və', 'EOS'): 2,
#          ('elektron', 'və', 'fəaliyyət'): 2,
#          ('olunmuşdur', 'ilə', 'ilə'): 2,
#          ('ilə', 'və', 'kitab'): 2,
#          ('əsasən', 'və', 'kitabxana'): 2,
#          ('EOS', 'dövlət', 'min'): 2,
#          ('və', 'fadə', 'EOS'): 2,
#          ('EOS', 'ya', 'fadə'): 2,
#          ('ümumi', 'EOS', 'EOS'): 2,
#          ('adına', 'EOS', 'EOS'): 2,
#          ('də', 'ilə', 'EOS'): 2,
#          ('EOS', 'və', 'müəllif'): 2,
#          ('və', 'müəllif', 'EOS'): 2,
#          ('bu', 'və', 'ilə'): 2,
#          ('EOS', 'edilən', 'EOS'): 2,
#          ('EOS', 'EOS', 'əlaqəyə'): 2,
#          ('əlyazma', 'EOS', 'EOS'): 2,
#          ('hər', 'EOS', 'EOS'): 2,
#          ('EOS', 'və', 'bir'): 2,
#          ('EOS', 'ibarət', 'və'): 2,
#          ('ilk', 'k', 'EOS'): 2,
#          ('ibarət', 'EOS', 'və'): 2,
#          ('EOS', 'az', 'EOS'): 2,
#          ('özündə', 'EOS', 'EOS'): 2,
#          ('EOS', 'və', 'qravür'): 2,
#          ('EOS', 'ilk', 'və'): 2,
#          ('k', 'n', 'olan'): 2,
#          ('yaradılmış', 'EOS', 'nın'): 2,
#          ('qaydada', 'EOS', 'EOS'): 2,
#          ('EOS', 'analit', 'informasiya'): 2,
#          ('s', 'və', 'EOS'): 2,
#          ('EOS', 'və', 'görə'): 2,
#          ('və', 'edir', 'azərbaycan'): 2,
#          ('və', 'ist', 'edir'): 2,
#          ('EOS', 'sonralar', 'EOS'): 2,
#          ('ndə', 'EOS', 'EOS'): 2,
#          ('idarə', 'EOS', 'EOS'): 2,
#          ('və', 'və', 'nin'): 2,
#          ('mədəniyyət', 'və', 'və'): 2,
#          ('və', 'və', 'əsərlərinin'): 2,
#          ('və', 'onun', 'EOS'): 2,
#          ('ildən', 'EOS', 'və'): 2,
#          ('audiovizual', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'edilməsi'): 2,
#          ('k', 'fəaliyyət', 'EOS'): 2,
#          ('olan', 'min', 'və'): 2,
#          ('kitabxana', 'olan', 'EOS'): 2,
#          ('bu', 'yaradılması', 'EOS'): 2,
#          ('k', 'EOS', 'v'): 2,
#          ('üçün', 'EOS', 'də'): 2,
#          ('maşınla', 'EOS', 'EOS'): 2,
#          ('çox', 'və', 'EOS'): 2,
#          ('və', 'EOS', 'da'): 2,
#          ('ibarətdir', 'və', 'EOS'): 2,
#          ('və', 'EOS', 'müstəqil'): 2,
#          ('biliklərin', 'EOS', 'EOS'): 2,
#          ('EOS', 'maddi', 'EOS'): 2,
#          ('mərkəzi', 'və', 'EOS'): 2,
#          ('EOS', 'fəaliyyət', 'və'): 2,
#          ('və', 'əsərləri', 'və'): 2,
#          ('EOS', 'EOS', 'yaradılmış'): 2,
#          ('klaviatura', 'EOS', 'EOS'): 2,
#          ('EOS', 'və', 'dair'): 2,
#          ('dövri', 'EOS', 'EOS'): 2,
#          ('EOS', 'şəxsi', 'EOS'): 2,
#          ('və', 'ki', 'EOS'): 2,
#          ('mindən', 'EOS', 'EOS'): 2,
#          ('rilməsi', 'və', 'EOS'): 2,
#          ('EOS', 'tədqiq', 'EOS'): 2,
#          ('EOS', 'bu', 'və'): 2,
#          ('və', 'ilə', 'kitabxanasından'): 2,
#          ('uşaq', 'EOS', 'EOS'): 2,
#          ('dissertasiyalar', 'EOS', 'EOS'): 2,
#          ('kitab', 'ist', 'EOS'): 2,
#          ('EOS', 'olunur', 'və'): 2,
#          ('və', 'EOS', 'i'): 2,
#          ('və', 'olar', 'EOS'): 2,
#          ('ki', 'EOS', 'EOS'): 2,
#          ('EOS', 'yeni', 'EOS'): 2,
#          ('ndən', 'milli', 'və'): 2,
#          ('və', 'əks', 'EOS'): 2,
#          ('EOS', 'ildə', 'və'): 2,
#          ('lazımdır', 'EOS', 'EOS'): 2,
#          ('kitabxanaları', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'tədris'): 2,
#          ('akademik', 'EOS', 'EOS'): 2,
#          ('EOS', 'və', 'daha'): 2,
#          ('və', 'nəzərdə', 'n'): 2,
#          ('EOS', 'EOS', 'adlı'): 2,
#          ('EOS', 'EOS', 'vəsaitlər'): 2,
#          ('və', 'və', 'informasiya'): 2,
#          ('və', 'informasiya', 'ilə'): 2,
#          ('EOS', 'EOS', 'xüsusi'): 2,
#          ('EOS', 'haqqında', 'və'): 2,
#          ('kitabxana', 'qeyd', 'EOS'): 2,
#          ('və', 'EOS', 'adına'): 2,
#          ('EOS', 'dissertasiya', 'EOS'): 2,
#          ('davam', 'EOS', 'k'): 2,
#          ('k', 'və', 'mürəkkəb'): 2,
#          ('EOS', 'informasiyanın', 'EOS'): 2,
#          ('EOS', 'ərzində', 'EOS'): 2,
#          ('EOS', 'mədəniyyət', 'kimi'): 2,
#          ('olmuşdur', 'ilə', 'EOS'): 2,
#          ('və', 'EOS', 'yeni'): 2,
#          ('kitabxana', 'EOS', 'n'): 2,
#          ('EOS', 'ilə', 'bir'): 2,
#          ('informasiyanın', 'və', 'və'): 2,
#          ('EOS', 'və', 'da'): 2,
#          ('və', 'EOS', 'müdiri'): 2,
#          ('EOS', 'EOS', 'mütaliə'): 2,
#          ('EOS', 'illərdə', 'milli'): 2,
#          ('EOS', 'EOS', 'q'): 2,
#          ('EOS', 'EOS', 'ə'): 2,
#          ('ilə', 'EOS', 'olunmuşdur'): 2,
#          ('EOS', 'azərbaycan', 'o'): 2,
#          ('xidmət', 'EOS', 'və'): 2,
#          ('lazımdır', 'EOS', 'haqqında'): 2,
#          ('EOS', 'və', 'xarici'): 2,
#          ('kimi', 'fadə', 'EOS'): 2,
#          ('nin', 'milli', 'EOS'): 2,
#          ('EOS', 'ya', 'na'): 2,
#          ('çap', 'EOS', 'EOS'): 2,
#          ('EOS', 'elektron', 'EOS'): 2,
#          ('k', 'EOS', 'bağlı'): 2,
#          ('və', 'ndə', 'və'): 2,
#          ('və', 'EOS', 'ədəbiyyat'): 2,
#          ('yası', 'EOS', 'EOS'): 2,
#          ('və', 'burada', 'və'): 2,
#          ('EOS', 'bütün', 'bir'): 2,
#          ('üzrə', 'son', 'EOS'): 2,
#          ('yası', 'EOS', 'kitabxana'): 2,
#          ('EOS', 'n', 'azərbaycan'): 2,
#          ('EOS', 'EOS', 'kitabxanaçılıq'): 2,
#          ('EOS', 'EOS', 'tərtər'): 2,
#          ('mk', 'EOS', 'və'): 2,
#          ('EOS', 'və', 'daxil'): 2,
#          ('olan', 'və', 'EOS'): 2,
#          ('xüsusi', 'EOS', 'EOS'): 2,
#          ('EOS', 'min', 'EOS'): 2,
#          ('isə', 'EOS', 'və'): 2,
#          ('EOS', 'və', 'çox'): 2,
#          ('EOS', 'EOS', 'malik'): 2,
#          ('və', 'bilər', 'və'): 2,
#          ('texniki', 'və', 'EOS'): 2,
#          ('EOS', 'obyekt', 'bir'): 2,
#          ('və', 'və', 'is'): 2,
#          ('EOS', 'vəzifələri', 't'): 2,
#          ('EOS', 'EOS', 'ali'): 2,
#          ('k', 'ildə', 'ilə'): 2,
#          ('sənədlər', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'etməyə'): 2,
#          ('EOS', 'sadi', 'EOS'): 2,
#          ('mərkəzi', 'EOS', 'ilə'): 2,
#          ('EOS', 'ərəb', 'EOS'): 2,
#          ('k', 'kitabxana', 'və'): 2,
#          ('olunur', 'nin', 'və'): 2,
#          ('EOS', 'EOS', 'olunmuş'): 2,
#          ('EOS', 'ildə', 'ümumi'): 2,
#          ('v', 'olaraq', 'EOS'): 2,
#          ('olaraq', 'EOS', 'EOS'): 2,
#          ('əsasında', 'ya', 'ilə'): 2,
#          ('EOS', 'EOS', 'sənədin'): 2,
#          ('EOS', 'və', 'axtarışın'): 2,
#          ('nəzərdə', 'EOS', 'EOS'): 2,
#          ('təhlil', 'EOS', 'EOS'): 2,
#          ('şəkildə', 'üzrə', 'EOS'): 2,
#          ('tərt', 'və', 'başqa'): 2,
#          ('EOS', 'n', 'bir'): 2,
#          ('bütün', 'və', 'EOS'): 2,
#          ('və', 'üçün', 'kitabxana'): 2,
#          ('EOS', 'idi', 'və'): 2,
#          ('sənədlərin', 'kitabxana', 'EOS'): 2,
#          ('EOS', 't', 'informasiya'): 2,
#          ('EOS', 'olmuş', 'və'): 2,
#          ('və', 'indiki', 'EOS'): 2,
#          ('EOS', 'və', 'azərbaycanda'): 2,
#          ('yasının', 'və', 'EOS'): 2,
#          ('EOS', 'və', 'ölkədə'): 2,
#          ('EOS', 't', 'nin'): 2,
#          ('əsrin', 'EOS', 'və'): 2,
#          ('EOS', 'bir', 'ildə'): 2,
#          ('ist', 'EOS', 'bu'): 2,
#          ('EOS', 'və', 't'): 2,
#          ('eht', 'və', 'EOS'): 2,
#          ('və', 'EOS', 'tərt'): 2,
#          ('ndən', 'və', 'və'): 2,
#          ('bu', 'EOS', 'jurnal'): 2,
#          ('ildə', 'EOS', 'k'): 2,
#          ('illərdə', 'EOS', 'EOS'): 2,
#          ('bütün', 'EOS', 'EOS'): 2,
#          ('k', 'EOS', 'informasiya'): 2,
#          ('və', 'ilə', 'ist'): 2,
#          ('bir', 'kitabxana', 'EOS'): 2,
#          ('və', 'yeni', 'EOS'): 2,
#          ('bütün', 'EOS', 'və'): 2,
#          ('edərək', 'EOS', 'və'): 2,
#          ('əsərləri', 'və', 'üzrə'): 2,
#          ('EOS', 'asılı', 'edərək'): 2,
#          ('EOS', 'EOS', 'asılı'): 2,
#          ('və', 'öz', 'EOS'): 2,
#          ('yüksək', 'və', 'və'): 2,
#          ('EOS', 'EOS', 'olmuşdur'): 2,
#          ('EOS', 'üçün', 'ya'): 2,
#          ('EOS', 'və', 'analit'): 2,
#          ('EOS', 'öyrənilməsi', 'milli'): 2,
#          ('s', 'və', 'ilə'): 2,
#          ('sahəvi', 'EOS', 'EOS'): 2,
#          ('ki', 'kitab', 'və'): 2,
#          ('EOS', 'EOS', 'dünyanın'): 2,
#          ('kütləvi', 'EOS', 'EOS'): 2,
#          ('kollekt', 'EOS', 'və'): 2,
#          ('məqsədilə', 'EOS', 'EOS'): 2,
#          ('konkret', 'EOS', 'EOS'): 2,
#          ('ya', 'üzrə', 'EOS'): 2,
#          ('dair', 'EOS', 'və'): 2,
#          ('EOS', 'və', 'ölkələri'): 2,
#          ('EOS', 'EOS', 'yerinə'): 2,
#          ('ist', 'yaradılmışdır', 'EOS'): 2,
#          ('müxtəlif', 'olan', 'EOS'): 2,
#          ('EOS', 'nəşri', 'bir'): 2,
#          ('nəşri', 'bir', 'EOS'): 2,
#          ('k', 'ilə', 'EOS'): 2,
#          ('ildə', 'ya', 'EOS'): 2,
#          ('olunmuş', 'təcrübi', 'EOS'): 2,
#          ('EOS', 'EOS', 'gələcək'): 2,
#          ('a', 'EOS', 'və'): 2,
#          ('və', 'EOS', 'bütün'): 2,
#          ('mk', 'EOS', 'EOS'): 2,
#          ('və', 'EOS', 'stat'): 2,
#          ('xidmət', 'ya', 'EOS'): 2,
#          ('və', 'EOS', 'olan'): 2,
#          ('EOS', 'və', 'əməkdaşlıq'): 2,
#          ('əsrin', 'və', 'kitab'): 2,
#          ('EOS', 'edir', 'EOS'): 2,
#          ('EOS', 'və', 'q'): 2,
#          ('EOS', 'k', 'olan'): 2,
#          ('və', 'qeyd', 'bib'): 2,
#          ('min', 'EOS', 'EOS'): 2,
#          ('çap', 'uşaq', 'EOS'): 2,
#          ('eləcə', 'və', 'EOS'): 2,
#          ('nin', 'bu', 'EOS'): 2,
#          ('üçün', 'ya', 'respublikasının'): 2,
#          ('EOS', 'haqqında', 'EOS'): 2,
#          ('EOS', 'EOS', 'keçirilir'): 2,
#          ('k', 'yet', 'isə'): 2,
#          ('EOS', 'azərbaycanda', 'EOS'): 2,
#          ('k', 'EOS', 'həm'): 2,
#          ('bakı', 'EOS', 'EOS'): 2,
#          ('inkişaf', 'EOS', 'və'): 2,
#          ('EOS', 'həmin', 'və'): 2,
#          ('s', 'kitabxana', 'EOS'): 2,
#          ('çox', 'EOS', 'əlavə'): 2,
#          ('t', 'nin', 'EOS'): 2,
#          ('azərbaycan', 'EOS', 'və'): 2,
#          ('və', 'ilk', 'EOS'): 2,
#          ('EOS', 'aid', 'üzrə'): 2,
#          ('EOS', 'çox', 'EOS'): 2,
#          ('EOS', 'EOS', 'təsvir'): 2,
#          ('EOS', 'həyata', 'mədəniyyət'): 2,
#          ('maarifpərvər', 'EOS', 'EOS'): 2,
#          ('EOS', 'respublika', 'təşkil'): 2,
#          ('və', 'azərbaycanda', 'EOS'): 2,
#          ('və', 'tərkibinə', 'müxtəlif'): 2,
#          ('və', 'ist', 'və'): 2,
#          ('EOS', 'əsas', 'EOS'): 2,
#          ('EOS', 'k', 'illərdə'): 2,
#          ('EOS', 'kitabxananın', 'EOS'): 2,
#          ('na', 'bu', 'kimi'): 2,
#          ('müəyyən', 'EOS', 'EOS'): 2,
#          ('EOS', 'v', 'ölkələrin'): 2,
#          ('uzun', 'EOS', 'EOS'): 2,
#          ('EOS', 'bu', 'milli'): 2,
#          ('EOS', 'EOS', 'sahəsində'): 2,
#          ('alim', 'EOS', 'və'): 2,
#          ('k', 'EOS', 'üçün'): 2,
#          ('EOS', 'dünya', 'ilə'): 2,
#          ('və', 'bir', 'EOS'): 2,
#          ('tərt', 'və', 'EOS'): 2,
#          ('EOS', 'informasiya', 'ist'): 2,
#          ('k', 'a', 'EOS'): 2,
#          ('kitabxanalar', 'EOS', 'və'): 2,
#          ('və', 'kitabxana', 'və'): 2,
#          ('ildə', 'EOS', 'kitabxananın'): 2,
#          ('EOS', 'EOS', 'mərkəzi'): 2,
#          ('üçün', 'ki', 'EOS'): 2,
#          ('kitab', 'EOS', 'ildən'): 2,
#          ('EOS', 'və', 'na'): 2,
#          ('dövlət', 'EOS', 'və'): 2,
#          ('EOS', 'belə', 'nin'): 2,
#          ('EOS', 'ilə', 'olaraq'): 2,
#          ('ildən', 'və', 'və'): 2,
#          ('və', 'və', 'üzrə'): 2,
#          ('EOS', 'nüsxə', 'ki'): 2,
#          ('EOS', 'qanuna', 'və'): 2,
#          ('EOS', 'p', 'EOS'): 2,
#          ('da', 'fəaliyyət', 'EOS'): 2,
#          ('sənədlərin', 'EOS', 'k'): 2,
#          ('yazının', 'dövlət', 'EOS'): 2,
#          ('üçün', 'bir', 'EOS'): 2,
#          ('EOS', 'bu', 'elmi'): 2,
#          ('və', 'EOS', 'olduğu'): 2,
#          ('EOS', 'təcrübəsi', 'EOS'): 2,
#          ('EOS', 'EOS', 'ni'): 2,
#          ('EOS', 'və', 'də'): 2,
#          ('EOS', 'bir', 'ist'): 2,
#          ('həmin', 'informasiya', 'EOS'): 2,
#          ('EOS', 'EOS', 'mai'): 2,
#          ('tədris', 'EOS', 'və'): 2,
#          ('və', 'EOS', 'dövlət'): 2,
#          ('bir', 'metodik', 'milli'): 2,
#          ('və', 'universitet', 'dair'): 2,
#          ('göstəricinin', 'bir', 'EOS'): 2,
#          ('EOS', 'aid', 'EOS'): 2,
#          ('isə', 'EOS', 'EOS'): 2,
#          ('daxili', 'və', 'n'): 2,
#          ('üçün', 'EOS', 'ilə'): 2,
#          ('müəyyən', 'EOS', 'və'): 2,
#          ('EOS', 'və', 'bazalarının'): 2,
#          ('və', 'n', 'informasiya'): 2,
#          ('işinin', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'məlumat'): 2,
#          ('keçirilir', 'EOS', 'EOS'): 2,
#          ('elmi', 'n', 'EOS'): 2,
#          ('EOS', 'EOS', 'əhatə'): 2,
#          ('EOS', 'ilə', 'çap'): 2,
#          ('ki', 'b', 'EOS'): 2,
#          ('s', 'EOS', 'EOS'): 2,
#          ('üçün', 'EOS', 'bu'): 2,
#          ('adda', 'EOS', 'və'): 2,
#          ('EOS', 'və', 'fondunun'): 2,
#          ('EOS', 'və', 'yaradılmış'): 2,
#          ('EOS', 'fondu', 'çox'): 2,
#          ('EOS', 'mövzu', 'və'): 2,
#          ('EOS', 'adına', 'EOS'): 2,
#          ('k', 'EOS', 'ildə'): 2,
#          ('bütün', 'EOS', 'e'): 2,
#          ('kitab', 'bir', 'EOS'): 2,
#          ('hökmdarı', 'EOS', 'EOS'): 2,
#          ('və', 'EOS', 'yunesko'): 2,
#          ('və', 'ist', 'EOS'): 2,
#          ('lövhə', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'verilənlər'): 2,
#          ('EOS', 'və', 'hər'): 2,
#          ('tərt', 'EOS', 'və'): 2,
#          ('və', 'də', 'EOS'): 2,
#          ('ya', 'EOS', 'k'): 2,
#          ('göstəricilər', 'EOS', 'EOS'): 2,
#          ('EOS', 'və', 'göstərir'): 2,
#          ('adına', 'n', 'EOS'): 2,
#          ('EOS', 'sıra', 'EOS'): 2,
#          ('malikdir', 'EOS', 'da'): 2,
#          ('EOS', 'cəmiyyət', 'informasiya'): 2,
#          ('əsr', 'EOS', 'EOS'): 2,
#          ('kitabxanalarının', 'və', 'EOS'): 2,
#          ('EOS', 'təşkil', 'edilmişdir'): 2,
#          ('ki', 'ndən', 'EOS'): 2,
#          ('daxil', 'və', 'EOS'): 2,
#          ('EOS', 'üçün', 'və'): 2,
#          ('EOS', 'kənd', 'bir'): 2,
#          ('materialların', 'EOS', 'EOS'): 2,
#          ('yanaşı', 'EOS', 'EOS'): 2,
#          ('EOS', 'alimi', 'EOS'): 2,
#          ('ya', 'kitab', 'n'): 2,
#          ('EOS', 'beynəlxalq', 'EOS'): 2,
#          ('EOS', 'bir', 'idi'): 2,
#          ('EOS', 'kitab', 'görə'): 2,
#          ('EOS', 'EOS', 'dövri'): 2,
#          ('bütün', 'EOS', 'kitabxana'): 2,
#          ('elmləri', 'EOS', 'EOS'): 2,
#          ('imkan', 'bütün', 'EOS'): 2,
#          ('EOS', 'və', 'yaradılması'): 2,
#          ('EOS', 'çap', 'EOS'): 2,
#          ('EOS', 'EOS', 'komitəsinin'): 2,
#          ('kitabxana', 'EOS', 'kitab'): 2,
#          ('EOS', 'jurnalı', 'EOS'): 2,
#          ('EOS', 'son', 'EOS'): 2,
#          ('infor', 'EOS', 'EOS'): 2,
#          ('EOS', 'etdirən', 'EOS'): 2,
#          ('k', 'EOS', 'adına'): 2,
#          ('EOS', 'milli', 'münasibət'): 2,
#          ('EOS', 'və', 'məcburi'): 2,
#          ('kitab', 'prezident', 'EOS'): 2,
#          ('EOS', 'kitab', 'ildə'): 2,
#          ('EOS', 'bakı', 'EOS'): 2,
#          ('beynəlxalq', 'etmişdir', 'EOS'): 2,
#          ('prosesi', 'EOS', 'və'): 2,
#          ('EOS', 'və', 'qısa'): 2,
#          ('ildə', 'və', 'görə'): 2,
#          ('dünyanın', 'EOS', 'EOS'): 2,
#          ('EOS', 'həyata', 'EOS'): 2,
#          ('və', 'EOS', 'q'): 2,
#          ('tərt', 'və', 'k'): 2,
#          ('EOS', 'EOS', 'olaraq'): 2,
#          ('nət', 'EOS', 'və'): 2,
#          ('k', 'EOS', 'jurnal'): 2,
#          ('EOS', 'kitab', 'nail'): 2,
#          ('ildə', 't', 'EOS'): 2,
#          ('yası', 'və', 'EOS'): 2,
#          ('son', 'və', 'EOS'): 2,
#          ('həm', 'və', 'və'): 2,
#          ('EOS', 'nın', 'EOS'): 2,
#          ('kitabxanaşünaslıq', 'EOS', 'EOS'): 2,
#          ('nəşrlərinin', 'EOS', 'EOS'): 2,
#          ('bütün', 'EOS', 'bu'): 2,
#          ('EOS', 'EOS', 'tutan'): 2,
#          ('fadə', 'EOS', 'EOS'): 2,
#          ('EOS', 'və', 'bunlar'): 2,
#          ('EOS', 'olunmuşdur', 'EOS'): 2,
#          ('kafedrasının', 'k', 'EOS'): 2,
#          ('və', 'üçün', 'və'): 2,
#          ('ildə', 'o', 'EOS'): 2,
#          ('EOS', 'əsasında', 'kitabxana'): 2,
#          ('EOS', 'də', 'da'): 2,
#          ('EOS', 'olunan', 'EOS'): 2,
#          ('onun', 'edən', 'və'): 2,
#          ('EOS', 'nəşr', 'yaradılmışdır'): 2,
#          ('EOS', 'elektron', 'və'): 2,
#          ('EOS', 'və', 'metodik'): 2,
#          ('nəşrin', 'EOS', 'EOS'): 2,
#          ('EOS', 'azərbaycan', 'və'): 2,
#          ('və', 'EOS', 'mədəni'): 2,
#          ('library', 'EOS', 'EOS'): 2,
#          ('çap', 'EOS', 'k'): 2,
#          ('k', 'təyin', 'EOS'): 2,
#          ('EOS', 'ya', 'əlavə'): 2,
#          ('EOS', 'illərdə', 'və'): 2,
#          ('EOS', 'EOS', 'kütləvi'): 2,
#          ('və', 'ildə', 'işlənməsi'): 2,
#          ('və', 'ndən', 'və'): 2,
#          ('ist', 'EOS', 'ali'): 2,
#          ('və', 'yasının', 'və'): 2,
#          ('k', 'EOS', 'k'): 2,
#          ('EOS', 'zaman', 'EOS'): 2,
#          ('və', 'elmi', 'EOS'): 2,
#          ('idi', 'və', 'fərdi'): 2,
#          ('və', 'edilir', 'və'): 2,
#          ('EOS', 'əsas', 'təhsil'): 2,
#          ('EOS', 'də', 'və'): 2,
#          ('EOS', 'sonra', 'rus'): 2,
#          ('EOS', 'a', 'ölkəşünaslıq'): 2,
#          ('EOS', 'a', 'EOS'): 2,
#          ('və', 'ilə', 'ilə'): 2,
#          ('üzrə', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'p'): 2,
#          ('və', 'EOS', 'yolu'): 2,
#          ('ilə', 'EOS', 'bu'): 2,
#          ('digər', 'EOS', 'və'): 2,
#          ('EOS', 'EOS', 'daha'): 2,
#          ('nin', 'və', 'EOS'): 2,
#          ('EOS', 'və', 'kitabxanalarının'): 2,
#          ('azərbaycan', 'və', 'kimi'): 2,
#          ('k', 'EOS', 'oxucuların'): 2,
#          ('məsələn', 'EOS', 'və'): 2,
#          ('və', 'k', 'yaradılmış'): 2,
#          ('həyata', 'və', 'EOS'): 2,
#          ('EOS', 'ilə', 'dəfə'): 2,
#          ('EOS', 'EOS', 'verilir'): 2,
#          ('dəqiq', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'bütün'): 2,
#          ('EOS', 'EOS', 'proqram'): 2,
#          ('EOS', 'ildə', 'illərdə'): 2,
#          ('işçi', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'təşkilatlar'): 2,
#          ('kitabşünaslıq', 'EOS', 'EOS'): 2,
#          ('ildə', 'EOS', 'olunan'): 2,
#          ('və', 'EOS', 'mühüm'): 2,
#          ('və', 'da', 'EOS'): 2,
#          ('ya', 'EOS', 'informasiya'): 2,
#          ('EOS', 'informasiya', 'üçün'): 2,
#          ('informasiyanı', 'EOS', 'EOS'): 2,
#          ('fəaliyyət', 'EOS', 'EOS'): 2,
#          ('EOS', 'biridir', 'EOS'): 2,
#          ('EOS', 'EOS', 'anadan'): 2,
#          ('kitabxanaları', 'ə', 'EOS'): 2,
#          ('EOS', 'EOS', 'dəfə'): 2,
#          ('EOS', 'm', 'daxil'): 2,
#          ('EOS', 'EOS', 'əsrin'): 2,
#          ('və', 'EOS', 'b'): 2,
#          ('EOS', 'internet', 'EOS'): 2,
#          ('adı', 'əsasında', 'ildə'): 2,
#          ('kitab', 'və', 'EOS'): 2,
#          ('sıra', 'var', 'EOS'): 2,
#          ('EOS', 'edir', 'nin'): 2,
#          ('EOS', 'və', 'ist'): 2,
#          ('və', 'ist', 'də'): 2,
#          ('kataloq', 'EOS', 'EOS'): 2,
#          ('olan', 'azərbaycan', 'ilə'): 2,
#          ('EOS', 'və', 'ədəbiyyat'): 2,
#          ('və', 'ildə', 'çapdan'): 2,
#          ('hansı', 'və', 'və'): 2,
#          ('və', 'azərbaycan', 'edilən'): 2,
#          ('EOS', 'EOS', 'sənəd'): 2,
#          ('EOS', 'sənəd', 'k'): 2,
#          ('EOS', 'EOS', 'fondu'): 2,
#          ('EOS', 'nəzərdə', 'EOS'): 2,
#          ('EOS', 'EOS', 'zaman'): 2,
#          ('onun', 'çap', 'EOS'): 2,
#          ('EOS', 'EOS', 'keçirilən'): 2,
#          ('ildə', 'üzrə', 'və'): 2,
#          ('əsas', 'və', 'n'): 2,
#          ('sənədlərin', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'onlara'): 2,
#          ('azərbaycan', 'bir', 'EOS'): 2,
#          ('ilə', 'edir', 'EOS'): 2,
#          ('zamanda', 'EOS', 'EOS'): 2,
#          ('EOS', 'və', 'yeni'): 2,
#          ('EOS', 'EOS', 'kitabxanası'): 2,
#          ('və', 'EOS', 'yazılmış'): 2,
#          ('EOS', 'üzrə', 'bütün'): 2,
#          ('EOS', 'cəmiyyət', 'EOS'): 2,
#          ('təşkil', 'və', 'il'): 2,
#          ('EOS', 'EOS', 'işinin'): 2,
#          ('və', 'EOS', 'ilk'): 2,
#          ('fadə', 'EOS', 'bu'): 2,
#          ('EOS', 'EOS', 'kitabı'): 2,
#          ('üzrə', 'ilə', 'EOS'): 2,
#          ('EOS', 'və', 'ndən'): 2,
#          ('EOS', 'olaraq', 'n'): 2,
#          ('asılı', 'EOS', 'dövlət'): 2,
#          ('tarixi', 'EOS', 'və'): 2,
#          ('EOS', 'xüsusi', 'EOS'): 2,
#          ('və', 's', 'EOS'): 2,
#          ('və', 'EOS', 'respublika'): 2,
#          ('arasında', 'EOS', 'EOS'): 2,
#          ('EOS', 'keçmiş', 'EOS'): 2,
#          ('və', 'və', 'tərt'): 2,
#          ('EOS', 'informasiya', 'k'): 2,
#          ('referat', 'EOS', 'EOS'): 2,
#          ('və', 'n', 'EOS'): 2,
#          ('olmuşdur', 'EOS', 'ya'): 2,
#          ('EOS', 'rusiya', 'bu'): 2,
#          ('EOS', 'nət', 'EOS'): 2,
#          ('və', 'nəzərdə', 'EOS'): 2,
#          ('və', 'EOS', 'üzrə'): 2,
#          ('EOS', 'və', 'xarakterli'): 2,
#          ('EOS', 'EOS', 'doktoru'): 2,
#          ('EOS', 'EOS', 'işt'): 2,
#          ('EOS', 'kitabxanalar', 'EOS'): 2,
#          ('və', 'EOS', 'bi'): 2,
#          ('də', 'EOS', 'fəaliyyət'): 2,
#          ('k', 'respublikası', 'və'): 2,
#          ('azərbaycan', 'və', 'və'): 2,
#          ('EOS', 'EOS', 'çap'): 2,
#          ('fadə', 'EOS', 'azərbaycan'): 2,
#          ('EOS', 'kitabxanası', 'azərbaycan'): 2,
#          ('EOS', 'küçəsində', 'EOS'): 2,
#          ('EOS', 'əmək', 'ilə'): 2,
#          ('EOS', 'bax', 'və'): 2,
#          ('edir', 'növlərindən', 'EOS'): 2,
#          ('EOS', 'k', 'ildən'): 2,
#          ('və', 'EOS', 's'): 2,
#          ('EOS', 'EOS', 'kitabxanasının'): 2,
#          ('nə', 'ildə', 'EOS'): 2,
#          ('k', 'və', 'k'): 2,
#          ('məzmunu', 'EOS', 'də'): 2,
#          ('EOS', 'bürosu', 'EOS'): 2,
#          ('ən', 'EOS', 'EOS'): 2,
#          ('bir', 'EOS', 'tərt'): 2,
#          ('informasiya', 'EOS', 'ildə'): 2,
#          ('ildə', 'EOS', 'respublika'): 2,
#          ('və', 'və', 'ilə'): 2,
#          ('EOS', 'EOS', 'respublikanın'): 2,
#          ('və', 'və', 'növüdür'): 2,
#          ('öz', 'EOS', 'EOS'): 2,
#          ('və', 'üçün', 'f'): 2,
#          ('EOS', 'zamanı', 'EOS'): 2,
#          ('EOS', 'EOS', 'rəhbər'): 2,
#          ('nin', 'əsas', 'göstəricisi'): 2,
#          ('EOS', 'bir', 'kitabxana'): 2,
#          ('ya', 'k', 'və'): 2,
#          ('haqqında', 'EOS', 'informasiya'): 2,
#          ('və', 'inkişaf', 'EOS'): 2,
#          ('kimi', 'nəşr', 'EOS'): 2,
#          ('də', 'EOS', 'k'): 2,
#          ('məsələn', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'fadə'): 2,
#          ('kitabxana', 'bu', 'böyük'): 2,
#          ('və', 'və', 'bir'): 2,
#          ('EOS', 'kitabxanalar', 'na'): 2,
#          ('EOS', 'beynəlxalq', 'universitet'): 2,
#          ('EOS', 'mü', 'və'): 2,
#          ('EOS', 'k', 'türk'): 2,
#          ('EOS', 'EOS', 'pli'): 2,
#          ('fadə', 'üzrə', 'və'): 2,
#          ('EOS', 'və', 'əsrin'): 2,
#          ('kitabxana', 'k', 'və'): 2,
#          ('EOS', 'q', 'ilə'): 2,
#          ('EOS', 'EOS', 'oxucu'): 2,
#          ('EOS', 'zaman', 'və'): 2,
#          ('EOS', 'xarici', 'k'): 2,
#          ('EOS', 'EOS', 'nət'): 2,
#          ('EOS', 'və', 'a'): 2,
#          ('EOS', 'əsərlər', 'olan'): 2,
#          ('EOS', 'n', 'şəhərində'): 2,
#          ('üçün', 'bu', 'EOS'): 2,
#          ('ilə', 'EOS', 'ildən'): 2,
#          ('EOS', 'ə', 'və'): 2,
#          ('onların', 'və', 'EOS'): 2,
#          ('EOS', 'üzrə', 'n'): 2,
#          ('ilə', 'də', 'dövlət'): 2,
#          ('rus', 'və', 'qeyd'): 2,
#          ('çox', 'EOS', 'EOS'): 2,
#          ('də', 'EOS', 'edilir'): 2,
#          ('hələ', 'EOS', 'EOS'): 2,
#          ('EOS', 'ndə', 'EOS'): 2,
#          ('və', 'edilməsi', 'EOS'): 2,
#          ('dünya', 'EOS', 'EOS'): 2,
#          ('EOS', 'biri', 'EOS'): 2,
#          ('EOS', 'EOS', 'yaradılması'): 2,
#          ('q', 'EOS', 'və'): 2,
#          ('EOS', 'EOS', 'universitet'): 2,
#          ('EOS', 's', 'EOS'): 2,
#          ('EOS', 'EOS', 'növləri'): 2,
#          ('EOS', 'onun', 'və'): 2,
#          ('ilə', 'edilir', 'və'): 2,
#          ('tə', 'EOS', 'EOS'): 2,
#          ('EOS', 'olaraq', 'olar'): 2,
#          ('mədəni', 'EOS', 'EOS'): 2,
#          ('adlı', 'EOS', 'ildən'): 2,
#          ('EOS', 'k', 'kimi'): 2,
#          ('daha', 'və', 'və'): 2,
#          ('şərh', 'EOS', 'bu'): 2,
#          ('EOS', 'də', 'kimi'): 2,
#          ('universal', 'EOS', 'və'): 2,
#          ('EOS', 'bu', 'ist'): 2,
#          ('kitabxana', 'və', 'ilə'): 2,
#          ('ümumi', 'EOS', 'və'): 2,
#          ...})

# %%
unigram_probs
# Out:
# {('yolu',): 0.0002655840953067496,
#  ('digər',): 0.0016314451568843192,
#  ('təbiət',): 0.00017886275806372934,
#  ('göstərici',): 0.0004878075219919891,
#  ('ilə',): 0.0069431270630193114,
#  ('təsvirlərin',): 9.214142082070906e-05,
#  ('strukturlarının',): 1.6260250733066305e-05,
#  ('fərqli',): 0.0001680225909083518,
#  ('EOS',): 0.07433644626800145,
#  ('sözlərə',): 1.6260250733066305e-05,
#  ('etmək',): 0.001051496214071621,
#  ('işi',): 0.0009864552111393558,
#  ('sıra',): 0.000607049360701142,
#  ('dədəm',): 1.6260250733066305e-05,
#  ('ziyali',): 1.0840167155377537e-05,
#  ('ümumi',): 0.0012195188049799728,
#  ('də',): 0.0038482593401590252,
#  ('dövlət',): 0.002975625884151134,
#  ('və',): 0.03262348305410869,
#  ('hissəsi',): 0.0004010861847489688,
#  ('ştat',): 2.710041788844384e-05,
#  ('əlyazma',): 0.00036856568328283624,
#  ('müəllif',): 0.0003577255161274587,
#  ('otaqda',): 3.252050146613261e-05,
#  ('yazılı',): 0.00017344267448604058,
#  ('konkret',): 0.00027642426246212717,
#  ('bütün',): 0.0017344267448604058,
#  ('oxucuların',): 0.0004390267697927902,
#  ('nəşr',): 0.0020650518430994206,
#  ('çox',): 0.0018265681656811149,
#  ('göstərir',): 0.0007208711158326062,
#  ('misirin',): 4.3360668621510146e-05,
#  ('peşəkar',): 0.00012466192228684166,
#  ('kitabələr',): 5.420083577688768e-05,
#  ('əlyazmalar',): 0.00017344267448604058,
#  ('əsərləri',): 0.0005853690263903869,
#  ('müəssisələri',): 0.0001680225909083518,
#  ('k',): 0.008937717819608778,
#  ('b',): 0.0021626133474978186,
#  ('rak',): 0.0003577255161274587,
#  ('azərbaycanda',): 0.0009376744589401568,
#  ('medalı',): 5.962091935457645e-05,
#  ('con',): 3.252050146613261e-05,
#  ('qəbulu',): 4.3360668621510146e-05,
#  ('ildə',): 0.006796784806421715,
#  ('yaradır',): 0.00019512300879679566,
#  ('yə',): 5.962091935457645e-05,
#  ('universitet',): 0.0009918752947170445,
#  ('kolleci',): 4.8780752199198914e-05,
#  ('seriyası',): 0.0001192418387091529,
#  ('məlumatlar',): 0.0003252050146613261,
#  ('mövzuda',): 4.3360668621510146e-05,
#  ('adına',): 0.0012737196407568605,
#  ('lıca',): 1.0840167155377537e-05,
#  ('maiyyət',): 7.046108650995399e-05,
#  ('zəsi',): 0.00018428284164141812,
#  ('fərqlər',): 3.252050146613261e-05,
#  ('prosesində',): 0.0002384836774183058,
#  ('şah',): 0.00012466192228684166,
#  ('fondu',): 0.0009756150439839782,
#  ('məcmuəsini',): 1.6260250733066305e-05,
#  ('olan',): 0.003436332988254679,
#  ('üzüdür',): 1.0840167155377537e-05,
#  ('yazılma',): 4.3360668621510146e-05,
#  ('kitabxanada',): 0.0004878075219919891,
#  ('idarə',): 0.0004173464354820351,
#  ('disküzərində',): 1.0840167155377537e-05,
#  ('yaxın',): 0.0003360451818167036,
#  ('meyillərdən',): 1.6260250733066305e-05,
#  ('ilk',): 0.0018265681656811149,
#  ('mümkün',): 0.00018970292521910688,
#  ('indiki',): 0.0006666702800557185,
#  ('tələb',): 0.0002493238445736833,
#  ('informasiya',): 0.003989181513178933,
#  ('götürür',): 2.1680334310755073e-05,
#  ('işt',): 0.0006449899457449634,
#  ('qəbul',): 0.0006558301129003409,
#  ('azərbaycanı',): 7.588117008764276e-05,
#  ('olmuşdur',): 0.0015880844882628091,
#  ('predmet',): 0.0002493238445736833,
#  ('sənədin',): 0.0007046108650995398,
#  ('tədqiqatçıların',): 2.1680334310755073e-05,
#  ('təsnifata',): 1.6260250733066305e-05,
#  ('əvvəllər',): 0.0001517623401752855,
#  ('edilir',): 0.0017886275806372933,
#  ('çap',): 0.0033550317345893473,
#  ('verilən',): 0.0002872644296175047,
#  ('birinin',): 6.504100293226522e-05,
#  ('nin',): 0.003105707890015664,
#  ('mətn',): 0.0002872644296175047,
#  ('olmuş',): 0.0004281866026374127,
#  ('yanların',): 1.0840167155377537e-05,
#  ('aiddir',): 0.0002384836774183058,
#  ('moskva',): 0.00018970292521910688,
#  ('gəcəvi',): 1.0840167155377537e-05,
#  ('kitabxanası',): 0.002075892010254798,
#  ('memarlıq',): 7.046108650995399e-05,
#  ('əsasən',): 0.0007208711158326062,
#  ('onların',): 0.001002715461872422,
#  ('olaraq',): 0.0016422853240396966,
#  ('kitabxananın',): 0.0018265681656811149,
#  ('nan',): 4.8780752199198914e-05,
#  ('bu',): 0.006563721212581098,
#  ('dəqiqliyinə',): 2.1680334310755073e-05,
#  ('idi',): 0.0008888937067409579,
#  ('dövründə',): 0.0003306250982390148,
#  ('divan',): 2.1680334310755073e-05,
#  ('haqqında',): 0.002758822541043583,
#  ('milli',): 0.0031490685586371744,
#  ('müəyyən',): 0.0011165372170038861,
#  ('şuraya',): 1.6260250733066305e-05,
#  ('hüquqşünasların',): 1.0840167155377537e-05,
#  ('böyük',): 0.0018753489178803136,
#  ('ist',): 0.004216825023441862,
#  ('gures',): 1.0840167155377537e-05,
#  ('hissədən',): 8.672133724302029e-05,
#  ('çoxlu',): 8.130125366533152e-05,
#  ('nu',): 2.710041788844384e-05,
#  ('quldarın',): 1.0840167155377537e-05,
#  ('mədəniyyət',): 0.001962070255123334,
#  ('məlumat',): 0.001474262733131345,
#  ('vasitəsi',): 0.0004065062683266576,
#  ('əldə',): 0.0004932276055696779,
#  ('mə',): 0.000303524680350571,
#  ('formaca',): 1.0840167155377537e-05,
#  ('rakçısı',): 4.3360668621510146e-05,
#  ('illik',): 0.00029268451319519346,
#  ('yaradılmış',): 0.0004281866026374127,
#  ('işçilərinin',): 0.00021680334310755073,
#  ('üçün',): 0.004482409118748611,
#  ('köməyi',): 8.672133724302029e-05,
#  ('ya',): 0.004813034216987626,
#  ('şəkildə',): 0.0007262911994102949,
#  ('sahə',): 0.0001355020894422192,
#  ('kitabxa',): 0.00012466192228684166,
#  ('nüfuzlu',): 5.420083577688768e-05,
#  ('obyekt',): 0.00027642426246212717,
#  ('olunmuşdur',): 0.0008780535395855804,
#  ('nə',): 0.0010948568826931312,
#  ('xidmət',): 0.0016477054076173856,
#  ('uşaq',): 0.0006829305307887848,
#  ('fəaliyyət',): 0.0027046217052666952,
#  ('dövrün',): 0.00017886275806372934,
#  ('sərvətlərin',): 1.6260250733066305e-05,
#  ('rə',): 0.00010840167155377537,
#  ('təsvir',): 0.0004119263519043464,
#  ('e',): 0.0005528485249242543,
#  ('kri',): 4.3360668621510146e-05,
#  ('şöbəsi',): 0.000303524680350571,
#  ('konversiyaya',): 1.0840167155377537e-05,
#  ('doğru',): 3.252050146613261e-05,
#  ('kataloqlaşdırılmasına',): 1.0840167155377537e-05,
#  ('daşıya',): 1.0840167155377537e-05,
#  ('sadi',): 0.00036314559970514746,
#  ('söhbət',): 3.252050146613261e-05,
#  ('əsərində',): 0.00014092217301990797,
#  ('görə',): 0.001517623401752855,
#  ('müxtəlif',): 0.0013929614794660134,
#  ('etməyə',): 0.0003523054325497699,
#  ('çoxcildli',): 2.710041788844384e-05,
#  ('yet',): 0.0007479715337210499,
#  ('jurnal',): 0.0006016292771234532,
#  ('ndən',): 0.002124672762453997,
#  ('adlı',): 0.0011382175513146413,
#  ('təbliği',): 9.214142082070906e-05,
#  ('iki',): 0.0007588117008764275,
#  ('səmərəliliyini',): 4.3360668621510146e-05,
#  ('a',): 0.0013658610615775695,
#  ('qablaşdırma',): 1.0840167155377537e-05,
#  ('ixt',): 0.0007967522859202489,
#  ('nəzdində',): 0.0003414652653943924,
#  ('əlaqədar',): 0.0005474284413465656,
#  ('fərqlidir',): 1.0840167155377537e-05,
#  ('bundan',): 0.0001680225909083518,
#  ('təbii',): 0.00013008200586453044,
#  ('təbliğ',): 8.672133724302029e-05,
#  ('təcrübəni',): 2.1680334310755073e-05,
#  ('əsrə',): 9.756150439839783e-05,
#  ('ka',): 0.0003414652653943924,
#  ('tutulmuş',): 0.00015718242375297427,
#  ('azərbaycan',): 0.004428208282971724,
#  ('informasia',): 1.0840167155377537e-05,
#  ('kollekt',): 0.00022764351026292827,
#  ('onal',): 0.00017886275806372934,
#  ('avqust',): 0.0001029815879760866,
#  ('vəsait',): 0.0009105740410517131,
#  ('adları',): 0.00014634225659759673,
#  ('kökləri',): 1.6260250733066305e-05,
#  ('azər',): 0.00010840167155377537,
#  ('formalaşması',): 0.00010840167155377537,
#  ('arayışı',): 1.6260250733066305e-05,
#  ('xarakterikdir',): 2.1680334310755073e-05,
#  ('edilməsi',): 0.001121957300581575,
#  ('məqsədi',): 0.00044444685337047897,
#  ('nöqtələri',): 1.0840167155377537e-05,
#  ('həqiqi',): 8.130125366533152e-05,
#  ('yeniliklər',): 2.1680334310755073e-05,
#  ('edilmiş',): 0.0012899798914899267,
#  ('kitabları',): 0.00031436484750594853,
#  ('n',): 0.004563710372413943,
#  ('seçilməsi',): 0.00013008200586453044,
#  ('ediən',): 1.0840167155377537e-05,
#  ('nəzarət',): 0.0001517623401752855,
#  ('şəhərində',): 0.0005799489428126982,
#  ('təchiz',): 0.00014092217301990797,
#  ('kimi',): 0.002802183209665093,
#  ('p',): 0.00048238743841430033,
#  ('materiallar',): 0.00031436484750594853,
#  ('adı',): 0.0007100309486772286,
#  ('taxta',): 3.794058504382138e-05,
#  ('nləşdirir',): 1.0840167155377537e-05,
#  ('gəlməsi',): 0.0001517623401752855,
#  ('kitab',): 0.00422224510701955,
#  ('windows',): 1.6260250733066305e-05,
#  ('yazılır',): 9.756150439839783e-05,
#  ('kursu',): 2.710041788844384e-05,
#  ('verilir',): 0.0006612501964780296,
#  ('çm',): 5.420083577688768e-05,
#  ('v',): 0.0019512300879679565,
#  ('edilən',): 0.0009105740410517131,
#  ('dəyişikliklər',): 7.588117008764276e-05,
#  ('qiymətləndirir',): 2.710041788844384e-05,
#  ('verilənlərdən',): 2.710041788844384e-05,
#  ('vardır',): 0.0005311681906134992,
#  ('virləri',): 1.0840167155377537e-05,
#  ('kilsəsinin',): 4.8780752199198914e-05,
#  ('losofu',): 3.794058504382138e-05,
#  ('daşımışdır',): 1.6260250733066305e-05,
#  ('ərzində',): 0.00046070710410354526,
#  ('gün',): 0.00012466192228684166,
#  ('nüsxədən',): 0.0003360451818167036,
#  ('il',): 0.0017344267448604058,
#  ('yardım',): 0.00010840167155377537,
#  ('bir',): 0.0046450116260792745,
#  ('kildiyini',): 1.0840167155377537e-05,
#  ('t',): 0.0026124802844459862,
#  ('nəşirlər',): 1.0840167155377537e-05,
#  ('şəhər',): 0.0006504100293226522,
#  ('imkanlarına',): 2.1680334310755073e-05,
#  ('olur',): 0.0006829305307887848,
#  ('əksini',): 0.00022764351026292827,
#  ('görülmüşdür',): 0.00023306359384061702,
#  ('verilirdi',): 8.672133724302029e-05,
#  ('arasında',): 0.0005311681906134992,
#  ('proquest',): 2.710041788844384e-05,
#  ('f',): 0.0010298158797608658,
#  ('həbs',): 2.1680334310755073e-05,
#  ('məhv',): 0.0001192418387091529,
#  ('s',): 0.0025149187800475883,
#  ('source',): 1.6260250733066305e-05,
#  ('elm',): 0.0006016292771234532,
#  ('illərdə',): 0.0020975723445655534,
#  ('liyyətə',): 1.0840167155377537e-05,
#  ('marağının',): 1.0840167155377537e-05,
#  ('dövr',): 0.00011382175513146413,
#  ('yazılırdısa',): 1.0840167155377537e-05,
#  ('bazası',): 0.00022222342668523949,
#  ('mənbələr',): 0.0001355020894422192,
#  ('fakül',): 2.1680334310755073e-05,
#  ('ifadə',): 0.0002493238445736833,
#  ('işinin',): 0.0008943137903186467,
#  ('formanın',): 2.1680334310755073e-05,
#  ('kitabı',): 0.00046070710410354526,
#  ('xüsusi',): 0.0012574593900237941,
#  ('tika',): 1.0840167155377537e-05,
#  ('xəzinəmizin',): 1.0840167155377537e-05,
#  ('həmin',): 0.0013604409779998808,
#  ('aparılırdı',): 3.252050146613261e-05,
#  ('vəsaitlərini',): 2.710041788844384e-05,
#  ('daxildir',): 0.0005420083577688768,
#  ('bunlarla',): 2.710041788844384e-05,
#  ('fərdi',): 0.0002493238445736833,
#  ('olunmasının',): 5.962091935457645e-05,
#  ('gəldiyi',): 1.6260250733066305e-05,
#  ('dövrdə',): 0.0004932276055696779,
#  ('illərin',): 0.0002547439281513721,
#  ('rayon',): 0.0008075924530756264,
#  ('bakı',): 0.0009485146260955344,
#  ('nəşrlərinin',): 0.00017344267448604058,
#  ('üzü',): 0.0001029815879760866,
#  ('keçirilməsinə',): 7.046108650995399e-05,
#  ('verirdi',): 4.8780752199198914e-05,
#  ('i',): 0.0008888937067409579,
#  ('beynəlxalq',): 0.001701906243394273,
#  ('fəal',): 0.0002059631759521732,
#  ('ümumalman',): 1.6260250733066305e-05,
#  ('mln',): 0.00022764351026292827,
#  ('axun',): 3.252050146613261e-05,
#  ('təcrübi',): 0.0001355020894422192,
#  ('bilər',): 0.0008292727873863815,
#  ('misal',): 0.0001517623401752855,
#  ('halda',): 0.0002005430923744844,
#  ('yaşünaslığa',): 1.6260250733066305e-05,
#  ('resursların',): 5.962091935457645e-05,
#  ('göstəriciləri',): 0.00016260250733066305,
#  ('sayı',): 0.0005094878563027442,
#  ('dırma',): 1.6260250733066305e-05,
#  ('ni',): 0.0009756150439839782,
#  ('informasiyanın',): 0.001008135545450111,
#  ('kitabxana',): 0.005924151350413824,
#  ('resursları',): 0.00016260250733066305,
#  ('buraxdığı',): 3.794058504382138e-05,
#  ('formalı',): 5.962091935457645e-05,
#  ('göstəricinin',): 0.00016260250733066305,
#  ('şısına',): 1.0840167155377537e-05,
#  ('mənt',): 0.00014092217301990797,
#  ('yeni',): 0.0016368652404620079,
#  ('tanınmış',): 9.214142082070906e-05,
#  ('kömüründən',): 1.0840167155377537e-05,
#  ('asiya',): 7.046108650995399e-05,
#  ('reallaşdırılması',): 2.710041788844384e-05,
#  ('menecment',): 9.214142082070906e-05,
#  ('ödəmək',): 5.420083577688768e-05,
#  ('bunlara',): 9.214142082070906e-05,
#  ('ekt',): 3.794058504382138e-05,
#  ('məcmusu',): 0.0001029815879760866,
#  ('dəniyyətlərin',): 1.0840167155377537e-05,
#  ('akademiyası',): 8.130125366533152e-05,
#  ('olmayan',): 0.0001355020894422192,
#  ('inst',): 0.00018970292521910688,
#  ('çevrilir',): 8.130125366533152e-05,
#  ('əsas',): 0.0016802259090835181,
#  ('sahəsini',): 3.252050146613261e-05,
#  ('hazırlanmış',): 0.0001355020894422192,
#  ('birgə',): 0.00017886275806372934,
#  ('mahnı',): 1.0840167155377537e-05,
#  ('olmalıdır',): 8.130125366533152e-05,
#  ('məkanından',): 1.0840167155377537e-05,
#  ('bilən',): 0.00012466192228684166,
#  ('keçilmişlərin',): 1.0840167155377537e-05,
#  ('dərc',): 0.0005040677727250555,
#  ('təşkilat',): 0.0002547439281513721,
#  ('həddən',): 1.0840167155377537e-05,
#  ('nın',): 0.0014092217301990796,
#  ('axtarış',): 0.00046612718768123404,
#  ('sistemi',): 0.0005528485249242543,
#  ('həsr',): 0.00034688534897208117,
#  ('ildən',): 0.0027913430425097153,
#  ('kitabxanalar',): 0.0007371313665656725,
#  ('tamamilə',): 8.130125366533152e-05,
#  ('sistemin',): 0.0001355020894422192,
#  ('nəşrlərin',): 0.0005636886920796319,
#  ('olar',): 0.0004173464354820351,
#  ('elektron',): 0.0014363221480875234,
#  ('fondunu',): 9.214142082070906e-05,
#  ('olunur',): 0.0013008200586453044,
#  ('ra',): 0.0002059631759521732,
#  ('yüksək',): 0.0004281866026374127,
#  ('dekabr',): 8.130125366533152e-05,
#  ('formalaşdırılır',): 4.3360668621510146e-05,
#  ('db',): 4.3360668621510146e-05,
#  ('fadəçilər',): 8.672133724302029e-05,
#  ('səviyyəsinə',): 9.214142082070906e-05,
#  ('tədris',): 0.0004010861847489688,
#  ('sahəvi',): 0.0002872644296175047,
#  ('çalışmışdır',): 0.00023306359384061702,
#  ('turizm',): 0.0002005430923744844,
#  ('açıldı',): 6.504100293226522e-05,
#  ('işlədilirdi',): 2.710041788844384e-05,
#  ('toplu',): 0.00022222342668523949,
#  ('başqaları',): 9.756150439839783e-05,
#  ('birləşmiş',): 9.214142082070906e-05,
#  ('hammurapi',): 6.504100293226522e-05,
#  ('ali',): 0.0005474284413465656,
#  ('sənədləri',): 0.00024390376099599456,
#  ('mövzu',): 0.0004065062683266576,
#  ('nda',): 0.0008997338738963355,
#  ('alqoritmik',): 1.0840167155377537e-05,
#  ('təbliğində',): 4.8780752199198914e-05,
#  ('dində',): 1.6260250733066305e-05,
#  ('idrak',): 1.6260250733066305e-05,
#  ('əhatə',): 0.0007425514501433612,
#  ('edir',): 0.0022981154369400374,
#  ('yaddaş',): 9.214142082070906e-05,
#  ('saxlayır',): 8.672133724302029e-05,
#  ('ədəbiyyatşünaslıq',): 8.130125366533152e-05,
#  ('fadə',): 0.0022276543504300837,
#  ('təhsil',): 0.0010623363812269984,
#  ('eht',): 0.0003902460175935913,
#  ('kitabçılıq',): 5.420083577688768e-05,
#  ('tələbləri',): 3.794058504382138e-05,
#  ('mövzusunu',): 2.1680334310755073e-05,
#  ('yaratmış',): 5.420083577688768e-05,
#  ('standartları',): 4.8780752199198914e-05,
#  ('xarakterli',): 0.0004227665190597239,
#  ('rus',): 0.0007696518680318051,
#  ('əsəri',): 0.00037398576686052497,
#  ('biblioqrafik',): 0.00024390376099599456,
#  ('formalaşmasına',): 4.3360668621510146e-05,
#  ('direktoru',): 0.0002384836774183058,
#  ('tərkib',): 0.0002493238445736833,
#  ('resursu',): 2.1680334310755073e-05,
#  ('nəzərdə',): 0.0007100309486772286,
#  ('xusu',): 1.0840167155377537e-05,
#  ('dilindədir',): 2.710041788844384e-05,
#  ('yyət',): 0.00017886275806372934,
#  ('xarakterist',): 9.214142082070906e-05,
#  ('üzvləri',): 5.962091935457645e-05,
#  ('sonralar',): 0.0002384836774183058,
#  ('tərt',): 0.0017344267448604058,
#  ('tərcümədə',): 3.252050146613261e-05,
#  ('mixi',): 0.00015718242375297427,
#  ('səsyazma',): 2.1680334310755073e-05,
#  ('xeroneili',): 1.0840167155377537e-05,
#  ('müstəqil',): 0.00043360668621510146,
#  ('buraxılması',): 2.710041788844384e-05,
#  ('edilmişdir',): 0.0011978384706692177,
#  ('isə',): 0.002222234266852395,
#  ('həm',): 0.0012195188049799728,
#  ('ayında',): 0.0001680225909083518,
#  ('georq',): 1.6260250733066305e-05,
#  ('şərh',): 0.0001355020894422192,
#  ('zəngin',): 0.00044444685337047897,
#  ('birləşdirilməsi',): 4.3360668621510146e-05,
#  ('qəzet',): 0.0004769673548366116,
#  ('əziyyət',): 1.0840167155377537e-05,
#  ('hı',): 1.0840167155377537e-05,
#  ('amea',): 0.0001192418387091529,
#  ('səviyyəli',): 7.588117008764276e-05,
#  ('verilmişdir',): 0.0004878075219919891,
#  ('istehsalı',): 8.130125366533152e-05,
#  ('mb',): 2.710041788844384e-05,
#  ('alban',): 0.00031436484750594853,
#  ('şəklində',): 0.0003523054325497699,
#  ('kitabın',): 0.00043360668621510146,
#  ('göstəricilərin',): 0.00014634225659759673,
#  ('olması',): 0.00017886275806372934,
#  ('işində',): 0.00018970292521910688,
#  ('oxucu',): 0.00045528702052585653,
#  ('ndə',): 0.0007750719516094938,
#  ('təmin',): 0.0008672133724302029,
#  ('insan',): 0.0001029815879760866,
#  ('kint',): 9.214142082070906e-05,
#  ('kilib',): 2.710041788844384e-05,
#  ('əsasında',): 0.0009918752947170445,
#  ('başlamış',): 0.00018428284164141812,
#  ('yazılmış',): 0.0002601640117290609,
#  ('müşahidə',): 2.1680334310755073e-05,
#  ('avtomatlaşdırılmış',): 0.00043360668621510146,
#  ('mət',): 0.00011382175513146413,
#  ('izahına',): 1.0840167155377537e-05,
#  ('ki',): 0.0022818551862069715,
#  ('fransisk',): 1.0840167155377537e-05,
#  ('direktor',): 0.0001192418387091529,
#  ('vermişdir',): 0.00013008200586453044,
#  ('variantda',): 2.1680334310755073e-05,
#  ('verilənlər',): 0.00037940585043821375,
#  ('məqsədli',): 4.3360668621510146e-05,
#  ('min',): 0.0014580024823982786,
#  ('tətbiq',): 0.0006504100293226522,
#  ('koopersiya',): 1.0840167155377537e-05,
#  ('münasibət',): 0.0001192418387091529,
#  ('ratmağa',): 1.0840167155377537e-05,
#  ('respublikasının',): 0.00043360668621510146,
#  ('hansı',): 0.00038482593401590253,
#  ('yerləşdirilir',): 8.130125366533152e-05,
#  ('pay',): 1.6260250733066305e-05,
#  ('konqres',): 0.0001029815879760866,
#  ('pilləli',): 1.0840167155377537e-05,
#  ('bolqarıstan',): 2.710041788844384e-05,
#  ('rajını',): 1.6260250733066305e-05,
#  ('masiya',): 7.588117008764276e-05,
#  ('əvvəl',): 0.00029268451319519346,
#  ('vəzifə',): 8.130125366533152e-05,
#  ('qruplaşdırılır',): 3.252050146613261e-05,
#  ('xix',): 0.0003197849310836373,
#  ('tövrat',): 1.0840167155377537e-05,
#  ('standart',): 0.00021138325952986195,
#  ('sürət',): 4.3360668621510146e-05,
#  ('navigator',): 1.0840167155377537e-05,
#  ('mühasibat',): 2.1680334310755073e-05,
#  ('yazılması',): 0.00019512300879679566,
#  ('edib',): 9.756150439839783e-05,
#  ('qiymətli',): 0.0004065062683266576,
#  ('qovuşaraq',): 1.0840167155377537e-05,
#  ('bədii',): 0.0003252050146613261,
#  ('proqram',): 0.0003523054325497699,
#  ('töv',): 3.252050146613261e-05,
#  ('yaradılmasında',): 6.504100293226522e-05,
#  ('üsulu',): 0.00011382175513146413,
#  ('növləri',): 0.0003306250982390148,
#  ('izah',): 9.214142082070906e-05,
#  ('əməkdə',): 1.0840167155377537e-05,
#  ('əsasındakı',): 1.0840167155377537e-05,
#  ('stat',): 0.00024390376099599456,
#  ('assosiasiyası',): 8.672133724302029e-05,
#  ('təsisçisi',): 3.794058504382138e-05,
#  ('şairi',): 4.8780752199198914e-05,
#  ('metodiki',): 0.0002384836774183058,
#  ('kafedrası',): 2.710041788844384e-05,
#  ('formasına',): 5.420083577688768e-05,
#  ('yaşünaslığın',): 3.252050146613261e-05,
#  ('ona',): 0.00028184434603981595,
#  ('lərin',): 9.756150439839783e-05,
#  ('komplektləşdirmə',): 9.756150439839783e-05,
#  ('oluna',): 5.962091935457645e-05,
#  ('sonra',): 0.0009539347096732232,
#  ('sosial',): 0.00021680334310755073,
#  ('kitabxanaların',): 0.0006720903636334072,
#  ('ən',): 0.0012791397243345493,
#  ('yaradılmışdır',): 0.0006341497785895859,
#  ('oğlu',): 0.0003577255161274587,
#  ('semant',): 7.588117008764276e-05,
#  ('onun',): 0.001940389920812579,
#  ('özündə',): 0.0004227665190597239,
#  ('daxil',): 0.0011869983035138402,
#  ('rayonunda',): 0.0001517623401752855,
#  ('vəsaitlərdə',): 5.420083577688768e-05,
#  ('öz',): 0.0015501439032189876,
#  ('təşkilatların',): 8.672133724302029e-05,
#  ('kommentariyaları',): 1.0840167155377537e-05,
#  ('əvvəlcə',): 7.588117008764276e-05,
#  ('mk',): 0.0004715472712589228,
#  ('ili',): 5.962091935457645e-05,
#  ('iiliyini',): 1.0840167155377537e-05,
#  ('qaydalar',): 7.588117008764276e-05,
#  ('tendensiyalarını',): 1.0840167155377537e-05,
#  ('alınmışdı',): 2.710041788844384e-05,
#  ('mənəvi',): 9.756150439839783e-05,
#  ('laborant',): 7.588117008764276e-05,
#  ('əlyetərlik',): 7.588117008764276e-05,
#  ('yaradılması',): 0.0007208711158326062,
#  ('nümunələrlə',): 1.0840167155377537e-05,
#  ('avesta',): 0.0001680225909083518,
#  ('o',): 0.0016748058255058294,
#  ('dəyərində',): 1.0840167155377537e-05,
#  ('verir',): 0.00044986693694816775,
#  ('bəy',): 0.0001517623401752855,
#  ('pro',): 6.504100293226522e-05,
#  ('malik',): 0.0005040677727250555,
#  ('skini',): 1.0840167155377537e-05,
#  ('növü',): 0.00037940585043821375,
#  ('olurdu',): 3.252050146613261e-05,
#  ('şərqdə',): 7.588117008764276e-05,
#  ('becərilməsi',): 1.0840167155377537e-05,
#  ('kasiyası',): 2.1680334310755073e-05,
#  ('ın',): 4.3360668621510146e-05,
#  ('incəsənət',): 0.00037398576686052497,
#  ('üzrə',): 0.003067767304971843,
#  ('lir',): 2.1680334310755073e-05,
#  ('r',): 0.00043360668621510146,
#  ('sistemli',): 0.00029268451319519346,
#  ('der',): 2.710041788844384e-05,
#  ('hamı',): 6.504100293226522e-05,
#  ('dair',): 0.0009593547932509119,
#  ('yerləşən',): 0.0002384836774183058,
#  ('fon',): 5.962091935457645e-05,
#  ('tabxana',): 8.130125366533152e-05,
#  ('şöbənin',): 8.672133724302029e-05,
#  ('tarixli',): 0.0003306250982390148,
#  ('q',): 0.001566404153952054,
#  ('səyləri',): 1.0840167155377537e-05,
#  ('əmrinə',): 4.3360668621510146e-05,
#  ('göstərişləri',): 1.6260250733066305e-05,
#  ('rəf',): 1.6260250733066305e-05,
#  ('ləşdirmə',): 2.710041788844384e-05,
#  ('yayımı',): 2.710041788844384e-05,
#  ('nəşri',): 0.0004390267697927902,
#  ('etməkdən',): 8.130125366533152e-05,
#  ('prob',): 2.710041788844384e-05,
#  ('səviyyəsinin',): 4.8780752199198914e-05,
#  ('cədvəlləri',): 0.0001355020894422192,
#  ('quruluşuna',): 2.710041788844384e-05,
#  ('hündür',): 7.046108650995399e-05,
#  ('göstərən',): 0.00034688534897208117,
#  ('qədər',): 0.0008997338738963355,
#  ('yuxarı',): 4.8780752199198914e-05,
#  ('di',): 4.3360668621510146e-05,
#  ('daş',): 8.672133724302029e-05,
#  ('xəsi',): 1.0840167155377537e-05,
#  ('metal',): 7.046108650995399e-05,
#  ('bah',): 1.6260250733066305e-05,
#  ('kitabxanaşünaslıq',): 0.00046612718768123404,
#  ('ümumiyyətlə',): 7.588117008764276e-05,
#  ('nümunələri',): 9.214142082070906e-05,
#  ('fərmanlara',): 1.0840167155377537e-05,
#  ('adlandırılmağa',): 1.6260250733066305e-05,
#  ('diametri',): 5.420083577688768e-05,
#  ('beylin',): 1.0840167155377537e-05,
#  ('universal',): 0.0004769673548366116,
#  ('xdr',): 1.0840167155377537e-05,
#  ('kiyədə',): 1.0840167155377537e-05,
#  ('the',): 0.0001029815879760866,
#  ('prosesidir',): 9.756150439839783e-05,
#  ('nəzərdən',): 0.0001680225909083518,
#  ('yoluna',): 1.0840167155377537e-05,
#  ('baş',): 0.0008997338738963355,
#  ('olmuşdu',): 4.8780752199198914e-05,
#  ('göstəricisi',): 0.00037940585043821375,
#  ('ümumiləşdirilməsi',): 3.252050146613261e-05,
#  ('akademiyasının',): 0.00021680334310755073,
#  ('nail',): 8.130125366533152e-05,
#  ('həmçinin',): 0.00039566610117128004,
#  ('qoymuşdur',): 6.504100293226522e-05,
#  ('da',): 0.0023089556040954153,
#  ('yası',): 0.0008617932888525141,
#  ('aparılmasına',): 3.252050146613261e-05,
#  ('krincə',): 2.710041788844384e-05,
#  ('na',): 0.0007262911994102949,
#  ('edilmişdi',): 0.0001355020894422192,
#  ('pli',): 0.00036856568328283624,
#  ('yazıların',): 0.0003360451818167036,
#  ('birləşməsi',): 4.3360668621510146e-05,
#  ('ingilis',): 0.0002493238445736833,
#  ('planına',): 2.710041788844384e-05,
#  ('word',): 1.0840167155377537e-05,
#  ('növbədə',): 0.00012466192228684166,
#  ('qayda',): 0.0001680225909083518,
#  ('yaradıcılığında',): 2.1680334310755073e-05,
#  ('yaddaşının',): 1.6260250733066305e-05,
#  ('məktubları',): 2.1680334310755073e-05,
#  ('yaxşılaşdıraq',): 1.0840167155377537e-05,
#  ('işlədilən',): 7.046108650995399e-05,
#  ('şimali',): 5.420083577688768e-05,
#  ('boyaqları',): 1.6260250733066305e-05,
#  ('nazirliyi',): 0.0001680225909083518,
#  ('dərəcədə',): 0.00017344267448604058,
#  ('formatları',): 3.794058504382138e-05,
#  ('əsərlərinin',): 0.00031436484750594853,
#  ('təxəyyülünün',): 1.0840167155377537e-05,
#  ('fəlsəfə',): 0.00030894476392825975,
#  ('əhməd',): 7.046108650995399e-05,
#  ('ideyası',): 5.420083577688768e-05,
#  ('at',): 5.420083577688768e-05,
#  ('əmrdə',): 1.0840167155377537e-05,
#  ('bəyan',): 1.6260250733066305e-05,
#  ('münasibətdə',): 1.0840167155377537e-05,
#  ('məzmun',): 0.00022222342668523949,
#  ('yenidən',): 0.00029810459677288224,
#  ('xəritələr',): 6.504100293226522e-05,
#  ('ittifaqların',): 1.0840167155377537e-05,
#  ('dərəcəsi',): 0.0002384836774183058,
#  ('əslində',): 5.962091935457645e-05,
#  ('alimi',): 0.0001680225909083518,
#  ('qiymətləndirməyimizdən',): 1.0840167155377537e-05,
#  ('etdirilməsidir',): 1.0840167155377537e-05,
#  ('əsədova',): 1.0840167155377537e-05,
#  ('cəsində',): 0.0003577255161274587,
#  ('başlayır',): 0.0002005430923744844,
#  ('dissertasiyanın',): 6.504100293226522e-05,
#  ('sferasında',): 2.1680334310755073e-05,
#  ('repertuarları',): 1.0840167155377537e-05,
#  ('kağız',): 0.00019512300879679566,
#  ('bb',): 0.00031436484750594853,
#  ('qanuni',): 1.0840167155377537e-05,
#  ('özlərinin',): 2.710041788844384e-05,
#  ('sesinin',): 1.6260250733066305e-05,
#  ('respublika',): 0.0008184326202310039,
#  ('şuşa',): 5.962091935457645e-05,
#  ('təsdiqlədi',): 1.0840167155377537e-05,
#  ('siyahısı',): 0.00029810459677288224,
#  ('metr',): 3.794058504382138e-05,
#  ('dövlətlərinin',): 3.794058504382138e-05,
#  ('bəyin',): 9.214142082070906e-05,
#  ('infeksləri',): 1.0840167155377537e-05,
#  ('xarici',): 0.0007750719516094938,
#  ('insanların',): 4.8780752199198914e-05,
#  ('qaydada',): 0.00011382175513146413,
#  ('şumer',): 0.00010840167155377537,
#  ('daxili',): 0.00011382175513146413,
#  ('əsrin',): 0.001073176548382376,
#  ('gürcü',): 4.3360668621510146e-05,
#  ('əsrdə',): 0.0005203280234581218,
#  ('rəqmli',): 1.0840167155377537e-05,
#  ('öyrənilməsində',): 6.504100293226522e-05,
#  ('komissarlığına',): 1.0840167155377537e-05,
#  ('tututulurdu',): 1.0840167155377537e-05,
#  ('tapır',): 9.214142082070906e-05,
#  ('saxlamaq',): 6.504100293226522e-05,
#  ('vəsaitlərin',): 0.00022764351026292827,
#  ('on',): 0.00039566610117128004,
#  ('təyinedicilər',): 8.672133724302029e-05,
#  ('diapo',): 1.0840167155377537e-05,
#  ('gələcək',): 8.672133724302029e-05,
#  ('endirməkdən',): 1.0840167155377537e-05,
#  ('sərgilərindən',): 1.6260250733066305e-05,
#  ('sietl',): 1.0840167155377537e-05,
#  ('lenin',): 5.420083577688768e-05,
#  ('mil',): 2.710041788844384e-05,
#  ('olmaz',): 3.794058504382138e-05,
#  ('kolont',): 3.794058504382138e-05,
#  ('salyan',): 5.420083577688768e-05,
#  ('etdirilməsi',): 0.0001029815879760866,
#  ('lüğətlər',): 6.504100293226522e-05,
#  ('saatlarında',): 1.0840167155377537e-05,
#  ('cildlik',): 0.00013008200586453044,
#  ('yazisi',): 1.6260250733066305e-05,
#  ('printerlərədn',): 1.0840167155377537e-05,
#  ('verildi',): 6.504100293226522e-05,
#  ('yəni',): 0.0003197849310836373,
#  ('təşkili',): 0.0007967522859202489,
#  ('sesə',): 1.0840167155377537e-05,
#  ('bazar',): 2.710041788844384e-05,
#  ('qısa',): 0.0002547439281513721,
#  ('ifaların',): 1.0840167155377537e-05,
#  ('sovet',): 0.00044444685337047897,
#  ('arayış',): 4.3360668621510146e-05,
#  ('veryovkina',): 1.0840167155377537e-05,
#  ('məruzə',): 3.794058504382138e-05,
#  ('yaşünaslıqla',): 1.0840167155377537e-05,
#  ('təhkim',): 2.1680334310755073e-05,
#  ('zərdüşt',): 8.672133724302029e-05,
#  ('təyin',): 0.00019512300879679566,
#  ('müdir',): 5.962091935457645e-05,
#  ('tarixçilər',): 1.0840167155377537e-05,
#  ('mümtaz',): 2.1680334310755073e-05,
#  ('disk',): 0.00027642426246212717,
#  ('aparmaq',): 8.130125366533152e-05,
#  ('qanunu',): 8.130125366533152e-05,
#  ('tələbatlar',): 1.0840167155377537e-05,
#  ('qoruyub',): 3.252050146613261e-05,
#  ('sürətli',): 5.962091935457645e-05,
#  ('avtomatlaş',): 2.710041788844384e-05,
#  ('nəşrlərə',): 4.3360668621510146e-05,
#  ('yalnız',): 0.00039566610117128004,
#  ('uyğun',): 0.0004281866026374127,
#  ('biri',): 0.0007859121187648714,
#  ('sisteminin',): 0.0004173464354820351,
#  ('linqvist',): 4.8780752199198914e-05,
#  ('yaxud',): 0.00022764351026292827,
#  ('dəfə',): 0.0007154510322549174,
#  ('işləmək',): 6.504100293226522e-05,
#  ('edən',): 0.0014309020645098347,
#  ('səviy',): 2.710041788844384e-05,
#  ('mühüm',): 0.0008997338738963355,
#  ('kitablar',): 0.0006720903636334072,
#  ('nəhəng',): 8.672133724302029e-05,
#  ('göndərilirsə',): 1.0840167155377537e-05,
#  ('kataloq',): 0.0004173464354820351,
#  ('yusif',): 2.710041788844384e-05,
#  ('bazasında',): 0.00014634225659759673,
#  ('keçmiş',): 0.00024390376099599456,
#  ('formada',): 0.00022222342668523949,
#  ('formallaşdırılması',): 1.6260250733066305e-05,
#  ('aşağıda',): 4.8780752199198914e-05,
#  ('xassələrə',): 1.0840167155377537e-05,
#  ('fakültəsində',): 0.00019512300879679566,
#  ('aşağıdakılar',): 0.0001192418387091529,
#  ('sistemləri',): 0.0002059631759521732,
#  ('qosudarstvennoy',): 1.0840167155377537e-05,
#  ('biblio',): 0.0001355020894422192,
#  ('orqanları',): 9.756150439839783e-05,
#  ('ermənistan',): 4.3360668621510146e-05,
#  ('imkan',): 0.0004281866026374127,
#  ('uzun',): 0.0002547439281513721,
#  ('lakin',): 0.0004119263519043464,
#  ('kitabların',): 0.0004986476891473666,
#  ('kitabçalar',): 4.3360668621510146e-05,
#  ('əksinədir',): 1.0840167155377537e-05,
#  ('təsvirin',): 0.0001517623401752855,
#  ('rmişdir',): 0.00019512300879679566,
#  ('internetdə',): 2.1680334310755073e-05,
#  ('bankları',): 2.710041788844384e-05,
#  ('rusiya',): 0.0007804920351871826,
#  ('tutunun',): 0.0002059631759521732,
#  ('latviya',): 1.6260250733066305e-05,
#  ('nəşrləri',): 0.0004010861847489688,
#  ('çapedici',): 2.710041788844384e-05,
#  ('özundən',): 1.0840167155377537e-05,
#  ('kompleks',): 0.00018428284164141812,
#  ('mks',): 0.0006937706979441623,
#  ('səmərəli',): 0.0002384836774183058,
#  ('elmi',): 0.003159908725792552,
#  ('qəsəbə',): 0.00014092217301990797,
#  ('operatoru',): 1.0840167155377537e-05,
#  ('plərin',): 2.1680334310755073e-05,
#  ('mefodi',): 1.6260250733066305e-05,
#  ('özəlləşdirilməsi',): 1.6260250733066305e-05,
#  ('givc',): 1.0840167155377537e-05,
#  ('kağızın',): 5.962091935457645e-05,
#  ('ının',): 4.3360668621510146e-05,
#  ('lankaran',): 1.0840167155377537e-05,
#  ('təsdiq',): 0.0002872644296175047,
#  ('zalı',): 0.0002601640117290609,
#  ('elementləri',): 0.00014634225659759673,
#  ('toplanan',): 3.252050146613261e-05,
#  ('tezliklə',): 3.794058504382138e-05,
#  ('sənəd',): 0.0006341497785895859,
#  ('onlardakı',): 1.0840167155377537e-05,
#  ('mai',): 0.0006287296950118971,
#  ('çexiyada',): 1.0840167155377537e-05,
#  ('yaşünaslıq',): 0.0002005430923744844,
#  ('kompakt',): 9.214142082070906e-05,
#  ('emalı',): 0.00011382175513146413,
#  ('bürümə',): 1.0840167155377537e-05,
#  ('yazıçıları',): 4.8780752199198914e-05,
#  ('üzünü',): 5.962091935457645e-05,
#  ('qruplaşdırılmış',): 2.710041788844384e-05,
#  ('şəxs',): 0.00011382175513146413,
#  ('seçmə',): 0.00011382175513146413,
#  ('nəşrə',): 0.00012466192228684166,
#  ('hazırda',): 0.0005853690263903869,
#  ('belə',): 0.0007425514501433612,
#  ('barən',): 0.0002547439281513721,
#  ('yerinə',): 0.0006178895278565195,
#  ('tətbiqi',): 0.00029810459677288224,
#  ('yer',): 0.00027642426246212717,
#  ('məsi',): 5.420083577688768e-05,
#  ('region',): 7.588117008764276e-05,
#  ('cari',): 0.0005962091935457645,
#  ('fayl',): 7.046108650995399e-05,
#  ('siyahıya',): 2.1680334310755073e-05,
#  ('ç',): 9.214142082070906e-05,
#  ('şəbəkəsiz',): 1.0840167155377537e-05,
#  ('lazım',): 0.00017886275806372934,
#  ('sentyabr',): 0.00013008200586453044,
#  ('artmaqda',): 2.1680334310755073e-05,
#  ('ibn',): 4.3360668621510146e-05,
#  ('ümumdünya',): 0.0001029815879760866,
#  ('apöarılması',): 1.0840167155377537e-05,
#  ('ticarət',): 1.6260250733066305e-05,
#  ('tərkibinə',): 0.0002384836774183058,
#  ('sənədlərin',): 0.0008401129545417591,
#  ('şərqşünaslıq',): 2.710041788844384e-05,
#  ('kanallarla',): 1.0840167155377537e-05,
#  ('milyon',): 0.00024390376099599456,
#  ('funk',): 4.3360668621510146e-05,
#  ('məktəblərində',): 4.3360668621510146e-05,
#  ('çala',): 2.710041788844384e-05,
#  ('məktəb',): 0.00048238743841430033,
#  ('məbədlər',): 1.0840167155377537e-05,
#  ('ağ',): 1.0840167155377537e-05,
#  ('toplanmış',): 0.0001029815879760866,
#  ('bitməmişdir',): 1.0840167155377537e-05,
#  ('mərkəzinin',): 9.214142082070906e-05,
#  ('hazırlanan',): 7.588117008764276e-05,
#  ('korolenko',): 1.6260250733066305e-05,
#  ('toplusunun',): 2.710041788844384e-05,
#  ('görülmüş',): 2.710041788844384e-05,
#  ('zərif',): 1.6260250733066305e-05,
#  ('fondunda',): 0.0006016292771234532,
#  ('dəfələrlə',): 9.214142082070906e-05,
#  ('əsi',): 7.046108650995399e-05,
#  ('şəbəkələrinin',): 4.3360668621510146e-05,
#  ('məcburi',): 0.00044986693694816775,
#  ('ict',): 0.0007317112829879836,
#  ('çoxfunksiyalı',): 2.1680334310755073e-05,
#  ('kat',): 0.0001517623401752855,
#  ('hüquq',): 0.00022764351026292827,
#  ('kataloqa',): 8.672133724302029e-05,
#  ('almışdır',): 0.0005149079398804329,
#  ('arxitekturası',): 1.6260250733066305e-05,
#  ('öyrənilir',): 4.3360668621510146e-05,
#  ('bi',): 0.00037398576686052497,
#  ('ədəbiyyat',): 0.001192418387091529,
#  ('format',): 5.962091935457645e-05,
#  ('mədə',): 3.794058504382138e-05,
#  ('adını',): 0.0001680225909083518,
#  ('funksiyalarına',): 3.252050146613261e-05,
#  ('mübadiləsi',): 0.0002655840953067496,
#  ('kadr',): 8.672133724302029e-05,
#  ('yazmaq',): 4.3360668621510146e-05,
#  ('məzmunu',): 0.00024390376099599456,
#  ('oolan',): 1.0840167155377537e-05,
#  ('dəyişdirilir',): 1.6260250733066305e-05,
#  ('təşkil',): 0.001799467747792671,
#  ('başqalarının',): 6.504100293226522e-05,
#  ('kiçik',): 0.0002710041788844384,
#  ('rəsmi',): 0.00036314559970514746,
#  ('əhəmiyyət',): 0.0005203280234581218,
#  ('ii',): 0.00038482593401590253,
#  ('adil',): 1.0840167155377537e-05,
#  ('idilər',): 3.794058504382138e-05,
#  ('nüsxə',): 0.0009539347096732232,
#  ('komplekt',): 4.8780752199198914e-05,
#  ('kasiya',): 7.588117008764276e-05,
#  ('geniş',): 0.0008075924530756264,
#  ('fərmanı',): 0.00018970292521910688,
#  ('patent',): 0.0002384836774183058,
#  ('araşdırmalardan',): 1.0840167155377537e-05,
#  ('avropada',): 8.130125366533152e-05,
#  ('batçılar',): 1.6260250733066305e-05,
#  ('rilmişdir',): 2.710041788844384e-05,
#  ('zaman',): 0.00046070710410354526,
#  ('buraxılışların',): 1.6260250733066305e-05,
#  ('kitabxanalarından',): 8.130125366533152e-05,
#  ('standartda',): 3.252050146613261e-05,
#  ('kütləvi',): 0.0007371313665656725,
#  ('fərqləndirilir',): 0.00018428284164141812,
#  ('ardıcıllığının',): 1.6260250733066305e-05,
#  ('həyata',): 0.0012682995571791718,
#  ('məxsus',): 0.00014092217301990797,
#  ('qiymət',): 8.672133724302029e-05,
#  ('çoxsahəli',): 3.794058504382138e-05,
#  ('for',): 0.00014092217301990797,
#  ('edilməsini',): 4.3360668621510146e-05,
#  ('türk',): 0.0002547439281513721,
#  ('sadiqi',): 1.6260250733066305e-05,
#  ('əsrlərə',): 4.8780752199198914e-05,
#  ('prezident',): 0.0003902460175935913,
#  ('mərkəzi',): 0.001517623401752855,
#  ('şəxsi',): 0.0004281866026374127,
#  ('illərində',): 0.0004281866026374127,
#  ('yət',): 0.00022222342668523949,
#  ('fərqlənirlər',): 2.1680334310755073e-05,
#  ('terminini',): 3.252050146613261e-05,
#  ('dağılması',): 1.0840167155377537e-05,
#  ('qüsursuz',): 2.1680334310755073e-05,
#  ('xülasəsidir',): 2.1680334310755073e-05,
#  ('olunan',): 0.0008130125366533152,
#  ('keçirilidi',): 1.0840167155377537e-05,
#  ('arxiv',): 0.00029268451319519346,
#  ('materialdan',): 4.8780752199198914e-05,
#  ('zində',): 1.0840167155377537e-05,
#  ('səhifələrində',): 5.962091935457645e-05,
#  ('kvadrat',): 1.6260250733066305e-05,
#  ('əhalisi',): 4.8780752199198914e-05,
#  ('aparılmış',): 7.046108650995399e-05,
#  ('olunmağa',): 0.00010840167155377537,
#  ('çıxarılmış',): 3.794058504382138e-05,
#  ('dayanmaq',): 2.1680334310755073e-05,
#  ('ayrılmış',): 3.794058504382138e-05,
#  ('mksdə',): 1.0840167155377537e-05,
#  ('bazasının',): 8.130125366533152e-05,
#  ('alırdı',): 3.252050146613261e-05,
#  ('kolleksiyalarının',): 1.6260250733066305e-05,
#  ('kitabxanaşünaslığın',): 4.8780752199198914e-05,
#  ('onlarla',): 2.1680334310755073e-05,
#  ('istədiyi',): 1.0840167155377537e-05,
#  ('kompüter',): 0.0002655840953067496,
#  ('məqsəd',): 0.0002059631759521732,
#  ('məlumdur',): 7.588117008764276e-05,
#  ('maneələrinin',): 1.6260250733066305e-05,
#  ('prosedurlarla',): 1.0840167155377537e-05,
#  ('üçcildlik',): 2.710041788844384e-05,
#  ('müalicəyə',): 1.0840167155377537e-05,
#  ('yolları',): 7.046108650995399e-05,
#  ('ək',): 9.756150439839783e-05,
#  ('orta',): 0.0004390267697927902,
#  ('planlaşdırılması',): 7.046108650995399e-05,
#  ('ənənəvi',): 0.0002005430923744844,
#  ('ölkə',): 0.0004769673548366116,
#  ('əsasını',): 0.00016260250733066305,
#  ('standartlaşdırma',): 7.046108650995399e-05,
#  ('kimyəvi',): 5.962091935457645e-05,
#  ('kənd',): 0.0005799489428126982,
#  ('çıxarılması',): 8.672133724302029e-05,
#  ('texniki',): 0.000607049360701142,
#  ('qalınlığı',): 2.710041788844384e-05,
#  ('ideyasından',): 1.0840167155377537e-05,
#  ('işlədilir',): 8.130125366533152e-05,
#  ('x',): 9.756150439839783e-05,
#  ('insanın',): 7.588117008764276e-05,
#  ('gücləndirilmiş',): 1.0840167155377537e-05,
#  ('rləri',): 1.6260250733066305e-05,
#  ('əlaqənin',): 2.1680334310755073e-05,
#  ('dövri',): 0.0007913322023425601,
#  ('xiv',): 3.252050146613261e-05,
#  ('qarşıladılar',): 1.0840167155377537e-05,
#  ('losof',): 2.1680334310755073e-05,
#  ('tutur',): 0.00022764351026292827,
#  ('yartdığı',): 1.0840167155377537e-05,
#  ('güclü',): 5.962091935457645e-05,
#  ('bölmədən',): 4.8780752199198914e-05,
#  ('meydana',): 0.0005094878563027442,
#  ('bağlı',): 0.00044444685337047897,
#  ('işlərin',): 0.00010840167155377537,
#  ('tədqiqat',): 0.0002493238445736833,
#  ('təsiri',): 5.962091935457645e-05,
#  ('təazahür',): 1.0840167155377537e-05,
#  ('icbari',): 6.504100293226522e-05,
#  ('həkim',): 4.3360668621510146e-05,
#  ('habelə',): 0.0001029815879760866,
#  ('mərkəzləri',): 9.214142082070906e-05,
#  ('qiraətxananı',): 1.6260250733066305e-05,
#  ('nedicisi',): 1.0840167155377537e-05,
#  ('yüklənməsi',): 1.6260250733066305e-05,
#  ('nümayiş',): 3.252050146613261e-05,
#  ('avropa',): 0.00018970292521910688,
#  ('əsası',): 0.0002601640117290609,
#  ('əvvəlində',): 5.962091935457645e-05,
#  ('göstəricidir',): 4.3360668621510146e-05,
#  ('onlar',): 0.0004173464354820351,
#  ('birlikdə',): 0.00027642426246212717,
#  ('metodu',): 0.00011382175513146413,
#  ('əsərin',): 0.0003252050146613261,
#  ('bərdə',): 5.962091935457645e-05,
#  ('göstərirdi',): 0.0001517623401752855,
#  ('aka',): 3.252050146613261e-05,
#  ('repk',): 1.6260250733066305e-05,
#  ('mikrosənəd',): 2.1680334310755073e-05,
#  ('formalaşdırılması',): 0.00011382175513146413,
#  ('əlaqəyə',): 3.252050146613261e-05,
#  ('sonrakı',): 0.00013008200586453044,
#  ('əmək',): 0.0003197849310836373,
#  ('ofset',): 9.756150439839783e-05,
#  ('komitəsinə',): 2.710041788844384e-05,
#  ('nəşrlər',): 0.0005907891099680758,
#  ('ndan',): 0.00017344267448604058,
#  ('direkt',): 3.794058504382138e-05,
#  ('bilmədiyindən',): 1.6260250733066305e-05,
#  ('əla',): 7.046108650995399e-05,
#  ('rəhbərliyi',): 0.00010840167155377537,
#  ('kitabxanasının',): 0.0007750719516094938,
#  ('cartographic',): 1.0840167155377537e-05,
#  ('şəraitlə',): 1.0840167155377537e-05,
#  ('yacın',): 1.0840167155377537e-05,
#  ('neyroqruppa',): 1.0840167155377537e-05,
#  ('axında',): 1.6260250733066305e-05,
#  ('məhsulun',): 3.794058504382138e-05,
#  ...}

# %%
total_unigrams = sum(unigram_counts.values())
unigram_probs = {
    unigram: (count+1)/(total_unigrams+len(unigram_counts)) for unigram, count in unigram_counts.items()
}

def unigram_perplexity(test_tokens, unigram_probs):
    log_prob_sum = 0
    for token in test_tokens:
        unigram = (token,)
        prob = unigram_probs.get(unigram, 1e-6)
        log_prob_sum += math.log(prob)
    return math.exp(-log_prob_sum / len(test_tokens))

perplexity_unigram = unigram_perplexity(test_tokens, unigram_probs)
perplexity_unigram
# Out:
# 2576.3131188341363

# %%
def bigram_perplexity(test_tokens, bigram_counts, unigram_counts):
    log_prob_sum = 0
    test_bigrams = build_ngrams(test_tokens, 2)
    for bigram in test_bigrams:
        count_bigram = bigram_counts.get(bigram, 1)
        count_unigram = unigram_counts.get((bigram[0],), 1)
        prob = (count_bigram + 1e-10) / (count_unigram + 1e-10)
        log_prob_sum += math.log(prob)
    return math.exp(-log_prob_sum / len(test_bigrams))

perplexity_bigram = bigram_perplexity(test_tokens, bigram_counts, unigram_counts)
perplexity_bigram
# Out:
# 48.772571716321316

# %%
def trigram_perplexity(test_tokens, trigram_counts, bigram_counts):
    log_prob_sum = 0
    test_trigrams = build_ngrams(test_tokens, 3)
    for trigram in test_trigrams:
        count_trigram = trigram_counts.get(trigram, 1)
        count_bigram = bigram_counts.get(trigram[:2], 1)
        prob = (count_trigram + 1e-10) / (count_bigram + 1e-10)
        log_prob_sum += math.log(prob)
    return math.exp(-log_prob_sum / len(test_trigrams))

perplexity_trigram = trigram_perplexity(test_tokens, trigram_counts, bigram_counts)
perplexity_trigram
# Out:
# 1.520862223151782

# %%
unigram_probs
# Out:
# {('yolu',): 0.0002655840953067496,
#  ('digər',): 0.0016314451568843192,
#  ('təbiət',): 0.00017886275806372934,
#  ('göstərici',): 0.0004878075219919891,
#  ('ilə',): 0.0069431270630193114,
#  ('təsvirlərin',): 9.214142082070906e-05,
#  ('strukturlarının',): 1.6260250733066305e-05,
#  ('fərqli',): 0.0001680225909083518,
#  ('EOS',): 0.07433644626800145,
#  ('sözlərə',): 1.6260250733066305e-05,
#  ('etmək',): 0.001051496214071621,
#  ('işi',): 0.0009864552111393558,
#  ('sıra',): 0.000607049360701142,
#  ('dədəm',): 1.6260250733066305e-05,
#  ('ziyali',): 1.0840167155377537e-05,
#  ('ümumi',): 0.0012195188049799728,
#  ('də',): 0.0038482593401590252,
#  ('dövlət',): 0.002975625884151134,
#  ('və',): 0.03262348305410869,
#  ('hissəsi',): 0.0004010861847489688,
#  ('ştat',): 2.710041788844384e-05,
#  ('əlyazma',): 0.00036856568328283624,
#  ('müəllif',): 0.0003577255161274587,
#  ('otaqda',): 3.252050146613261e-05,
#  ('yazılı',): 0.00017344267448604058,
#  ('konkret',): 0.00027642426246212717,
#  ('bütün',): 0.0017344267448604058,
#  ('oxucuların',): 0.0004390267697927902,
#  ('nəşr',): 0.0020650518430994206,
#  ('çox',): 0.0018265681656811149,
#  ('göstərir',): 0.0007208711158326062,
#  ('misirin',): 4.3360668621510146e-05,
#  ('peşəkar',): 0.00012466192228684166,
#  ('kitabələr',): 5.420083577688768e-05,
#  ('əlyazmalar',): 0.00017344267448604058,
#  ('əsərləri',): 0.0005853690263903869,
#  ('müəssisələri',): 0.0001680225909083518,
#  ('k',): 0.008937717819608778,
#  ('b',): 0.0021626133474978186,
#  ('rak',): 0.0003577255161274587,
#  ('azərbaycanda',): 0.0009376744589401568,
#  ('medalı',): 5.962091935457645e-05,
#  ('con',): 3.252050146613261e-05,
#  ('qəbulu',): 4.3360668621510146e-05,
#  ('ildə',): 0.006796784806421715,
#  ('yaradır',): 0.00019512300879679566,
#  ('yə',): 5.962091935457645e-05,
#  ('universitet',): 0.0009918752947170445,
#  ('kolleci',): 4.8780752199198914e-05,
#  ('seriyası',): 0.0001192418387091529,
#  ('məlumatlar',): 0.0003252050146613261,
#  ('mövzuda',): 4.3360668621510146e-05,
#  ('adına',): 0.0012737196407568605,
#  ('lıca',): 1.0840167155377537e-05,
#  ('maiyyət',): 7.046108650995399e-05,
#  ('zəsi',): 0.00018428284164141812,
#  ('fərqlər',): 3.252050146613261e-05,
#  ('prosesində',): 0.0002384836774183058,
#  ('şah',): 0.00012466192228684166,
#  ('fondu',): 0.0009756150439839782,
#  ('məcmuəsini',): 1.6260250733066305e-05,
#  ('olan',): 0.003436332988254679,
#  ('üzüdür',): 1.0840167155377537e-05,
#  ('yazılma',): 4.3360668621510146e-05,
#  ('kitabxanada',): 0.0004878075219919891,
#  ('idarə',): 0.0004173464354820351,
#  ('disküzərində',): 1.0840167155377537e-05,
#  ('yaxın',): 0.0003360451818167036,
#  ('meyillərdən',): 1.6260250733066305e-05,
#  ('ilk',): 0.0018265681656811149,
#  ('mümkün',): 0.00018970292521910688,
#  ('indiki',): 0.0006666702800557185,
#  ('tələb',): 0.0002493238445736833,
#  ('informasiya',): 0.003989181513178933,
#  ('götürür',): 2.1680334310755073e-05,
#  ('işt',): 0.0006449899457449634,
#  ('qəbul',): 0.0006558301129003409,
#  ('azərbaycanı',): 7.588117008764276e-05,
#  ('olmuşdur',): 0.0015880844882628091,
#  ('predmet',): 0.0002493238445736833,
#  ('sənədin',): 0.0007046108650995398,
#  ('tədqiqatçıların',): 2.1680334310755073e-05,
#  ('təsnifata',): 1.6260250733066305e-05,
#  ('əvvəllər',): 0.0001517623401752855,
#  ('edilir',): 0.0017886275806372933,
#  ('çap',): 0.0033550317345893473,
#  ('verilən',): 0.0002872644296175047,
#  ('birinin',): 6.504100293226522e-05,
#  ('nin',): 0.003105707890015664,
#  ('mətn',): 0.0002872644296175047,
#  ('olmuş',): 0.0004281866026374127,
#  ('yanların',): 1.0840167155377537e-05,
#  ('aiddir',): 0.0002384836774183058,
#  ('moskva',): 0.00018970292521910688,
#  ('gəcəvi',): 1.0840167155377537e-05,
#  ('kitabxanası',): 0.002075892010254798,
#  ('memarlıq',): 7.046108650995399e-05,
#  ('əsasən',): 0.0007208711158326062,
#  ('onların',): 0.001002715461872422,
#  ('olaraq',): 0.0016422853240396966,
#  ('kitabxananın',): 0.0018265681656811149,
#  ('nan',): 4.8780752199198914e-05,
#  ('bu',): 0.006563721212581098,
#  ('dəqiqliyinə',): 2.1680334310755073e-05,
#  ('idi',): 0.0008888937067409579,
#  ('dövründə',): 0.0003306250982390148,
#  ('divan',): 2.1680334310755073e-05,
#  ('haqqında',): 0.002758822541043583,
#  ('milli',): 0.0031490685586371744,
#  ('müəyyən',): 0.0011165372170038861,
#  ('şuraya',): 1.6260250733066305e-05,
#  ('hüquqşünasların',): 1.0840167155377537e-05,
#  ('böyük',): 0.0018753489178803136,
#  ('ist',): 0.004216825023441862,
#  ('gures',): 1.0840167155377537e-05,
#  ('hissədən',): 8.672133724302029e-05,
#  ('çoxlu',): 8.130125366533152e-05,
#  ('nu',): 2.710041788844384e-05,
#  ('quldarın',): 1.0840167155377537e-05,
#  ('mədəniyyət',): 0.001962070255123334,
#  ('məlumat',): 0.001474262733131345,
#  ('vasitəsi',): 0.0004065062683266576,
#  ('əldə',): 0.0004932276055696779,
#  ('mə',): 0.000303524680350571,
#  ('formaca',): 1.0840167155377537e-05,
#  ('rakçısı',): 4.3360668621510146e-05,
#  ('illik',): 0.00029268451319519346,
#  ('yaradılmış',): 0.0004281866026374127,
#  ('işçilərinin',): 0.00021680334310755073,
#  ('üçün',): 0.004482409118748611,
#  ('köməyi',): 8.672133724302029e-05,
#  ('ya',): 0.004813034216987626,
#  ('şəkildə',): 0.0007262911994102949,
#  ('sahə',): 0.0001355020894422192,
#  ('kitabxa',): 0.00012466192228684166,
#  ('nüfuzlu',): 5.420083577688768e-05,
#  ('obyekt',): 0.00027642426246212717,
#  ('olunmuşdur',): 0.0008780535395855804,
#  ('nə',): 0.0010948568826931312,
#  ('xidmət',): 0.0016477054076173856,
#  ('uşaq',): 0.0006829305307887848,
#  ('fəaliyyət',): 0.0027046217052666952,
#  ('dövrün',): 0.00017886275806372934,
#  ('sərvətlərin',): 1.6260250733066305e-05,
#  ('rə',): 0.00010840167155377537,
#  ('təsvir',): 0.0004119263519043464,
#  ('e',): 0.0005528485249242543,
#  ('kri',): 4.3360668621510146e-05,
#  ('şöbəsi',): 0.000303524680350571,
#  ('konversiyaya',): 1.0840167155377537e-05,
#  ('doğru',): 3.252050146613261e-05,
#  ('kataloqlaşdırılmasına',): 1.0840167155377537e-05,
#  ('daşıya',): 1.0840167155377537e-05,
#  ('sadi',): 0.00036314559970514746,
#  ('söhbət',): 3.252050146613261e-05,
#  ('əsərində',): 0.00014092217301990797,
#  ('görə',): 0.001517623401752855,
#  ('müxtəlif',): 0.0013929614794660134,
#  ('etməyə',): 0.0003523054325497699,
#  ('çoxcildli',): 2.710041788844384e-05,
#  ('yet',): 0.0007479715337210499,
#  ('jurnal',): 0.0006016292771234532,
#  ('ndən',): 0.002124672762453997,
#  ('adlı',): 0.0011382175513146413,
#  ('təbliği',): 9.214142082070906e-05,
#  ('iki',): 0.0007588117008764275,
#  ('səmərəliliyini',): 4.3360668621510146e-05,
#  ('a',): 0.0013658610615775695,
#  ('qablaşdırma',): 1.0840167155377537e-05,
#  ('ixt',): 0.0007967522859202489,
#  ('nəzdində',): 0.0003414652653943924,
#  ('əlaqədar',): 0.0005474284413465656,
#  ('fərqlidir',): 1.0840167155377537e-05,
#  ('bundan',): 0.0001680225909083518,
#  ('təbii',): 0.00013008200586453044,
#  ('təbliğ',): 8.672133724302029e-05,
#  ('təcrübəni',): 2.1680334310755073e-05,
#  ('əsrə',): 9.756150439839783e-05,
#  ('ka',): 0.0003414652653943924,
#  ('tutulmuş',): 0.00015718242375297427,
#  ('azərbaycan',): 0.004428208282971724,
#  ('informasia',): 1.0840167155377537e-05,
#  ('kollekt',): 0.00022764351026292827,
#  ('onal',): 0.00017886275806372934,
#  ('avqust',): 0.0001029815879760866,
#  ('vəsait',): 0.0009105740410517131,
#  ('adları',): 0.00014634225659759673,
#  ('kökləri',): 1.6260250733066305e-05,
#  ('azər',): 0.00010840167155377537,
#  ('formalaşması',): 0.00010840167155377537,
#  ('arayışı',): 1.6260250733066305e-05,
#  ('xarakterikdir',): 2.1680334310755073e-05,
#  ('edilməsi',): 0.001121957300581575,
#  ('məqsədi',): 0.00044444685337047897,
#  ('nöqtələri',): 1.0840167155377537e-05,
#  ('həqiqi',): 8.130125366533152e-05,
#  ('yeniliklər',): 2.1680334310755073e-05,
#  ('edilmiş',): 0.0012899798914899267,
#  ('kitabları',): 0.00031436484750594853,
#  ('n',): 0.004563710372413943,
#  ('seçilməsi',): 0.00013008200586453044,
#  ('ediən',): 1.0840167155377537e-05,
#  ('nəzarət',): 0.0001517623401752855,
#  ('şəhərində',): 0.0005799489428126982,
#  ('təchiz',): 0.00014092217301990797,
#  ('kimi',): 0.002802183209665093,
#  ('p',): 0.00048238743841430033,
#  ('materiallar',): 0.00031436484750594853,
#  ('adı',): 0.0007100309486772286,
#  ('taxta',): 3.794058504382138e-05,
#  ('nləşdirir',): 1.0840167155377537e-05,
#  ('gəlməsi',): 0.0001517623401752855,
#  ('kitab',): 0.00422224510701955,
#  ('windows',): 1.6260250733066305e-05,
#  ('yazılır',): 9.756150439839783e-05,
#  ('kursu',): 2.710041788844384e-05,
#  ('verilir',): 0.0006612501964780296,
#  ('çm',): 5.420083577688768e-05,
#  ('v',): 0.0019512300879679565,
#  ('edilən',): 0.0009105740410517131,
#  ('dəyişikliklər',): 7.588117008764276e-05,
#  ('qiymətləndirir',): 2.710041788844384e-05,
#  ('verilənlərdən',): 2.710041788844384e-05,
#  ('vardır',): 0.0005311681906134992,
#  ('virləri',): 1.0840167155377537e-05,
#  ('kilsəsinin',): 4.8780752199198914e-05,
#  ('losofu',): 3.794058504382138e-05,
#  ('daşımışdır',): 1.6260250733066305e-05,
#  ('ərzində',): 0.00046070710410354526,
#  ('gün',): 0.00012466192228684166,
#  ('nüsxədən',): 0.0003360451818167036,
#  ('il',): 0.0017344267448604058,
#  ('yardım',): 0.00010840167155377537,
#  ('bir',): 0.0046450116260792745,
#  ('kildiyini',): 1.0840167155377537e-05,
#  ('t',): 0.0026124802844459862,
#  ('nəşirlər',): 1.0840167155377537e-05,
#  ('şəhər',): 0.0006504100293226522,
#  ('imkanlarına',): 2.1680334310755073e-05,
#  ('olur',): 0.0006829305307887848,
#  ('əksini',): 0.00022764351026292827,
#  ('görülmüşdür',): 0.00023306359384061702,
#  ('verilirdi',): 8.672133724302029e-05,
#  ('arasında',): 0.0005311681906134992,
#  ('proquest',): 2.710041788844384e-05,
#  ('f',): 0.0010298158797608658,
#  ('həbs',): 2.1680334310755073e-05,
#  ('məhv',): 0.0001192418387091529,
#  ('s',): 0.0025149187800475883,
#  ('source',): 1.6260250733066305e-05,
#  ('elm',): 0.0006016292771234532,
#  ('illərdə',): 0.0020975723445655534,
#  ('liyyətə',): 1.0840167155377537e-05,
#  ('marağının',): 1.0840167155377537e-05,
#  ('dövr',): 0.00011382175513146413,
#  ('yazılırdısa',): 1.0840167155377537e-05,
#  ('bazası',): 0.00022222342668523949,
#  ('mənbələr',): 0.0001355020894422192,
#  ('fakül',): 2.1680334310755073e-05,
#  ('ifadə',): 0.0002493238445736833,
#  ('işinin',): 0.0008943137903186467,
#  ('formanın',): 2.1680334310755073e-05,
#  ('kitabı',): 0.00046070710410354526,
#  ('xüsusi',): 0.0012574593900237941,
#  ('tika',): 1.0840167155377537e-05,
#  ('xəzinəmizin',): 1.0840167155377537e-05,
#  ('həmin',): 0.0013604409779998808,
#  ('aparılırdı',): 3.252050146613261e-05,
#  ('vəsaitlərini',): 2.710041788844384e-05,
#  ('daxildir',): 0.0005420083577688768,
#  ('bunlarla',): 2.710041788844384e-05,
#  ('fərdi',): 0.0002493238445736833,
#  ('olunmasının',): 5.962091935457645e-05,
#  ('gəldiyi',): 1.6260250733066305e-05,
#  ('dövrdə',): 0.0004932276055696779,
#  ('illərin',): 0.0002547439281513721,
#  ('rayon',): 0.0008075924530756264,
#  ('bakı',): 0.0009485146260955344,
#  ('nəşrlərinin',): 0.00017344267448604058,
#  ('üzü',): 0.0001029815879760866,
#  ('keçirilməsinə',): 7.046108650995399e-05,
#  ('verirdi',): 4.8780752199198914e-05,
#  ('i',): 0.0008888937067409579,
#  ('beynəlxalq',): 0.001701906243394273,
#  ('fəal',): 0.0002059631759521732,
#  ('ümumalman',): 1.6260250733066305e-05,
#  ('mln',): 0.00022764351026292827,
#  ('axun',): 3.252050146613261e-05,
#  ('təcrübi',): 0.0001355020894422192,
#  ('bilər',): 0.0008292727873863815,
#  ('misal',): 0.0001517623401752855,
#  ('halda',): 0.0002005430923744844,
#  ('yaşünaslığa',): 1.6260250733066305e-05,
#  ('resursların',): 5.962091935457645e-05,
#  ('göstəriciləri',): 0.00016260250733066305,
#  ('sayı',): 0.0005094878563027442,
#  ('dırma',): 1.6260250733066305e-05,
#  ('ni',): 0.0009756150439839782,
#  ('informasiyanın',): 0.001008135545450111,
#  ('kitabxana',): 0.005924151350413824,
#  ('resursları',): 0.00016260250733066305,
#  ('buraxdığı',): 3.794058504382138e-05,
#  ('formalı',): 5.962091935457645e-05,
#  ('göstəricinin',): 0.00016260250733066305,
#  ('şısına',): 1.0840167155377537e-05,
#  ('mənt',): 0.00014092217301990797,
#  ('yeni',): 0.0016368652404620079,
#  ('tanınmış',): 9.214142082070906e-05,
#  ('kömüründən',): 1.0840167155377537e-05,
#  ('asiya',): 7.046108650995399e-05,
#  ('reallaşdırılması',): 2.710041788844384e-05,
#  ('menecment',): 9.214142082070906e-05,
#  ('ödəmək',): 5.420083577688768e-05,
#  ('bunlara',): 9.214142082070906e-05,
#  ('ekt',): 3.794058504382138e-05,
#  ('məcmusu',): 0.0001029815879760866,
#  ('dəniyyətlərin',): 1.0840167155377537e-05,
#  ('akademiyası',): 8.130125366533152e-05,
#  ('olmayan',): 0.0001355020894422192,
#  ('inst',): 0.00018970292521910688,
#  ('çevrilir',): 8.130125366533152e-05,
#  ('əsas',): 0.0016802259090835181,
#  ('sahəsini',): 3.252050146613261e-05,
#  ('hazırlanmış',): 0.0001355020894422192,
#  ('birgə',): 0.00017886275806372934,
#  ('mahnı',): 1.0840167155377537e-05,
#  ('olmalıdır',): 8.130125366533152e-05,
#  ('məkanından',): 1.0840167155377537e-05,
#  ('bilən',): 0.00012466192228684166,
#  ('keçilmişlərin',): 1.0840167155377537e-05,
#  ('dərc',): 0.0005040677727250555,
#  ('təşkilat',): 0.0002547439281513721,
#  ('həddən',): 1.0840167155377537e-05,
#  ('nın',): 0.0014092217301990796,
#  ('axtarış',): 0.00046612718768123404,
#  ('sistemi',): 0.0005528485249242543,
#  ('həsr',): 0.00034688534897208117,
#  ('ildən',): 0.0027913430425097153,
#  ('kitabxanalar',): 0.0007371313665656725,
#  ('tamamilə',): 8.130125366533152e-05,
#  ('sistemin',): 0.0001355020894422192,
#  ('nəşrlərin',): 0.0005636886920796319,
#  ('olar',): 0.0004173464354820351,
#  ('elektron',): 0.0014363221480875234,
#  ('fondunu',): 9.214142082070906e-05,
#  ('olunur',): 0.0013008200586453044,
#  ('ra',): 0.0002059631759521732,
#  ('yüksək',): 0.0004281866026374127,
#  ('dekabr',): 8.130125366533152e-05,
#  ('formalaşdırılır',): 4.3360668621510146e-05,
#  ('db',): 4.3360668621510146e-05,
#  ('fadəçilər',): 8.672133724302029e-05,
#  ('səviyyəsinə',): 9.214142082070906e-05,
#  ('tədris',): 0.0004010861847489688,
#  ('sahəvi',): 0.0002872644296175047,
#  ('çalışmışdır',): 0.00023306359384061702,
#  ('turizm',): 0.0002005430923744844,
#  ('açıldı',): 6.504100293226522e-05,
#  ('işlədilirdi',): 2.710041788844384e-05,
#  ('toplu',): 0.00022222342668523949,
#  ('başqaları',): 9.756150439839783e-05,
#  ('birləşmiş',): 9.214142082070906e-05,
#  ('hammurapi',): 6.504100293226522e-05,
#  ('ali',): 0.0005474284413465656,
#  ('sənədləri',): 0.00024390376099599456,
#  ('mövzu',): 0.0004065062683266576,
#  ('nda',): 0.0008997338738963355,
#  ('alqoritmik',): 1.0840167155377537e-05,
#  ('təbliğində',): 4.8780752199198914e-05,
#  ('dində',): 1.6260250733066305e-05,
#  ('idrak',): 1.6260250733066305e-05,
#  ('əhatə',): 0.0007425514501433612,
#  ('edir',): 0.0022981154369400374,
#  ('yaddaş',): 9.214142082070906e-05,
#  ('saxlayır',): 8.672133724302029e-05,
#  ('ədəbiyyatşünaslıq',): 8.130125366533152e-05,
#  ('fadə',): 0.0022276543504300837,
#  ('təhsil',): 0.0010623363812269984,
#  ('eht',): 0.0003902460175935913,
#  ('kitabçılıq',): 5.420083577688768e-05,
#  ('tələbləri',): 3.794058504382138e-05,
#  ('mövzusunu',): 2.1680334310755073e-05,
#  ('yaratmış',): 5.420083577688768e-05,
#  ('standartları',): 4.8780752199198914e-05,
#  ('xarakterli',): 0.0004227665190597239,
#  ('rus',): 0.0007696518680318051,
#  ('əsəri',): 0.00037398576686052497,
#  ('biblioqrafik',): 0.00024390376099599456,
#  ('formalaşmasına',): 4.3360668621510146e-05,
#  ('direktoru',): 0.0002384836774183058,
#  ('tərkib',): 0.0002493238445736833,
#  ('resursu',): 2.1680334310755073e-05,
#  ('nəzərdə',): 0.0007100309486772286,
#  ('xusu',): 1.0840167155377537e-05,
#  ('dilindədir',): 2.710041788844384e-05,
#  ('yyət',): 0.00017886275806372934,
#  ('xarakterist',): 9.214142082070906e-05,
#  ('üzvləri',): 5.962091935457645e-05,
#  ('sonralar',): 0.0002384836774183058,
#  ('tərt',): 0.0017344267448604058,
#  ('tərcümədə',): 3.252050146613261e-05,
#  ('mixi',): 0.00015718242375297427,
#  ('səsyazma',): 2.1680334310755073e-05,
#  ('xeroneili',): 1.0840167155377537e-05,
#  ('müstəqil',): 0.00043360668621510146,
#  ('buraxılması',): 2.710041788844384e-05,
#  ('edilmişdir',): 0.0011978384706692177,
#  ('isə',): 0.002222234266852395,
#  ('həm',): 0.0012195188049799728,
#  ('ayında',): 0.0001680225909083518,
#  ('georq',): 1.6260250733066305e-05,
#  ('şərh',): 0.0001355020894422192,
#  ('zəngin',): 0.00044444685337047897,
#  ('birləşdirilməsi',): 4.3360668621510146e-05,
#  ('qəzet',): 0.0004769673548366116,
#  ('əziyyət',): 1.0840167155377537e-05,
#  ('hı',): 1.0840167155377537e-05,
#  ('amea',): 0.0001192418387091529,
#  ('səviyyəli',): 7.588117008764276e-05,
#  ('verilmişdir',): 0.0004878075219919891,
#  ('istehsalı',): 8.130125366533152e-05,
#  ('mb',): 2.710041788844384e-05,
#  ('alban',): 0.00031436484750594853,
#  ('şəklində',): 0.0003523054325497699,
#  ('kitabın',): 0.00043360668621510146,
#  ('göstəricilərin',): 0.00014634225659759673,
#  ('olması',): 0.00017886275806372934,
#  ('işində',): 0.00018970292521910688,
#  ('oxucu',): 0.00045528702052585653,
#  ('ndə',): 0.0007750719516094938,
#  ('təmin',): 0.0008672133724302029,
#  ('insan',): 0.0001029815879760866,
#  ('kint',): 9.214142082070906e-05,
#  ('kilib',): 2.710041788844384e-05,
#  ('əsasında',): 0.0009918752947170445,
#  ('başlamış',): 0.00018428284164141812,
#  ('yazılmış',): 0.0002601640117290609,
#  ('müşahidə',): 2.1680334310755073e-05,
#  ('avtomatlaşdırılmış',): 0.00043360668621510146,
#  ('mət',): 0.00011382175513146413,
#  ('izahına',): 1.0840167155377537e-05,
#  ('ki',): 0.0022818551862069715,
#  ('fransisk',): 1.0840167155377537e-05,
#  ('direktor',): 0.0001192418387091529,
#  ('vermişdir',): 0.00013008200586453044,
#  ('variantda',): 2.1680334310755073e-05,
#  ('verilənlər',): 0.00037940585043821375,
#  ('məqsədli',): 4.3360668621510146e-05,
#  ('min',): 0.0014580024823982786,
#  ('tətbiq',): 0.0006504100293226522,
#  ('koopersiya',): 1.0840167155377537e-05,
#  ('münasibət',): 0.0001192418387091529,
#  ('ratmağa',): 1.0840167155377537e-05,
#  ('respublikasının',): 0.00043360668621510146,
#  ('hansı',): 0.00038482593401590253,
#  ('yerləşdirilir',): 8.130125366533152e-05,
#  ('pay',): 1.6260250733066305e-05,
#  ('konqres',): 0.0001029815879760866,
#  ('pilləli',): 1.0840167155377537e-05,
#  ('bolqarıstan',): 2.710041788844384e-05,
#  ('rajını',): 1.6260250733066305e-05,
#  ('masiya',): 7.588117008764276e-05,
#  ('əvvəl',): 0.00029268451319519346,
#  ('vəzifə',): 8.130125366533152e-05,
#  ('qruplaşdırılır',): 3.252050146613261e-05,
#  ('xix',): 0.0003197849310836373,
#  ('tövrat',): 1.0840167155377537e-05,
#  ('standart',): 0.00021138325952986195,
#  ('sürət',): 4.3360668621510146e-05,
#  ('navigator',): 1.0840167155377537e-05,
#  ('mühasibat',): 2.1680334310755073e-05,
#  ('yazılması',): 0.00019512300879679566,
#  ('edib',): 9.756150439839783e-05,
#  ('qiymətli',): 0.0004065062683266576,
#  ('qovuşaraq',): 1.0840167155377537e-05,
#  ('bədii',): 0.0003252050146613261,
#  ('proqram',): 0.0003523054325497699,
#  ('töv',): 3.252050146613261e-05,
#  ('yaradılmasında',): 6.504100293226522e-05,
#  ('üsulu',): 0.00011382175513146413,
#  ('növləri',): 0.0003306250982390148,
#  ('izah',): 9.214142082070906e-05,
#  ('əməkdə',): 1.0840167155377537e-05,
#  ('əsasındakı',): 1.0840167155377537e-05,
#  ('stat',): 0.00024390376099599456,
#  ('assosiasiyası',): 8.672133724302029e-05,
#  ('təsisçisi',): 3.794058504382138e-05,
#  ('şairi',): 4.8780752199198914e-05,
#  ('metodiki',): 0.0002384836774183058,
#  ('kafedrası',): 2.710041788844384e-05,
#  ('formasına',): 5.420083577688768e-05,
#  ('yaşünaslığın',): 3.252050146613261e-05,
#  ('ona',): 0.00028184434603981595,
#  ('lərin',): 9.756150439839783e-05,
#  ('komplektləşdirmə',): 9.756150439839783e-05,
#  ('oluna',): 5.962091935457645e-05,
#  ('sonra',): 0.0009539347096732232,
#  ('sosial',): 0.00021680334310755073,
#  ('kitabxanaların',): 0.0006720903636334072,
#  ('ən',): 0.0012791397243345493,
#  ('yaradılmışdır',): 0.0006341497785895859,
#  ('oğlu',): 0.0003577255161274587,
#  ('semant',): 7.588117008764276e-05,
#  ('onun',): 0.001940389920812579,
#  ('özündə',): 0.0004227665190597239,
#  ('daxil',): 0.0011869983035138402,
#  ('rayonunda',): 0.0001517623401752855,
#  ('vəsaitlərdə',): 5.420083577688768e-05,
#  ('öz',): 0.0015501439032189876,
#  ('təşkilatların',): 8.672133724302029e-05,
#  ('kommentariyaları',): 1.0840167155377537e-05,
#  ('əvvəlcə',): 7.588117008764276e-05,
#  ('mk',): 0.0004715472712589228,
#  ('ili',): 5.962091935457645e-05,
#  ('iiliyini',): 1.0840167155377537e-05,
#  ('qaydalar',): 7.588117008764276e-05,
#  ('tendensiyalarını',): 1.0840167155377537e-05,
#  ('alınmışdı',): 2.710041788844384e-05,
#  ('mənəvi',): 9.756150439839783e-05,
#  ('laborant',): 7.588117008764276e-05,
#  ('əlyetərlik',): 7.588117008764276e-05,
#  ('yaradılması',): 0.0007208711158326062,
#  ('nümunələrlə',): 1.0840167155377537e-05,
#  ('avesta',): 0.0001680225909083518,
#  ('o',): 0.0016748058255058294,
#  ('dəyərində',): 1.0840167155377537e-05,
#  ('verir',): 0.00044986693694816775,
#  ('bəy',): 0.0001517623401752855,
#  ('pro',): 6.504100293226522e-05,
#  ('malik',): 0.0005040677727250555,
#  ('skini',): 1.0840167155377537e-05,
#  ('növü',): 0.00037940585043821375,
#  ('olurdu',): 3.252050146613261e-05,
#  ('şərqdə',): 7.588117008764276e-05,
#  ('becərilməsi',): 1.0840167155377537e-05,
#  ('kasiyası',): 2.1680334310755073e-05,
#  ('ın',): 4.3360668621510146e-05,
#  ('incəsənət',): 0.00037398576686052497,
#  ('üzrə',): 0.003067767304971843,
#  ('lir',): 2.1680334310755073e-05,
#  ('r',): 0.00043360668621510146,
#  ('sistemli',): 0.00029268451319519346,
#  ('der',): 2.710041788844384e-05,
#  ('hamı',): 6.504100293226522e-05,
#  ('dair',): 0.0009593547932509119,
#  ('yerləşən',): 0.0002384836774183058,
#  ('fon',): 5.962091935457645e-05,
#  ('tabxana',): 8.130125366533152e-05,
#  ('şöbənin',): 8.672133724302029e-05,
#  ('tarixli',): 0.0003306250982390148,
#  ('q',): 0.001566404153952054,
#  ('səyləri',): 1.0840167155377537e-05,
#  ('əmrinə',): 4.3360668621510146e-05,
#  ('göstərişləri',): 1.6260250733066305e-05,
#  ('rəf',): 1.6260250733066305e-05,
#  ('ləşdirmə',): 2.710041788844384e-05,
#  ('yayımı',): 2.710041788844384e-05,
#  ('nəşri',): 0.0004390267697927902,
#  ('etməkdən',): 8.130125366533152e-05,
#  ('prob',): 2.710041788844384e-05,
#  ('səviyyəsinin',): 4.8780752199198914e-05,
#  ('cədvəlləri',): 0.0001355020894422192,
#  ('quruluşuna',): 2.710041788844384e-05,
#  ('hündür',): 7.046108650995399e-05,
#  ('göstərən',): 0.00034688534897208117,
#  ('qədər',): 0.0008997338738963355,
#  ('yuxarı',): 4.8780752199198914e-05,
#  ('di',): 4.3360668621510146e-05,
#  ('daş',): 8.672133724302029e-05,
#  ('xəsi',): 1.0840167155377537e-05,
#  ('metal',): 7.046108650995399e-05,
#  ('bah',): 1.6260250733066305e-05,
#  ('kitabxanaşünaslıq',): 0.00046612718768123404,
#  ('ümumiyyətlə',): 7.588117008764276e-05,
#  ('nümunələri',): 9.214142082070906e-05,
#  ('fərmanlara',): 1.0840167155377537e-05,
#  ('adlandırılmağa',): 1.6260250733066305e-05,
#  ('diametri',): 5.420083577688768e-05,
#  ('beylin',): 1.0840167155377537e-05,
#  ('universal',): 0.0004769673548366116,
#  ('xdr',): 1.0840167155377537e-05,
#  ('kiyədə',): 1.0840167155377537e-05,
#  ('the',): 0.0001029815879760866,
#  ('prosesidir',): 9.756150439839783e-05,
#  ('nəzərdən',): 0.0001680225909083518,
#  ('yoluna',): 1.0840167155377537e-05,
#  ('baş',): 0.0008997338738963355,
#  ('olmuşdu',): 4.8780752199198914e-05,
#  ('göstəricisi',): 0.00037940585043821375,
#  ('ümumiləşdirilməsi',): 3.252050146613261e-05,
#  ('akademiyasının',): 0.00021680334310755073,
#  ('nail',): 8.130125366533152e-05,
#  ('həmçinin',): 0.00039566610117128004,
#  ('qoymuşdur',): 6.504100293226522e-05,
#  ('da',): 0.0023089556040954153,
#  ('yası',): 0.0008617932888525141,
#  ('aparılmasına',): 3.252050146613261e-05,
#  ('krincə',): 2.710041788844384e-05,
#  ('na',): 0.0007262911994102949,
#  ('edilmişdi',): 0.0001355020894422192,
#  ('pli',): 0.00036856568328283624,
#  ('yazıların',): 0.0003360451818167036,
#  ('birləşməsi',): 4.3360668621510146e-05,
#  ('ingilis',): 0.0002493238445736833,
#  ('planına',): 2.710041788844384e-05,
#  ('word',): 1.0840167155377537e-05,
#  ('növbədə',): 0.00012466192228684166,
#  ('qayda',): 0.0001680225909083518,
#  ('yaradıcılığında',): 2.1680334310755073e-05,
#  ('yaddaşının',): 1.6260250733066305e-05,
#  ('məktubları',): 2.1680334310755073e-05,
#  ('yaxşılaşdıraq',): 1.0840167155377537e-05,
#  ('işlədilən',): 7.046108650995399e-05,
#  ('şimali',): 5.420083577688768e-05,
#  ('boyaqları',): 1.6260250733066305e-05,
#  ('nazirliyi',): 0.0001680225909083518,
#  ('dərəcədə',): 0.00017344267448604058,
#  ('formatları',): 3.794058504382138e-05,
#  ('əsərlərinin',): 0.00031436484750594853,
#  ('təxəyyülünün',): 1.0840167155377537e-05,
#  ('fəlsəfə',): 0.00030894476392825975,
#  ('əhməd',): 7.046108650995399e-05,
#  ('ideyası',): 5.420083577688768e-05,
#  ('at',): 5.420083577688768e-05,
#  ('əmrdə',): 1.0840167155377537e-05,
#  ('bəyan',): 1.6260250733066305e-05,
#  ('münasibətdə',): 1.0840167155377537e-05,
#  ('məzmun',): 0.00022222342668523949,
#  ('yenidən',): 0.00029810459677288224,
#  ('xəritələr',): 6.504100293226522e-05,
#  ('ittifaqların',): 1.0840167155377537e-05,
#  ('dərəcəsi',): 0.0002384836774183058,
#  ('əslində',): 5.962091935457645e-05,
#  ('alimi',): 0.0001680225909083518,
#  ('qiymətləndirməyimizdən',): 1.0840167155377537e-05,
#  ('etdirilməsidir',): 1.0840167155377537e-05,
#  ('əsədova',): 1.0840167155377537e-05,
#  ('cəsində',): 0.0003577255161274587,
#  ('başlayır',): 0.0002005430923744844,
#  ('dissertasiyanın',): 6.504100293226522e-05,
#  ('sferasında',): 2.1680334310755073e-05,
#  ('repertuarları',): 1.0840167155377537e-05,
#  ('kağız',): 0.00019512300879679566,
#  ('bb',): 0.00031436484750594853,
#  ('qanuni',): 1.0840167155377537e-05,
#  ('özlərinin',): 2.710041788844384e-05,
#  ('sesinin',): 1.6260250733066305e-05,
#  ('respublika',): 0.0008184326202310039,
#  ('şuşa',): 5.962091935457645e-05,
#  ('təsdiqlədi',): 1.0840167155377537e-05,
#  ('siyahısı',): 0.00029810459677288224,
#  ('metr',): 3.794058504382138e-05,
#  ('dövlətlərinin',): 3.794058504382138e-05,
#  ('bəyin',): 9.214142082070906e-05,
#  ('infeksləri',): 1.0840167155377537e-05,
#  ('xarici',): 0.0007750719516094938,
#  ('insanların',): 4.8780752199198914e-05,
#  ('qaydada',): 0.00011382175513146413,
#  ('şumer',): 0.00010840167155377537,
#  ('daxili',): 0.00011382175513146413,
#  ('əsrin',): 0.001073176548382376,
#  ('gürcü',): 4.3360668621510146e-05,
#  ('əsrdə',): 0.0005203280234581218,
#  ('rəqmli',): 1.0840167155377537e-05,
#  ('öyrənilməsində',): 6.504100293226522e-05,
#  ('komissarlığına',): 1.0840167155377537e-05,
#  ('tututulurdu',): 1.0840167155377537e-05,
#  ('tapır',): 9.214142082070906e-05,
#  ('saxlamaq',): 6.504100293226522e-05,
#  ('vəsaitlərin',): 0.00022764351026292827,
#  ('on',): 0.00039566610117128004,
#  ('təyinedicilər',): 8.672133724302029e-05,
#  ('diapo',): 1.0840167155377537e-05,
#  ('gələcək',): 8.672133724302029e-05,
#  ('endirməkdən',): 1.0840167155377537e-05,
#  ('sərgilərindən',): 1.6260250733066305e-05,
#  ('sietl',): 1.0840167155377537e-05,
#  ('lenin',): 5.420083577688768e-05,
#  ('mil',): 2.710041788844384e-05,
#  ('olmaz',): 3.794058504382138e-05,
#  ('kolont',): 3.794058504382138e-05,
#  ('salyan',): 5.420083577688768e-05,
#  ('etdirilməsi',): 0.0001029815879760866,
#  ('lüğətlər',): 6.504100293226522e-05,
#  ('saatlarında',): 1.0840167155377537e-05,
#  ('cildlik',): 0.00013008200586453044,
#  ('yazisi',): 1.6260250733066305e-05,
#  ('printerlərədn',): 1.0840167155377537e-05,
#  ('verildi',): 6.504100293226522e-05,
#  ('yəni',): 0.0003197849310836373,
#  ('təşkili',): 0.0007967522859202489,
#  ('sesə',): 1.0840167155377537e-05,
#  ('bazar',): 2.710041788844384e-05,
#  ('qısa',): 0.0002547439281513721,
#  ('ifaların',): 1.0840167155377537e-05,
#  ('sovet',): 0.00044444685337047897,
#  ('arayış',): 4.3360668621510146e-05,
#  ('veryovkina',): 1.0840167155377537e-05,
#  ('məruzə',): 3.794058504382138e-05,
#  ('yaşünaslıqla',): 1.0840167155377537e-05,
#  ('təhkim',): 2.1680334310755073e-05,
#  ('zərdüşt',): 8.672133724302029e-05,
#  ('təyin',): 0.00019512300879679566,
#  ('müdir',): 5.962091935457645e-05,
#  ('tarixçilər',): 1.0840167155377537e-05,
#  ('mümtaz',): 2.1680334310755073e-05,
#  ('disk',): 0.00027642426246212717,
#  ('aparmaq',): 8.130125366533152e-05,
#  ('qanunu',): 8.130125366533152e-05,
#  ('tələbatlar',): 1.0840167155377537e-05,
#  ('qoruyub',): 3.252050146613261e-05,
#  ('sürətli',): 5.962091935457645e-05,
#  ('avtomatlaş',): 2.710041788844384e-05,
#  ('nəşrlərə',): 4.3360668621510146e-05,
#  ('yalnız',): 0.00039566610117128004,
#  ('uyğun',): 0.0004281866026374127,
#  ('biri',): 0.0007859121187648714,
#  ('sisteminin',): 0.0004173464354820351,
#  ('linqvist',): 4.8780752199198914e-05,
#  ('yaxud',): 0.00022764351026292827,
#  ('dəfə',): 0.0007154510322549174,
#  ('işləmək',): 6.504100293226522e-05,
#  ('edən',): 0.0014309020645098347,
#  ('səviy',): 2.710041788844384e-05,
#  ('mühüm',): 0.0008997338738963355,
#  ('kitablar',): 0.0006720903636334072,
#  ('nəhəng',): 8.672133724302029e-05,
#  ('göndərilirsə',): 1.0840167155377537e-05,
#  ('kataloq',): 0.0004173464354820351,
#  ('yusif',): 2.710041788844384e-05,
#  ('bazasında',): 0.00014634225659759673,
#  ('keçmiş',): 0.00024390376099599456,
#  ('formada',): 0.00022222342668523949,
#  ('formallaşdırılması',): 1.6260250733066305e-05,
#  ('aşağıda',): 4.8780752199198914e-05,
#  ('xassələrə',): 1.0840167155377537e-05,
#  ('fakültəsində',): 0.00019512300879679566,
#  ('aşağıdakılar',): 0.0001192418387091529,
#  ('sistemləri',): 0.0002059631759521732,
#  ('qosudarstvennoy',): 1.0840167155377537e-05,
#  ('biblio',): 0.0001355020894422192,
#  ('orqanları',): 9.756150439839783e-05,
#  ('ermənistan',): 4.3360668621510146e-05,
#  ('imkan',): 0.0004281866026374127,
#  ('uzun',): 0.0002547439281513721,
#  ('lakin',): 0.0004119263519043464,
#  ('kitabların',): 0.0004986476891473666,
#  ('kitabçalar',): 4.3360668621510146e-05,
#  ('əksinədir',): 1.0840167155377537e-05,
#  ('təsvirin',): 0.0001517623401752855,
#  ('rmişdir',): 0.00019512300879679566,
#  ('internetdə',): 2.1680334310755073e-05,
#  ('bankları',): 2.710041788844384e-05,
#  ('rusiya',): 0.0007804920351871826,
#  ('tutunun',): 0.0002059631759521732,
#  ('latviya',): 1.6260250733066305e-05,
#  ('nəşrləri',): 0.0004010861847489688,
#  ('çapedici',): 2.710041788844384e-05,
#  ('özundən',): 1.0840167155377537e-05,
#  ('kompleks',): 0.00018428284164141812,
#  ('mks',): 0.0006937706979441623,
#  ('səmərəli',): 0.0002384836774183058,
#  ('elmi',): 0.003159908725792552,
#  ('qəsəbə',): 0.00014092217301990797,
#  ('operatoru',): 1.0840167155377537e-05,
#  ('plərin',): 2.1680334310755073e-05,
#  ('mefodi',): 1.6260250733066305e-05,
#  ('özəlləşdirilməsi',): 1.6260250733066305e-05,
#  ('givc',): 1.0840167155377537e-05,
#  ('kağızın',): 5.962091935457645e-05,
#  ('ının',): 4.3360668621510146e-05,
#  ('lankaran',): 1.0840167155377537e-05,
#  ('təsdiq',): 0.0002872644296175047,
#  ('zalı',): 0.0002601640117290609,
#  ('elementləri',): 0.00014634225659759673,
#  ('toplanan',): 3.252050146613261e-05,
#  ('tezliklə',): 3.794058504382138e-05,
#  ('sənəd',): 0.0006341497785895859,
#  ('onlardakı',): 1.0840167155377537e-05,
#  ('mai',): 0.0006287296950118971,
#  ('çexiyada',): 1.0840167155377537e-05,
#  ('yaşünaslıq',): 0.0002005430923744844,
#  ('kompakt',): 9.214142082070906e-05,
#  ('emalı',): 0.00011382175513146413,
#  ('bürümə',): 1.0840167155377537e-05,
#  ('yazıçıları',): 4.8780752199198914e-05,
#  ('üzünü',): 5.962091935457645e-05,
#  ('qruplaşdırılmış',): 2.710041788844384e-05,
#  ('şəxs',): 0.00011382175513146413,
#  ('seçmə',): 0.00011382175513146413,
#  ('nəşrə',): 0.00012466192228684166,
#  ('hazırda',): 0.0005853690263903869,
#  ('belə',): 0.0007425514501433612,
#  ('barən',): 0.0002547439281513721,
#  ('yerinə',): 0.0006178895278565195,
#  ('tətbiqi',): 0.00029810459677288224,
#  ('yer',): 0.00027642426246212717,
#  ('məsi',): 5.420083577688768e-05,
#  ('region',): 7.588117008764276e-05,
#  ('cari',): 0.0005962091935457645,
#  ('fayl',): 7.046108650995399e-05,
#  ('siyahıya',): 2.1680334310755073e-05,
#  ('ç',): 9.214142082070906e-05,
#  ('şəbəkəsiz',): 1.0840167155377537e-05,
#  ('lazım',): 0.00017886275806372934,
#  ('sentyabr',): 0.00013008200586453044,
#  ('artmaqda',): 2.1680334310755073e-05,
#  ('ibn',): 4.3360668621510146e-05,
#  ('ümumdünya',): 0.0001029815879760866,
#  ('apöarılması',): 1.0840167155377537e-05,
#  ('ticarət',): 1.6260250733066305e-05,
#  ('tərkibinə',): 0.0002384836774183058,
#  ('sənədlərin',): 0.0008401129545417591,
#  ('şərqşünaslıq',): 2.710041788844384e-05,
#  ('kanallarla',): 1.0840167155377537e-05,
#  ('milyon',): 0.00024390376099599456,
#  ('funk',): 4.3360668621510146e-05,
#  ('məktəblərində',): 4.3360668621510146e-05,
#  ('çala',): 2.710041788844384e-05,
#  ('məktəb',): 0.00048238743841430033,
#  ('məbədlər',): 1.0840167155377537e-05,
#  ('ağ',): 1.0840167155377537e-05,
#  ('toplanmış',): 0.0001029815879760866,
#  ('bitməmişdir',): 1.0840167155377537e-05,
#  ('mərkəzinin',): 9.214142082070906e-05,
#  ('hazırlanan',): 7.588117008764276e-05,
#  ('korolenko',): 1.6260250733066305e-05,
#  ('toplusunun',): 2.710041788844384e-05,
#  ('görülmüş',): 2.710041788844384e-05,
#  ('zərif',): 1.6260250733066305e-05,
#  ('fondunda',): 0.0006016292771234532,
#  ('dəfələrlə',): 9.214142082070906e-05,
#  ('əsi',): 7.046108650995399e-05,
#  ('şəbəkələrinin',): 4.3360668621510146e-05,
#  ('məcburi',): 0.00044986693694816775,
#  ('ict',): 0.0007317112829879836,
#  ('çoxfunksiyalı',): 2.1680334310755073e-05,
#  ('kat',): 0.0001517623401752855,
#  ('hüquq',): 0.00022764351026292827,
#  ('kataloqa',): 8.672133724302029e-05,
#  ('almışdır',): 0.0005149079398804329,
#  ('arxitekturası',): 1.6260250733066305e-05,
#  ('öyrənilir',): 4.3360668621510146e-05,
#  ('bi',): 0.00037398576686052497,
#  ('ədəbiyyat',): 0.001192418387091529,
#  ('format',): 5.962091935457645e-05,
#  ('mədə',): 3.794058504382138e-05,
#  ('adını',): 0.0001680225909083518,
#  ('funksiyalarına',): 3.252050146613261e-05,
#  ('mübadiləsi',): 0.0002655840953067496,
#  ('kadr',): 8.672133724302029e-05,
#  ('yazmaq',): 4.3360668621510146e-05,
#  ('məzmunu',): 0.00024390376099599456,
#  ('oolan',): 1.0840167155377537e-05,
#  ('dəyişdirilir',): 1.6260250733066305e-05,
#  ('təşkil',): 0.001799467747792671,
#  ('başqalarının',): 6.504100293226522e-05,
#  ('kiçik',): 0.0002710041788844384,
#  ('rəsmi',): 0.00036314559970514746,
#  ('əhəmiyyət',): 0.0005203280234581218,
#  ('ii',): 0.00038482593401590253,
#  ('adil',): 1.0840167155377537e-05,
#  ('idilər',): 3.794058504382138e-05,
#  ('nüsxə',): 0.0009539347096732232,
#  ('komplekt',): 4.8780752199198914e-05,
#  ('kasiya',): 7.588117008764276e-05,
#  ('geniş',): 0.0008075924530756264,
#  ('fərmanı',): 0.00018970292521910688,
#  ('patent',): 0.0002384836774183058,
#  ('araşdırmalardan',): 1.0840167155377537e-05,
#  ('avropada',): 8.130125366533152e-05,
#  ('batçılar',): 1.6260250733066305e-05,
#  ('rilmişdir',): 2.710041788844384e-05,
#  ('zaman',): 0.00046070710410354526,
#  ('buraxılışların',): 1.6260250733066305e-05,
#  ('kitabxanalarından',): 8.130125366533152e-05,
#  ('standartda',): 3.252050146613261e-05,
#  ('kütləvi',): 0.0007371313665656725,
#  ('fərqləndirilir',): 0.00018428284164141812,
#  ('ardıcıllığının',): 1.6260250733066305e-05,
#  ('həyata',): 0.0012682995571791718,
#  ('məxsus',): 0.00014092217301990797,
#  ('qiymət',): 8.672133724302029e-05,
#  ('çoxsahəli',): 3.794058504382138e-05,
#  ('for',): 0.00014092217301990797,
#  ('edilməsini',): 4.3360668621510146e-05,
#  ('türk',): 0.0002547439281513721,
#  ('sadiqi',): 1.6260250733066305e-05,
#  ('əsrlərə',): 4.8780752199198914e-05,
#  ('prezident',): 0.0003902460175935913,
#  ('mərkəzi',): 0.001517623401752855,
#  ('şəxsi',): 0.0004281866026374127,
#  ('illərində',): 0.0004281866026374127,
#  ('yət',): 0.00022222342668523949,
#  ('fərqlənirlər',): 2.1680334310755073e-05,
#  ('terminini',): 3.252050146613261e-05,
#  ('dağılması',): 1.0840167155377537e-05,
#  ('qüsursuz',): 2.1680334310755073e-05,
#  ('xülasəsidir',): 2.1680334310755073e-05,
#  ('olunan',): 0.0008130125366533152,
#  ('keçirilidi',): 1.0840167155377537e-05,
#  ('arxiv',): 0.00029268451319519346,
#  ('materialdan',): 4.8780752199198914e-05,
#  ('zində',): 1.0840167155377537e-05,
#  ('səhifələrində',): 5.962091935457645e-05,
#  ('kvadrat',): 1.6260250733066305e-05,
#  ('əhalisi',): 4.8780752199198914e-05,
#  ('aparılmış',): 7.046108650995399e-05,
#  ('olunmağa',): 0.00010840167155377537,
#  ('çıxarılmış',): 3.794058504382138e-05,
#  ('dayanmaq',): 2.1680334310755073e-05,
#  ('ayrılmış',): 3.794058504382138e-05,
#  ('mksdə',): 1.0840167155377537e-05,
#  ('bazasının',): 8.130125366533152e-05,
#  ('alırdı',): 3.252050146613261e-05,
#  ('kolleksiyalarının',): 1.6260250733066305e-05,
#  ('kitabxanaşünaslığın',): 4.8780752199198914e-05,
#  ('onlarla',): 2.1680334310755073e-05,
#  ('istədiyi',): 1.0840167155377537e-05,
#  ('kompüter',): 0.0002655840953067496,
#  ('məqsəd',): 0.0002059631759521732,
#  ('məlumdur',): 7.588117008764276e-05,
#  ('maneələrinin',): 1.6260250733066305e-05,
#  ('prosedurlarla',): 1.0840167155377537e-05,
#  ('üçcildlik',): 2.710041788844384e-05,
#  ('müalicəyə',): 1.0840167155377537e-05,
#  ('yolları',): 7.046108650995399e-05,
#  ('ək',): 9.756150439839783e-05,
#  ('orta',): 0.0004390267697927902,
#  ('planlaşdırılması',): 7.046108650995399e-05,
#  ('ənənəvi',): 0.0002005430923744844,
#  ('ölkə',): 0.0004769673548366116,
#  ('əsasını',): 0.00016260250733066305,
#  ('standartlaşdırma',): 7.046108650995399e-05,
#  ('kimyəvi',): 5.962091935457645e-05,
#  ('kənd',): 0.0005799489428126982,
#  ('çıxarılması',): 8.672133724302029e-05,
#  ('texniki',): 0.000607049360701142,
#  ('qalınlığı',): 2.710041788844384e-05,
#  ('ideyasından',): 1.0840167155377537e-05,
#  ('işlədilir',): 8.130125366533152e-05,
#  ('x',): 9.756150439839783e-05,
#  ('insanın',): 7.588117008764276e-05,
#  ('gücləndirilmiş',): 1.0840167155377537e-05,
#  ('rləri',): 1.6260250733066305e-05,
#  ('əlaqənin',): 2.1680334310755073e-05,
#  ('dövri',): 0.0007913322023425601,
#  ('xiv',): 3.252050146613261e-05,
#  ('qarşıladılar',): 1.0840167155377537e-05,
#  ('losof',): 2.1680334310755073e-05,
#  ('tutur',): 0.00022764351026292827,
#  ('yartdığı',): 1.0840167155377537e-05,
#  ('güclü',): 5.962091935457645e-05,
#  ('bölmədən',): 4.8780752199198914e-05,
#  ('meydana',): 0.0005094878563027442,
#  ('bağlı',): 0.00044444685337047897,
#  ('işlərin',): 0.00010840167155377537,
#  ('tədqiqat',): 0.0002493238445736833,
#  ('təsiri',): 5.962091935457645e-05,
#  ('təazahür',): 1.0840167155377537e-05,
#  ('icbari',): 6.504100293226522e-05,
#  ('həkim',): 4.3360668621510146e-05,
#  ('habelə',): 0.0001029815879760866,
#  ('mərkəzləri',): 9.214142082070906e-05,
#  ('qiraətxananı',): 1.6260250733066305e-05,
#  ('nedicisi',): 1.0840167155377537e-05,
#  ('yüklənməsi',): 1.6260250733066305e-05,
#  ('nümayiş',): 3.252050146613261e-05,
#  ('avropa',): 0.00018970292521910688,
#  ('əsası',): 0.0002601640117290609,
#  ('əvvəlində',): 5.962091935457645e-05,
#  ('göstəricidir',): 4.3360668621510146e-05,
#  ('onlar',): 0.0004173464354820351,
#  ('birlikdə',): 0.00027642426246212717,
#  ('metodu',): 0.00011382175513146413,
#  ('əsərin',): 0.0003252050146613261,
#  ('bərdə',): 5.962091935457645e-05,
#  ('göstərirdi',): 0.0001517623401752855,
#  ('aka',): 3.252050146613261e-05,
#  ('repk',): 1.6260250733066305e-05,
#  ('mikrosənəd',): 2.1680334310755073e-05,
#  ('formalaşdırılması',): 0.00011382175513146413,
#  ('əlaqəyə',): 3.252050146613261e-05,
#  ('sonrakı',): 0.00013008200586453044,
#  ('əmək',): 0.0003197849310836373,
#  ('ofset',): 9.756150439839783e-05,
#  ('komitəsinə',): 2.710041788844384e-05,
#  ('nəşrlər',): 0.0005907891099680758,
#  ('ndan',): 0.00017344267448604058,
#  ('direkt',): 3.794058504382138e-05,
#  ('bilmədiyindən',): 1.6260250733066305e-05,
#  ('əla',): 7.046108650995399e-05,
#  ('rəhbərliyi',): 0.00010840167155377537,
#  ('kitabxanasının',): 0.0007750719516094938,
#  ('cartographic',): 1.0840167155377537e-05,
#  ('şəraitlə',): 1.0840167155377537e-05,
#  ('yacın',): 1.0840167155377537e-05,
#  ('neyroqruppa',): 1.0840167155377537e-05,
#  ('axında',): 1.6260250733066305e-05,
#  ('məhsulun',): 3.794058504382138e-05,
#  ...}

# %%
lambda1, lambda2, lambda3 = 0.1, 0.3, 0.6
def interpolated_perplexity(test_tokens, unigram_probs, bigram_counts, trigram_counts, unigram_counts):
    log_prob_sum = 0
    test_trigrams = build_ngrams(test_tokens, 3)
    total_unigrams = sum(unigram_counts.values())
    
    for trigram in test_trigrams:
        unigram_prob = unigram_probs.get((trigram[2],), 1e-6) / total_unigrams
        bigram_prob = (bigram_counts.get(trigram[1:], 0) + 1e-6) / (unigram_counts.get((trigram[1],), 0) + 1e-6)
        trigram_prob = (trigram_counts.get(trigram, 0) + 1e-6) / (bigram_counts.get(trigram[:2], 0) + 1e-6)
        
        prob = lambda1 * unigram_prob + lambda2 * bigram_prob + lambda3 * trigram_prob
        log_prob_sum += math.log(prob)
        
    return math.exp(-log_prob_sum / len(test_trigrams))

interpolated_perplexity(test_tokens, unigram_probs, bigram_counts, trigram_counts, unigram_counts)
# Out:
# 0.036485835273053116

# %%
trigram_counts
# Out:
# Counter({('EOS', 'EOS', 'EOS'): 102,
#          ('EOS', 'EOS', 'və'): 51,
#          ('və', 'EOS', 'EOS'): 42,
#          ('EOS', 'və', 'EOS'): 41,
#          ('EOS', 'və', 'və'): 21,
#          ('və', 'və', 'EOS'): 19,
#          ('EOS', 'ildə', 'EOS'): 15,
#          ('EOS', 'k', 'EOS'): 14,
#          ('EOS', 'EOS', 'k'): 12,
#          ('və', 'EOS', 'və'): 12,
#          ('EOS', 'və', 'ilə'): 11,
#          ('EOS', 'EOS', 'ilə'): 11,
#          ('EOS', 'bu', 'EOS'): 11,
#          ('və', 'və', 'və'): 11,
#          ('k', 'EOS', 'EOS'): 11,
#          ('EOS', 'informasiya', 'EOS'): 10,
#          ('EOS', 'EOS', 'n'): 10,
#          ('EOS', 'EOS', 'bu'): 10,
#          ('ildə', 'EOS', 'EOS'): 9,
#          ('EOS', 'EOS', 'bir'): 9,
#          ('EOS', 'EOS', 'nin'): 8,
#          ('ilə', 'EOS', 'EOS'): 8,
#          ('EOS', 'EOS', 'üçün'): 8,
#          ('mədəniyyət', 'EOS', 'EOS'): 8,
#          ('EOS', 'EOS', 'ist'): 8,
#          ('EOS', 'EOS', 'haqqında'): 8,
#          ('elmi', 'EOS', 'və'): 8,
#          ('EOS', 'ilə', 'EOS'): 8,
#          ('EOS', 'üçün', 'EOS'): 7,
#          ('və', 'EOS', 'azərbaycan'): 7,
#          ('ya', 'EOS', 'EOS'): 7,
#          ('EOS', 'ildən', 'EOS'): 7,
#          ('EOS', 'və', 'kitabxana'): 7,
#          ('EOS', 'EOS', 't'): 7,
#          ('edir', 'EOS', 'EOS'): 7,
#          ('EOS', 'EOS', 'ildə'): 7,
#          ('EOS', 'EOS', 'elmi'): 7,
#          ('EOS', 'kitabxana', 'EOS'): 7,
#          ('EOS', 'EOS', 'il'): 7,
#          ('EOS', 'EOS', 'ki'): 7,
#          ('EOS', 'EOS', 'informasiya'): 6,
#          ('və', 'haqqında', 'EOS'): 6,
#          ('EOS', 'kitab', 'EOS'): 6,
#          ('EOS', 'EOS', 'kitabxana'): 6,
#          ('EOS', 'və', 'üzrə'): 6,
#          ('kitabxana', 'EOS', 'və'): 6,
#          ('EOS', 'ist', 'EOS'): 6,
#          ('nin', 'EOS', 'EOS'): 6,
#          ('EOS', 'və', 'n'): 6,
#          ('EOS', 'EOS', 'kitab'): 6,
#          ('bir', 'EOS', 'EOS'): 6,
#          ('ilə', 'və', 'EOS'): 6,
#          ('haqqında', 'EOS', 'EOS'): 6,
#          ('bu', 'EOS', 'EOS'): 6,
#          ('EOS', 'milli', 'EOS'): 6,
#          ('EOS', 'ya', 'EOS'): 6,
#          ('də', 'və', 'EOS'): 5,
#          ('ildə', 'EOS', 'və'): 5,
#          ('EOS', 'ndən', 'EOS'): 5,
#          ('və', 'ildən', 'EOS'): 5,
#          ('EOS', 'EOS', 'kimi'): 5,
#          ('t', 'EOS', 'EOS'): 5,
#          ('bu', 'və', 'EOS'): 5,
#          ('EOS', 'olduğu', 'EOS'): 5,
#          ('və', 'EOS', 'k'): 5,
#          ('ildə', 'və', 'EOS'): 5,
#          ('EOS', 'b', 'EOS'): 5,
#          ('EOS', 'k', 'və'): 5,
#          ('EOS', 'EOS', 'azərbaycan'): 5,
#          ('EOS', 'EOS', 'da'): 5,
#          ('olan', 'EOS', 'EOS'): 5,
#          ('k', 'EOS', 'və'): 5,
#          ('EOS', 'təşkil', 'EOS'): 5,
#          ('EOS', 'dövlət', 'EOS'): 5,
#          ('informasiya', 'EOS', 'EOS'): 5,
#          ('onun', 'EOS', 'EOS'): 5,
#          ('EOS', 'kitab', 'və'): 5,
#          ('EOS', 'EOS', 'fəaliyyət'): 5,
#          ('EOS', 'EOS', 'milli'): 5,
#          ('və', 'EOS', 'fadə'): 5,
#          ('bu', 'EOS', 'və'): 5,
#          ('ən', 'və', 'EOS'): 5,
#          ('da', 'EOS', 'EOS'): 5,
#          ('EOS', 'EOS', 'ya'): 5,
#          ('kitab', 'EOS', 'EOS'): 5,
#          ('də', 'EOS', 'EOS'): 5,
#          ('EOS', 'bir', 'və'): 5,
#          ('b', 'EOS', 'EOS'): 4,
#          ('fəaliyyət', 'EOS', 'və'): 4,
#          ('və', 'ilə', 'EOS'): 4,
#          ('digər', 'və', 'EOS'): 4,
#          ('EOS', 'olan', 'və'): 4,
#          ('kitabxana', 'və', 'EOS'): 4,
#          ('EOS', 'ist', 'və'): 4,
#          ('EOS', 'EOS', 'uzun'): 4,
#          ('dövlət', 'EOS', 'EOS'): 4,
#          ('və', 'və', 'ist'): 4,
#          ('EOS', 'EOS', 'dövlət'): 4,
#          ('milli', 'və', 'EOS'): 4,
#          ('k', 'EOS', 'ildən'): 4,
#          ('EOS', 'böyük', 'EOS'): 4,
#          ('f', 'EOS', 'EOS'): 4,
#          ('EOS', 'EOS', 'nəşr'): 4,
#          ('və', 'EOS', 'üçün'): 4,
#          ('və', 'görə', 'EOS'): 4,
#          ('ist', 'və', 'EOS'): 4,
#          ('EOS', 'və', 'illərdə'): 4,
#          ('EOS', 'həmin', 'EOS'): 4,
#          ('EOS', 'EOS', 'görə'): 4,
#          ('EOS', 'EOS', 'həmin'): 4,
#          ('k', 'və', 'EOS'): 4,
#          ('EOS', 'kitab', 'k'): 4,
#          ('EOS', 'EOS', 's'): 4,
#          ('informasiya', 'və', 'EOS'): 4,
#          ('və', 'və', 'bu'): 4,
#          ('EOS', 'bir', 'EOS'): 4,
#          ('EOS', 'və', 'dövlət'): 4,
#          ('EOS', 'ya', 'və'): 4,
#          ('və', 't', 'EOS'): 4,
#          ('EOS', 'da', 'EOS'): 4,
#          ('n', 'EOS', 'EOS'): 4,
#          ('EOS', 'mədəniyyət', 'və'): 4,
#          ('və', 'EOS', 'kitab'): 4,
#          ('EOS', 'azərbaycan', 'EOS'): 4,
#          ('EOS', 'EOS', 'üzrə'): 4,
#          ('EOS', 'və', 'ildə'): 4,
#          ('EOS', 'kitabxana', 'və'): 4,
#          ('kitabxana', 'və', 'və'): 4,
#          ('kitabxana', 'EOS', 'EOS'): 4,
#          ('olan', 'EOS', 'və'): 4,
#          ('daxil', 'EOS', 'EOS'): 4,
#          ('EOS', 'EOS', 'də'): 4,
#          ('EOS', 'edilmişdir', 'EOS'): 4,
#          ('yeni', 'EOS', 'EOS'): 4,
#          ('belə', 'EOS', 'və'): 4,
#          ('inkişaf', 'EOS', 'EOS'): 4,
#          ('kitabxanası', 'və', 'EOS'): 4,
#          ('azərbaycan', 'EOS', 'EOS'): 4,
#          ('EOS', 'və', 'ndə'): 4,
#          ('EOS', 'EOS', 'çox'): 4,
#          ('EOS', 'və', 'bu'): 4,
#          ('EOS', 'də', 'EOS'): 4,
#          ('EOS', 'EOS', 'əsasında'): 4,
#          ('və', 'bu', 'EOS'): 4,
#          ('ildə', 'EOS', 'bu'): 4,
#          ('və', 'kitabxana', 'EOS'): 4,
#          ('EOS', 'et', 'EOS'): 4,
#          ('bir', 'və', 'EOS'): 4,
#          ('q', 'EOS', 'EOS'): 4,
#          ('milli', 'EOS', 'EOS'): 4,
#          ('və', 'EOS', 'bir'): 3,
#          ('EOS', 'ni', 'EOS'): 3,
#          ('EOS', 'və', 'üçün'): 3,
#          ('və', 'və', 'bilər'): 3,
#          ('EOS', 'malik', 'EOS'): 3,
#          ('ilk', 'EOS', 'EOS'): 3,
#          ('EOS', 'digər', 'EOS'): 3,
#          ('k', 'k', 'EOS'): 3,
#          ('ən', 'EOS', 'və'): 3,
#          ('EOS', 'EOS', 'o'): 3,
#          ('və', 'EOS', 'ist'): 3,
#          ('EOS', 'eht', 'EOS'): 3,
#          ('EOS', 'kimi', 'EOS'): 3,
#          ('yerinə', 'EOS', 'EOS'): 3,
#          ('EOS', 'EOS', 'ndən'): 3,
#          ('və', 'EOS', 'olmuşdur'): 3,
#          ('milli', 'EOS', 'və'): 3,
#          ('EOS', 'olan', 'EOS'): 3,
#          ('EOS', 'edilməsi', 'və'): 3,
#          ('üzrə', 'EOS', 'və'): 3,
#          ('və', 'EOS', 'vəsait'): 3,
#          ('kimi', 'EOS', 'ist'): 3,
#          ('EOS', 'fadə', 'EOS'): 3,
#          ('EOS', 'EOS', 'məqsədi'): 3,
#          ('EOS', 'əsasında', 'EOS'): 3,
#          ('təşkili', 'EOS', 'EOS'): 3,
#          ('EOS', 't', 'EOS'): 3,
#          ('böyük', 'EOS', 'və'): 3,
#          ('görə', 'EOS', 'EOS'): 3,
#          ('təhsil', 'EOS', 'EOS'): 3,
#          ('kimi', 'EOS', 'EOS'): 3,
#          ('və', 'EOS', 'ki'): 3,
#          ('EOS', 'edilməsi', 'EOS'): 3,
#          ('və', 'olmuşdur', 'EOS'): 3,
#          ('EOS', 'və', 'sahəsində'): 3,
#          ('ədəbiyyatla', 'EOS', 'EOS'): 3,
#          ('və', 'illərdə', 'və'): 3,
#          ('EOS', 'EOS', 'müxtəlif'): 3,
#          ('və', 'EOS', 'dövri'): 3,
#          ('EOS', 'müəyyən', 'EOS'): 3,
#          ('EOS', 'EOS', 'yeni'): 3,
#          ('və', 'kitabxanası', 'EOS'): 3,
#          ('və', 'EOS', 'öz'): 3,
#          ('EOS', 'EOS', 'b'): 3,
#          ('n', 'və', 'EOS'): 3,
#          ('EOS', 'texniki', 'EOS'): 3,
#          ('həm', 'EOS', 'EOS'): 3,
#          ('edilir', 'EOS', 'EOS'): 3,
#          ('həmin', 'EOS', 'EOS'): 3,
#          ('EOS', 'EOS', 'mədəniyyət'): 3,
#          ('vəsait', 'EOS', 'EOS'): 3,
#          ('mühüm', 'EOS', 'EOS'): 3,
#          ('EOS', 'tərt', 'EOS'): 3,
#          ('EOS', 'EOS', 'kitabların'): 3,
#          ('kimi', 'EOS', 'və'): 3,
#          ('və', 'EOS', 'ümumi'): 3,
#          ('EOS', 'edilmiş', 'və'): 3,
#          ('EOS', 'EOS', 'iş'): 3,
#          ('EOS', 'və', 'burada'): 3,
#          ('EOS', 'ən', 'EOS'): 3,
#          ('və', 'daxil', 'EOS'): 3,
#          ('EOS', 'EOS', 'şəkildə'): 3,
#          ('işlər', 'EOS', 'EOS'): 3,
#          ('EOS', 'm', 'və'): 3,
#          ('EOS', 'EOS', 'üzərində'): 3,
#          ('və', 'k', 'EOS'): 3,
#          ('EOS', 'EOS', 'yanaşı'): 3,
#          ('EOS', 'nin', 'EOS'): 3,
#          ('və', 'EOS', 'etdirən'): 3,
#          ('üçün', 'EOS', 'EOS'): 3,
#          ('kitablar', 'EOS', 'EOS'): 3,
#          ('və', 'digər', 'EOS'): 3,
#          ('adlanır', 'EOS', 'EOS'): 3,
#          ('EOS', 'hissəsi', 'EOS'): 3,
#          ('və', 'üzrə', 'EOS'): 3,
#          ('EOS', 'məlumat', 'EOS'): 3,
#          ('EOS', 'il', 'EOS'): 3,
#          ('digər', 'EOS', 'EOS'): 3,
#          ('n', 'k', 'EOS'): 3,
#          ('edilmişdir', 'EOS', 'EOS'): 3,
#          ('EOS', 'üzrə', 'EOS'): 3,
#          ('növü', 'EOS', 'EOS'): 3,
#          ('bir', 'EOS', 'və'): 3,
#          ('EOS', 'və', 'k'): 3,
#          ('və', 'ildə', 'EOS'): 3,
#          ('ildən', 'EOS', 'EOS'): 3,
#          ('EOS', 'EOS', 'digər'): 3,
#          ('EOS', 'və', 'haqqında'): 3,
#          ('sonra', 'EOS', 'EOS'): 3,
#          ('və', 'və', 'respublika'): 3,
#          ('EOS', 'bütün', 'EOS'): 3,
#          ('və', 'fəaliyyət', 'EOS'): 3,
#          ('EOS', 'ilə', 'və'): 3,
#          ('elmi', 'EOS', 'EOS'): 3,
#          ('EOS', 'əsas', 'və'): 3,
#          ('ilə', 'k', 'və'): 3,
#          ('edir', 'EOS', 'və'): 3,
#          ('EOS', 'mədəniyyət', 'EOS'): 3,
#          ('EOS', 'm', 'EOS'): 3,
#          ('kitabı', 'EOS', 'EOS'): 3,
#          ('EOS', 'EOS', 'olan'): 3,
#          ('həmin', 'EOS', 'və'): 3,
#          ('EOS', 'EOS', 'həmçinin'): 3,
#          ('isə', 'və', 'EOS'): 3,
#          ('EOS', 'EOS', 'cümlədən'): 3,
#          ('yanın', 'EOS', 'EOS'): 3,
#          ('k', 'ya', 'EOS'): 3,
#          ('üçün', 'EOS', 'informasiya'): 3,
#          ('EOS', 'EOS', 'təşkil'): 3,
#          ('və', 'EOS', 'edilir'): 3,
#          ('EOS', 'və', 'bütün'): 3,
#          ('ist', 'EOS', 'və'): 3,
#          ('il', 'EOS', 'EOS'): 3,
#          ('ya', 'və', 'EOS'): 3,
#          ('üzrə', 'və', 'və'): 3,
#          ('və', 'olan', 'EOS'): 3,
#          ('işt', 'EOS', 'EOS'): 3,
#          ('və', 'EOS', 'kimi'): 3,
#          ('ildə', 'k', 'EOS'): 3,
#          ('EOS', 'EOS', 'təhsil'): 3,
#          ('EOS', 'k', 'informasiya'): 3,
#          ('EOS', 'elmi', 'EOS'): 3,
#          ('yeni', 'ilə', 'EOS'): 3,
#          ('kitabxana', 'ilə', 'EOS'): 3,
#          ('respublika', 'EOS', 'EOS'): 3,
#          ('informasiya', 'k', 'EOS'): 3,
#          ('EOS', 'və', 'kitab'): 3,
#          ('həyata', 'EOS', 'EOS'): 3,
#          ('olunan', 'və', 'və'): 3,
#          ('EOS', 'EOS', 'beynəlxalq'): 3,
#          ('EOS', 'kitabxanaçı', 'və'): 3,
#          ('EOS', 'EOS', 'uşaq'): 3,
#          ('əsasında', 'EOS', 'EOS'): 3,
#          ('və', 'EOS', 'daha'): 3,
#          ('çap', 'və', 'EOS'): 3,
#          ('təmin', 'EOS', 'EOS'): 3,
#          ('fondu', 'EOS', 'EOS'): 3,
#          ('və', 'ndən', 'EOS'): 3,
#          ('EOS', 'sahəsində', 'EOS'): 3,
#          ('əks', 'EOS', 'EOS'): 3,
#          ('EOS', 'sonra', 'EOS'): 3,
#          ('EOS', 'n', 'EOS'): 3,
#          ('EOS', 'və', 'azərbaycan'): 3,
#          ('görə', 'EOS', 'və'): 3,
#          ('EOS', 'EOS', 'illərdə'): 3,
#          ('EOS', 'ali', 'EOS'): 3,
#          ('edilmiş', 'EOS', 'EOS'): 3,
#          ('EOS', 'kitabxananın', 'və'): 3,
#          ('və', 'EOS', 'nin'): 3,
#          ('və', 'və', 'mədəniyyət'): 3,
#          ('EOS', 'rayon', 'EOS'): 3,
#          ('EOS', 'EOS', 'v'): 3,
#          ('üçün', 'və', 'EOS'): 3,
#          ('və', 'EOS', 'elmi'): 3,
#          ('məlumatların', 'EOS', 'EOS'): 3,
#          ('EOS', 'EOS', 'xarici'): 3,
#          ('EOS', 'uzun', 'və'): 3,
#          ('EOS', 'EOS', 'öz'): 3,
#          ('xidmət', 'və', 'EOS'): 3,
#          ('və', 'azərbaycan', 'EOS'): 3,
#          ('azərbaycanı', 'EOS', 'EOS'): 3,
#          ('ya', 'EOS', 'və'): 3,
#          ('nəşr', 'EOS', 'EOS'): 3,
#          ('k', 'b', 'EOS'): 2,
#          ('və', 'haqqında', 'uşaq'): 2,
#          ('EOS', 'EOS', 'adı'): 2,
#          ('EOS', 'şəhər', 'edilən'): 2,
#          ('yet', 'EOS', 'EOS'): 2,
#          ('EOS', 'və', 'resursların'): 2,
#          ('EOS', 'ilk', 'EOS'): 2,
#          ('EOS', 'etməkdən', 'EOS'): 2,
#          ('və', 'yenidən', 'və'): 2,
#          ('EOS', 'və', 'təsdiq'): 2,
#          ('çap', 'EOS', 'haqqında'): 2,
#          ('indiki', 'ildə', 'və'): 2,
#          ('nin', 'informasiya', 'və'): 2,
#          ('ədəbiyyat', 'ndən', 'EOS'): 2,
#          ('informasiya', 'və', 'n'): 2,
#          ('k', 'yası', 'EOS'): 2,
#          ('k', 'EOS', 'olunmağa'): 2,
#          ('və', 'belə', 'EOS'): 2,
#          ('EOS', 'illərdə', 'EOS'): 2,
#          ('s', 'və', 'əsas'): 2,
#          ('burada', 'EOS', 'EOS'): 2,
#          ('EOS', 'kitabxana', 'n'): 2,
#          ('n', 'dövlət', 'EOS'): 2,
#          ('ildə', 'EOS', 'çap'): 2,
#          ('EOS', 'olduğu', 'və'): 2,
#          ('EOS', 'fondu', 'kitabxana'): 2,
#          ('də', 'EOS', 'və'): 2,
#          ('EOS', 'və', 'kütləvi'): 2,
#          ('ildən', 'və', 'EOS'): 2,
#          ('kimi', 'EOS', 'kitabxana'): 2,
#          ('ist', 'EOS', 'EOS'): 2,
#          ('EOS', 'daxildir', 'EOS'): 2,
#          ('k', 'EOS', 'kitabxana'): 2,
#          ('və', 'uyğun', 'n'): 2,
#          ('bir', 'EOS', 'sənədin'): 2,
#          ('adı', 'EOS', 'EOS'): 2,
#          ('EOS', 'il', 'şəhər'): 2,
#          ('EOS', 'əlyazma', 'və'): 2,
#          ('informasiya', 'və', 'ilə'): 2,
#          ('ilə', 'olan', 'EOS'): 2,
#          ('EOS', 'və', 'ya'): 2,
#          ('EOS', 't', 'avtomatlaşdırılmış'): 2,
#          ('də', 'EOS', 'n'): 2,
#          ('ildə', 'və', 'b'): 2,
#          ('təşkilat', 'EOS', 'EOS'): 2,
#          ('EOS', 'xv', 'EOS'): 2,
#          ('EOS', 'milli', 'başlayaraq'): 2,
#          ('EOS', 'EOS', 'yası'): 2,
#          ('kimi', 'EOS', 'nəşr'): 2,
#          ('gəlib', 'və', 'verilir'): 2,
#          ('kitabxana', 'təsviri', 'və'): 2,
#          ('m', 'EOS', 'bu'): 2,
#          ('bir', 's', 'EOS'): 2,
#          ('olmuşdur', 'üzrə', 'EOS'): 2,
#          ('kitabxananın', 's', 'EOS'): 2,
#          ('ilə', 'və', 'mədəniyyət'): 2,
#          ('EOS', 'ist', 'onların'): 2,
#          ('EOS', 'informasiya', 'və'): 2,
#          ('və', 'dilində', 'EOS'): 2,
#          ('dilində', 'EOS', 'və'): 2,
#          ('v', 'və', 'EOS'): 2,
#          ('elektron', 'və', 'fəaliyyət'): 2,
#          ('olunmuşdur', 'ilə', 'ilə'): 2,
#          ('ilə', 'və', 'kitab'): 2,
#          ('əsasən', 'və', 'kitabxana'): 2,
#          ('EOS', 'dövlət', 'min'): 2,
#          ('və', 'fadə', 'EOS'): 2,
#          ('EOS', 'ya', 'fadə'): 2,
#          ('ümumi', 'EOS', 'EOS'): 2,
#          ('adına', 'EOS', 'EOS'): 2,
#          ('də', 'ilə', 'EOS'): 2,
#          ('EOS', 'və', 'müəllif'): 2,
#          ('və', 'müəllif', 'EOS'): 2,
#          ('bu', 'və', 'ilə'): 2,
#          ('EOS', 'edilən', 'EOS'): 2,
#          ('EOS', 'EOS', 'əlaqəyə'): 2,
#          ('əlyazma', 'EOS', 'EOS'): 2,
#          ('hər', 'EOS', 'EOS'): 2,
#          ('EOS', 'və', 'bir'): 2,
#          ('EOS', 'ibarət', 'və'): 2,
#          ('ilk', 'k', 'EOS'): 2,
#          ('ibarət', 'EOS', 'və'): 2,
#          ('EOS', 'az', 'EOS'): 2,
#          ('özündə', 'EOS', 'EOS'): 2,
#          ('EOS', 'və', 'qravür'): 2,
#          ('EOS', 'ilk', 'və'): 2,
#          ('k', 'n', 'olan'): 2,
#          ('yaradılmış', 'EOS', 'nın'): 2,
#          ('qaydada', 'EOS', 'EOS'): 2,
#          ('EOS', 'analit', 'informasiya'): 2,
#          ('s', 'və', 'EOS'): 2,
#          ('EOS', 'və', 'görə'): 2,
#          ('və', 'edir', 'azərbaycan'): 2,
#          ('və', 'ist', 'edir'): 2,
#          ('EOS', 'sonralar', 'EOS'): 2,
#          ('ndə', 'EOS', 'EOS'): 2,
#          ('idarə', 'EOS', 'EOS'): 2,
#          ('və', 'və', 'nin'): 2,
#          ('mədəniyyət', 'və', 'və'): 2,
#          ('və', 'və', 'əsərlərinin'): 2,
#          ('və', 'onun', 'EOS'): 2,
#          ('ildən', 'EOS', 'və'): 2,
#          ('audiovizual', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'edilməsi'): 2,
#          ('k', 'fəaliyyət', 'EOS'): 2,
#          ('olan', 'min', 'və'): 2,
#          ('kitabxana', 'olan', 'EOS'): 2,
#          ('bu', 'yaradılması', 'EOS'): 2,
#          ('k', 'EOS', 'v'): 2,
#          ('üçün', 'EOS', 'də'): 2,
#          ('maşınla', 'EOS', 'EOS'): 2,
#          ('çox', 'və', 'EOS'): 2,
#          ('və', 'EOS', 'da'): 2,
#          ('ibarətdir', 'və', 'EOS'): 2,
#          ('və', 'EOS', 'müstəqil'): 2,
#          ('biliklərin', 'EOS', 'EOS'): 2,
#          ('EOS', 'maddi', 'EOS'): 2,
#          ('mərkəzi', 'və', 'EOS'): 2,
#          ('EOS', 'fəaliyyət', 'və'): 2,
#          ('və', 'əsərləri', 'və'): 2,
#          ('EOS', 'EOS', 'yaradılmış'): 2,
#          ('klaviatura', 'EOS', 'EOS'): 2,
#          ('EOS', 'və', 'dair'): 2,
#          ('dövri', 'EOS', 'EOS'): 2,
#          ('EOS', 'şəxsi', 'EOS'): 2,
#          ('və', 'ki', 'EOS'): 2,
#          ('mindən', 'EOS', 'EOS'): 2,
#          ('rilməsi', 'və', 'EOS'): 2,
#          ('EOS', 'tədqiq', 'EOS'): 2,
#          ('EOS', 'bu', 'və'): 2,
#          ('və', 'ilə', 'kitabxanasından'): 2,
#          ('uşaq', 'EOS', 'EOS'): 2,
#          ('dissertasiyalar', 'EOS', 'EOS'): 2,
#          ('kitab', 'ist', 'EOS'): 2,
#          ('EOS', 'olunur', 'və'): 2,
#          ('və', 'EOS', 'i'): 2,
#          ('və', 'olar', 'EOS'): 2,
#          ('ki', 'EOS', 'EOS'): 2,
#          ('EOS', 'yeni', 'EOS'): 2,
#          ('ndən', 'milli', 'və'): 2,
#          ('və', 'əks', 'EOS'): 2,
#          ('EOS', 'ildə', 'və'): 2,
#          ('lazımdır', 'EOS', 'EOS'): 2,
#          ('kitabxanaları', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'tədris'): 2,
#          ('akademik', 'EOS', 'EOS'): 2,
#          ('EOS', 'və', 'daha'): 2,
#          ('və', 'nəzərdə', 'n'): 2,
#          ('EOS', 'EOS', 'adlı'): 2,
#          ('EOS', 'EOS', 'vəsaitlər'): 2,
#          ('və', 'və', 'informasiya'): 2,
#          ('və', 'informasiya', 'ilə'): 2,
#          ('EOS', 'EOS', 'xüsusi'): 2,
#          ('EOS', 'haqqında', 'və'): 2,
#          ('kitabxana', 'qeyd', 'EOS'): 2,
#          ('və', 'EOS', 'adına'): 2,
#          ('EOS', 'dissertasiya', 'EOS'): 2,
#          ('davam', 'EOS', 'k'): 2,
#          ('k', 'və', 'mürəkkəb'): 2,
#          ('EOS', 'informasiyanın', 'EOS'): 2,
#          ('EOS', 'ərzində', 'EOS'): 2,
#          ('EOS', 'mədəniyyət', 'kimi'): 2,
#          ('olmuşdur', 'ilə', 'EOS'): 2,
#          ('və', 'EOS', 'yeni'): 2,
#          ('kitabxana', 'EOS', 'n'): 2,
#          ('EOS', 'ilə', 'bir'): 2,
#          ('informasiyanın', 'və', 'və'): 2,
#          ('EOS', 'və', 'da'): 2,
#          ('və', 'EOS', 'müdiri'): 2,
#          ('EOS', 'EOS', 'mütaliə'): 2,
#          ('EOS', 'illərdə', 'milli'): 2,
#          ('EOS', 'EOS', 'q'): 2,
#          ('EOS', 'EOS', 'ə'): 2,
#          ('ilə', 'EOS', 'olunmuşdur'): 2,
#          ('EOS', 'azərbaycan', 'o'): 2,
#          ('xidmət', 'EOS', 'və'): 2,
#          ('lazımdır', 'EOS', 'haqqında'): 2,
#          ('EOS', 'və', 'xarici'): 2,
#          ('kimi', 'fadə', 'EOS'): 2,
#          ('nin', 'milli', 'EOS'): 2,
#          ('EOS', 'ya', 'na'): 2,
#          ('çap', 'EOS', 'EOS'): 2,
#          ('EOS', 'elektron', 'EOS'): 2,
#          ('k', 'EOS', 'bağlı'): 2,
#          ('və', 'ndə', 'və'): 2,
#          ('və', 'EOS', 'ədəbiyyat'): 2,
#          ('yası', 'EOS', 'EOS'): 2,
#          ('və', 'burada', 'və'): 2,
#          ('EOS', 'bütün', 'bir'): 2,
#          ('üzrə', 'son', 'EOS'): 2,
#          ('yası', 'EOS', 'kitabxana'): 2,
#          ('EOS', 'n', 'azərbaycan'): 2,
#          ('EOS', 'EOS', 'kitabxanaçılıq'): 2,
#          ('EOS', 'EOS', 'tərtər'): 2,
#          ('mk', 'EOS', 'və'): 2,
#          ('EOS', 'və', 'daxil'): 2,
#          ('olan', 'və', 'EOS'): 2,
#          ('xüsusi', 'EOS', 'EOS'): 2,
#          ('EOS', 'min', 'EOS'): 2,
#          ('isə', 'EOS', 'və'): 2,
#          ('EOS', 'və', 'çox'): 2,
#          ('EOS', 'EOS', 'malik'): 2,
#          ('və', 'bilər', 'və'): 2,
#          ('texniki', 'və', 'EOS'): 2,
#          ('EOS', 'obyekt', 'bir'): 2,
#          ('və', 'və', 'is'): 2,
#          ('EOS', 'vəzifələri', 't'): 2,
#          ('EOS', 'EOS', 'ali'): 2,
#          ('k', 'ildə', 'ilə'): 2,
#          ('sənədlər', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'etməyə'): 2,
#          ('EOS', 'sadi', 'EOS'): 2,
#          ('mərkəzi', 'EOS', 'ilə'): 2,
#          ('EOS', 'ərəb', 'EOS'): 2,
#          ('k', 'kitabxana', 'və'): 2,
#          ('olunur', 'nin', 'və'): 2,
#          ('EOS', 'EOS', 'olunmuş'): 2,
#          ('EOS', 'ildə', 'ümumi'): 2,
#          ('v', 'olaraq', 'EOS'): 2,
#          ('olaraq', 'EOS', 'EOS'): 2,
#          ('əsasında', 'ya', 'ilə'): 2,
#          ('EOS', 'EOS', 'sənədin'): 2,
#          ('EOS', 'və', 'axtarışın'): 2,
#          ('nəzərdə', 'EOS', 'EOS'): 2,
#          ('təhlil', 'EOS', 'EOS'): 2,
#          ('şəkildə', 'üzrə', 'EOS'): 2,
#          ('tərt', 'və', 'başqa'): 2,
#          ('EOS', 'n', 'bir'): 2,
#          ('bütün', 'və', 'EOS'): 2,
#          ('və', 'üçün', 'kitabxana'): 2,
#          ('EOS', 'idi', 'və'): 2,
#          ('sənədlərin', 'kitabxana', 'EOS'): 2,
#          ('EOS', 't', 'informasiya'): 2,
#          ('EOS', 'olmuş', 'və'): 2,
#          ('və', 'indiki', 'EOS'): 2,
#          ('EOS', 'və', 'azərbaycanda'): 2,
#          ('yasının', 'və', 'EOS'): 2,
#          ('EOS', 'və', 'ölkədə'): 2,
#          ('EOS', 't', 'nin'): 2,
#          ('əsrin', 'EOS', 'və'): 2,
#          ('EOS', 'bir', 'ildə'): 2,
#          ('ist', 'EOS', 'bu'): 2,
#          ('EOS', 'və', 't'): 2,
#          ('eht', 'və', 'EOS'): 2,
#          ('və', 'EOS', 'tərt'): 2,
#          ('ndən', 'və', 'və'): 2,
#          ('bu', 'EOS', 'jurnal'): 2,
#          ('ildə', 'EOS', 'k'): 2,
#          ('illərdə', 'EOS', 'EOS'): 2,
#          ('bütün', 'EOS', 'EOS'): 2,
#          ('k', 'EOS', 'informasiya'): 2,
#          ('və', 'ilə', 'ist'): 2,
#          ('bir', 'kitabxana', 'EOS'): 2,
#          ('və', 'yeni', 'EOS'): 2,
#          ('bütün', 'EOS', 'və'): 2,
#          ('edərək', 'EOS', 'və'): 2,
#          ('əsərləri', 'və', 'üzrə'): 2,
#          ('EOS', 'asılı', 'edərək'): 2,
#          ('EOS', 'EOS', 'asılı'): 2,
#          ('və', 'öz', 'EOS'): 2,
#          ('yüksək', 'və', 'və'): 2,
#          ('EOS', 'EOS', 'olmuşdur'): 2,
#          ('EOS', 'üçün', 'ya'): 2,
#          ('EOS', 'və', 'analit'): 2,
#          ('EOS', 'öyrənilməsi', 'milli'): 2,
#          ('s', 'və', 'ilə'): 2,
#          ('sahəvi', 'EOS', 'EOS'): 2,
#          ('ki', 'kitab', 'və'): 2,
#          ('EOS', 'EOS', 'dünyanın'): 2,
#          ('kütləvi', 'EOS', 'EOS'): 2,
#          ('kollekt', 'EOS', 'və'): 2,
#          ('məqsədilə', 'EOS', 'EOS'): 2,
#          ('konkret', 'EOS', 'EOS'): 2,
#          ('ya', 'üzrə', 'EOS'): 2,
#          ('dair', 'EOS', 'və'): 2,
#          ('EOS', 'və', 'ölkələri'): 2,
#          ('EOS', 'EOS', 'yerinə'): 2,
#          ('ist', 'yaradılmışdır', 'EOS'): 2,
#          ('müxtəlif', 'olan', 'EOS'): 2,
#          ('EOS', 'nəşri', 'bir'): 2,
#          ('nəşri', 'bir', 'EOS'): 2,
#          ('k', 'ilə', 'EOS'): 2,
#          ('ildə', 'ya', 'EOS'): 2,
#          ('olunmuş', 'təcrübi', 'EOS'): 2,
#          ('EOS', 'EOS', 'gələcək'): 2,
#          ('a', 'EOS', 'və'): 2,
#          ('və', 'EOS', 'bütün'): 2,
#          ('mk', 'EOS', 'EOS'): 2,
#          ('və', 'EOS', 'stat'): 2,
#          ('xidmət', 'ya', 'EOS'): 2,
#          ('və', 'EOS', 'olan'): 2,
#          ('EOS', 'və', 'əməkdaşlıq'): 2,
#          ('əsrin', 'və', 'kitab'): 2,
#          ('EOS', 'edir', 'EOS'): 2,
#          ('EOS', 'və', 'q'): 2,
#          ('EOS', 'k', 'olan'): 2,
#          ('və', 'qeyd', 'bib'): 2,
#          ('min', 'EOS', 'EOS'): 2,
#          ('çap', 'uşaq', 'EOS'): 2,
#          ('eləcə', 'və', 'EOS'): 2,
#          ('nin', 'bu', 'EOS'): 2,
#          ('üçün', 'ya', 'respublikasının'): 2,
#          ('EOS', 'haqqında', 'EOS'): 2,
#          ('EOS', 'EOS', 'keçirilir'): 2,
#          ('k', 'yet', 'isə'): 2,
#          ('EOS', 'azərbaycanda', 'EOS'): 2,
#          ('k', 'EOS', 'həm'): 2,
#          ('bakı', 'EOS', 'EOS'): 2,
#          ('inkişaf', 'EOS', 'və'): 2,
#          ('EOS', 'həmin', 'və'): 2,
#          ('s', 'kitabxana', 'EOS'): 2,
#          ('çox', 'EOS', 'əlavə'): 2,
#          ('t', 'nin', 'EOS'): 2,
#          ('azərbaycan', 'EOS', 'və'): 2,
#          ('və', 'ilk', 'EOS'): 2,
#          ('EOS', 'aid', 'üzrə'): 2,
#          ('EOS', 'çox', 'EOS'): 2,
#          ('EOS', 'EOS', 'təsvir'): 2,
#          ('EOS', 'həyata', 'mədəniyyət'): 2,
#          ('maarifpərvər', 'EOS', 'EOS'): 2,
#          ('EOS', 'respublika', 'təşkil'): 2,
#          ('və', 'azərbaycanda', 'EOS'): 2,
#          ('və', 'tərkibinə', 'müxtəlif'): 2,
#          ('və', 'ist', 'və'): 2,
#          ('EOS', 'əsas', 'EOS'): 2,
#          ('EOS', 'k', 'illərdə'): 2,
#          ('EOS', 'kitabxananın', 'EOS'): 2,
#          ('na', 'bu', 'kimi'): 2,
#          ('müəyyən', 'EOS', 'EOS'): 2,
#          ('EOS', 'v', 'ölkələrin'): 2,
#          ('uzun', 'EOS', 'EOS'): 2,
#          ('EOS', 'bu', 'milli'): 2,
#          ('EOS', 'EOS', 'sahəsində'): 2,
#          ('alim', 'EOS', 'və'): 2,
#          ('k', 'EOS', 'üçün'): 2,
#          ('EOS', 'dünya', 'ilə'): 2,
#          ('və', 'bir', 'EOS'): 2,
#          ('tərt', 'və', 'EOS'): 2,
#          ('EOS', 'informasiya', 'ist'): 2,
#          ('k', 'a', 'EOS'): 2,
#          ('kitabxanalar', 'EOS', 'və'): 2,
#          ('və', 'kitabxana', 'və'): 2,
#          ('ildə', 'EOS', 'kitabxananın'): 2,
#          ('EOS', 'EOS', 'mərkəzi'): 2,
#          ('üçün', 'ki', 'EOS'): 2,
#          ('kitab', 'EOS', 'ildən'): 2,
#          ('EOS', 'və', 'na'): 2,
#          ('dövlət', 'EOS', 'və'): 2,
#          ('EOS', 'belə', 'nin'): 2,
#          ('EOS', 'ilə', 'olaraq'): 2,
#          ('ildən', 'və', 'və'): 2,
#          ('və', 'və', 'üzrə'): 2,
#          ('EOS', 'nüsxə', 'ki'): 2,
#          ('EOS', 'qanuna', 'və'): 2,
#          ('EOS', 'p', 'EOS'): 2,
#          ('da', 'fəaliyyət', 'EOS'): 2,
#          ('sənədlərin', 'EOS', 'k'): 2,
#          ('yazının', 'dövlət', 'EOS'): 2,
#          ('üçün', 'bir', 'EOS'): 2,
#          ('EOS', 'bu', 'elmi'): 2,
#          ('və', 'EOS', 'olduğu'): 2,
#          ('EOS', 'təcrübəsi', 'EOS'): 2,
#          ('EOS', 'EOS', 'ni'): 2,
#          ('EOS', 'və', 'də'): 2,
#          ('EOS', 'bir', 'ist'): 2,
#          ('həmin', 'informasiya', 'EOS'): 2,
#          ('EOS', 'EOS', 'mai'): 2,
#          ('tədris', 'EOS', 'və'): 2,
#          ('və', 'EOS', 'dövlət'): 2,
#          ('bir', 'metodik', 'milli'): 2,
#          ('və', 'universitet', 'dair'): 2,
#          ('göstəricinin', 'bir', 'EOS'): 2,
#          ('EOS', 'aid', 'EOS'): 2,
#          ('isə', 'EOS', 'EOS'): 2,
#          ('daxili', 'və', 'n'): 2,
#          ('üçün', 'EOS', 'ilə'): 2,
#          ('müəyyən', 'EOS', 'və'): 2,
#          ('EOS', 'və', 'bazalarının'): 2,
#          ('və', 'n', 'informasiya'): 2,
#          ('işinin', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'məlumat'): 2,
#          ('keçirilir', 'EOS', 'EOS'): 2,
#          ('elmi', 'n', 'EOS'): 2,
#          ('EOS', 'EOS', 'əhatə'): 2,
#          ('EOS', 'ilə', 'çap'): 2,
#          ('ki', 'b', 'EOS'): 2,
#          ('s', 'EOS', 'EOS'): 2,
#          ('üçün', 'EOS', 'bu'): 2,
#          ('adda', 'EOS', 'və'): 2,
#          ('EOS', 'və', 'fondunun'): 2,
#          ('EOS', 'və', 'yaradılmış'): 2,
#          ('EOS', 'fondu', 'çox'): 2,
#          ('EOS', 'mövzu', 'və'): 2,
#          ('EOS', 'adına', 'EOS'): 2,
#          ('k', 'EOS', 'ildə'): 2,
#          ('bütün', 'EOS', 'e'): 2,
#          ('kitab', 'bir', 'EOS'): 2,
#          ('hökmdarı', 'EOS', 'EOS'): 2,
#          ('və', 'EOS', 'yunesko'): 2,
#          ('və', 'ist', 'EOS'): 2,
#          ('lövhə', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'verilənlər'): 2,
#          ('EOS', 'və', 'hər'): 2,
#          ('tərt', 'EOS', 'və'): 2,
#          ('və', 'də', 'EOS'): 2,
#          ('ya', 'EOS', 'k'): 2,
#          ('göstəricilər', 'EOS', 'EOS'): 2,
#          ('EOS', 'və', 'göstərir'): 2,
#          ('adına', 'n', 'EOS'): 2,
#          ('EOS', 'sıra', 'EOS'): 2,
#          ('malikdir', 'EOS', 'da'): 2,
#          ('EOS', 'cəmiyyət', 'informasiya'): 2,
#          ('əsr', 'EOS', 'EOS'): 2,
#          ('kitabxanalarının', 'və', 'EOS'): 2,
#          ('EOS', 'təşkil', 'edilmişdir'): 2,
#          ('ki', 'ndən', 'EOS'): 2,
#          ('daxil', 'və', 'EOS'): 2,
#          ('EOS', 'üçün', 'və'): 2,
#          ('EOS', 'kənd', 'bir'): 2,
#          ('materialların', 'EOS', 'EOS'): 2,
#          ('yanaşı', 'EOS', 'EOS'): 2,
#          ('EOS', 'alimi', 'EOS'): 2,
#          ('ya', 'kitab', 'n'): 2,
#          ('EOS', 'beynəlxalq', 'EOS'): 2,
#          ('EOS', 'bir', 'idi'): 2,
#          ('EOS', 'kitab', 'görə'): 2,
#          ('EOS', 'EOS', 'dövri'): 2,
#          ('bütün', 'EOS', 'kitabxana'): 2,
#          ('elmləri', 'EOS', 'EOS'): 2,
#          ('imkan', 'bütün', 'EOS'): 2,
#          ('EOS', 'və', 'yaradılması'): 2,
#          ('EOS', 'çap', 'EOS'): 2,
#          ('EOS', 'EOS', 'komitəsinin'): 2,
#          ('kitabxana', 'EOS', 'kitab'): 2,
#          ('EOS', 'jurnalı', 'EOS'): 2,
#          ('EOS', 'son', 'EOS'): 2,
#          ('infor', 'EOS', 'EOS'): 2,
#          ('EOS', 'etdirən', 'EOS'): 2,
#          ('k', 'EOS', 'adına'): 2,
#          ('EOS', 'milli', 'münasibət'): 2,
#          ('EOS', 'və', 'məcburi'): 2,
#          ('kitab', 'prezident', 'EOS'): 2,
#          ('EOS', 'kitab', 'ildə'): 2,
#          ('EOS', 'bakı', 'EOS'): 2,
#          ('beynəlxalq', 'etmişdir', 'EOS'): 2,
#          ('prosesi', 'EOS', 'və'): 2,
#          ('EOS', 'və', 'qısa'): 2,
#          ('ildə', 'və', 'görə'): 2,
#          ('dünyanın', 'EOS', 'EOS'): 2,
#          ('EOS', 'həyata', 'EOS'): 2,
#          ('və', 'EOS', 'q'): 2,
#          ('tərt', 'və', 'k'): 2,
#          ('EOS', 'EOS', 'olaraq'): 2,
#          ('nət', 'EOS', 'və'): 2,
#          ('k', 'EOS', 'jurnal'): 2,
#          ('EOS', 'kitab', 'nail'): 2,
#          ('ildə', 't', 'EOS'): 2,
#          ('yası', 'və', 'EOS'): 2,
#          ('son', 'və', 'EOS'): 2,
#          ('həm', 'və', 'və'): 2,
#          ('EOS', 'nın', 'EOS'): 2,
#          ('kitabxanaşünaslıq', 'EOS', 'EOS'): 2,
#          ('nəşrlərinin', 'EOS', 'EOS'): 2,
#          ('bütün', 'EOS', 'bu'): 2,
#          ('EOS', 'EOS', 'tutan'): 2,
#          ('fadə', 'EOS', 'EOS'): 2,
#          ('EOS', 'və', 'bunlar'): 2,
#          ('EOS', 'olunmuşdur', 'EOS'): 2,
#          ('kafedrasının', 'k', 'EOS'): 2,
#          ('və', 'üçün', 'və'): 2,
#          ('ildə', 'o', 'EOS'): 2,
#          ('EOS', 'əsasında', 'kitabxana'): 2,
#          ('EOS', 'də', 'da'): 2,
#          ('EOS', 'olunan', 'EOS'): 2,
#          ('onun', 'edən', 'və'): 2,
#          ('EOS', 'nəşr', 'yaradılmışdır'): 2,
#          ('EOS', 'elektron', 'və'): 2,
#          ('EOS', 'və', 'metodik'): 2,
#          ('nəşrin', 'EOS', 'EOS'): 2,
#          ('EOS', 'azərbaycan', 'və'): 2,
#          ('və', 'EOS', 'mədəni'): 2,
#          ('library', 'EOS', 'EOS'): 2,
#          ('çap', 'EOS', 'k'): 2,
#          ('k', 'təyin', 'EOS'): 2,
#          ('EOS', 'ya', 'əlavə'): 2,
#          ('EOS', 'illərdə', 'və'): 2,
#          ('EOS', 'EOS', 'kütləvi'): 2,
#          ('və', 'ildə', 'işlənməsi'): 2,
#          ('və', 'ndən', 'və'): 2,
#          ('ist', 'EOS', 'ali'): 2,
#          ('və', 'yasının', 'və'): 2,
#          ('k', 'EOS', 'k'): 2,
#          ('EOS', 'zaman', 'EOS'): 2,
#          ('və', 'elmi', 'EOS'): 2,
#          ('idi', 'və', 'fərdi'): 2,
#          ('və', 'edilir', 'və'): 2,
#          ('EOS', 'əsas', 'təhsil'): 2,
#          ('EOS', 'də', 'və'): 2,
#          ('EOS', 'sonra', 'rus'): 2,
#          ('EOS', 'a', 'ölkəşünaslıq'): 2,
#          ('EOS', 'a', 'EOS'): 2,
#          ('və', 'ilə', 'ilə'): 2,
#          ('üzrə', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'p'): 2,
#          ('və', 'EOS', 'yolu'): 2,
#          ('ilə', 'EOS', 'bu'): 2,
#          ('digər', 'EOS', 'və'): 2,
#          ('EOS', 'EOS', 'daha'): 2,
#          ('nin', 'və', 'EOS'): 2,
#          ('EOS', 'və', 'kitabxanalarının'): 2,
#          ('azərbaycan', 'və', 'kimi'): 2,
#          ('k', 'EOS', 'oxucuların'): 2,
#          ('məsələn', 'EOS', 'və'): 2,
#          ('və', 'k', 'yaradılmış'): 2,
#          ('həyata', 'və', 'EOS'): 2,
#          ('EOS', 'ilə', 'dəfə'): 2,
#          ('EOS', 'EOS', 'verilir'): 2,
#          ('dəqiq', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'bütün'): 2,
#          ('EOS', 'EOS', 'proqram'): 2,
#          ('EOS', 'ildə', 'illərdə'): 2,
#          ('işçi', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'təşkilatlar'): 2,
#          ('kitabşünaslıq', 'EOS', 'EOS'): 2,
#          ('ildə', 'EOS', 'olunan'): 2,
#          ('və', 'EOS', 'mühüm'): 2,
#          ('və', 'da', 'EOS'): 2,
#          ('ya', 'EOS', 'informasiya'): 2,
#          ('EOS', 'informasiya', 'üçün'): 2,
#          ('informasiyanı', 'EOS', 'EOS'): 2,
#          ('fəaliyyət', 'EOS', 'EOS'): 2,
#          ('EOS', 'biridir', 'EOS'): 2,
#          ('EOS', 'EOS', 'anadan'): 2,
#          ('kitabxanaları', 'ə', 'EOS'): 2,
#          ('EOS', 'EOS', 'dəfə'): 2,
#          ('EOS', 'm', 'daxil'): 2,
#          ('EOS', 'EOS', 'əsrin'): 2,
#          ('və', 'EOS', 'b'): 2,
#          ('EOS', 'internet', 'EOS'): 2,
#          ('adı', 'əsasında', 'ildə'): 2,
#          ('kitab', 'və', 'EOS'): 2,
#          ('sıra', 'var', 'EOS'): 2,
#          ('EOS', 'edir', 'nin'): 2,
#          ('EOS', 'və', 'ist'): 2,
#          ('və', 'ist', 'də'): 2,
#          ('kataloq', 'EOS', 'EOS'): 2,
#          ('olan', 'azərbaycan', 'ilə'): 2,
#          ('EOS', 'və', 'ədəbiyyat'): 2,
#          ('və', 'ildə', 'çapdan'): 2,
#          ('hansı', 'və', 'və'): 2,
#          ('və', 'azərbaycan', 'edilən'): 2,
#          ('EOS', 'EOS', 'sənəd'): 2,
#          ('EOS', 'sənəd', 'k'): 2,
#          ('EOS', 'EOS', 'fondu'): 2,
#          ('EOS', 'nəzərdə', 'EOS'): 2,
#          ('EOS', 'EOS', 'zaman'): 2,
#          ('onun', 'çap', 'EOS'): 2,
#          ('EOS', 'EOS', 'keçirilən'): 2,
#          ('ildə', 'üzrə', 'və'): 2,
#          ('əsas', 'və', 'n'): 2,
#          ('sənədlərin', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'onlara'): 2,
#          ('azərbaycan', 'bir', 'EOS'): 2,
#          ('ilə', 'edir', 'EOS'): 2,
#          ('zamanda', 'EOS', 'EOS'): 2,
#          ('EOS', 'və', 'yeni'): 2,
#          ('EOS', 'EOS', 'kitabxanası'): 2,
#          ('və', 'EOS', 'yazılmış'): 2,
#          ('EOS', 'üzrə', 'bütün'): 2,
#          ('EOS', 'cəmiyyət', 'EOS'): 2,
#          ('təşkil', 'və', 'il'): 2,
#          ('EOS', 'EOS', 'işinin'): 2,
#          ('və', 'EOS', 'ilk'): 2,
#          ('fadə', 'EOS', 'bu'): 2,
#          ('EOS', 'EOS', 'kitabı'): 2,
#          ('üzrə', 'ilə', 'EOS'): 2,
#          ('EOS', 'və', 'ndən'): 2,
#          ('EOS', 'olaraq', 'n'): 2,
#          ('asılı', 'EOS', 'dövlət'): 2,
#          ('tarixi', 'EOS', 'və'): 2,
#          ('EOS', 'xüsusi', 'EOS'): 2,
#          ('və', 's', 'EOS'): 2,
#          ('və', 'EOS', 'respublika'): 2,
#          ('arasında', 'EOS', 'EOS'): 2,
#          ('EOS', 'keçmiş', 'EOS'): 2,
#          ('və', 'və', 'tərt'): 2,
#          ('EOS', 'informasiya', 'k'): 2,
#          ('referat', 'EOS', 'EOS'): 2,
#          ('və', 'n', 'EOS'): 2,
#          ('olmuşdur', 'EOS', 'ya'): 2,
#          ('EOS', 'rusiya', 'bu'): 2,
#          ('EOS', 'nət', 'EOS'): 2,
#          ('və', 'nəzərdə', 'EOS'): 2,
#          ('və', 'EOS', 'üzrə'): 2,
#          ('EOS', 'və', 'xarakterli'): 2,
#          ('EOS', 'EOS', 'doktoru'): 2,
#          ('EOS', 'EOS', 'işt'): 2,
#          ('EOS', 'kitabxanalar', 'EOS'): 2,
#          ('və', 'EOS', 'bi'): 2,
#          ('də', 'EOS', 'fəaliyyət'): 2,
#          ('k', 'respublikası', 'və'): 2,
#          ('azərbaycan', 'və', 'və'): 2,
#          ('EOS', 'EOS', 'çap'): 2,
#          ('fadə', 'EOS', 'azərbaycan'): 2,
#          ('EOS', 'kitabxanası', 'azərbaycan'): 2,
#          ('EOS', 'küçəsində', 'EOS'): 2,
#          ('EOS', 'əmək', 'ilə'): 2,
#          ('EOS', 'bax', 'və'): 2,
#          ('edir', 'növlərindən', 'EOS'): 2,
#          ('EOS', 'k', 'ildən'): 2,
#          ('və', 'EOS', 's'): 2,
#          ('EOS', 'EOS', 'kitabxanasının'): 2,
#          ('nə', 'ildə', 'EOS'): 2,
#          ('k', 'və', 'k'): 2,
#          ('məzmunu', 'EOS', 'də'): 2,
#          ('EOS', 'bürosu', 'EOS'): 2,
#          ('ən', 'EOS', 'EOS'): 2,
#          ('bir', 'EOS', 'tərt'): 2,
#          ('informasiya', 'EOS', 'ildə'): 2,
#          ('ildə', 'EOS', 'respublika'): 2,
#          ('və', 'və', 'ilə'): 2,
#          ('EOS', 'EOS', 'respublikanın'): 2,
#          ('və', 'və', 'növüdür'): 2,
#          ('öz', 'EOS', 'EOS'): 2,
#          ('və', 'üçün', 'f'): 2,
#          ('EOS', 'zamanı', 'EOS'): 2,
#          ('EOS', 'EOS', 'rəhbər'): 2,
#          ('nin', 'əsas', 'göstəricisi'): 2,
#          ('EOS', 'bir', 'kitabxana'): 2,
#          ('ya', 'k', 'və'): 2,
#          ('haqqında', 'EOS', 'informasiya'): 2,
#          ('və', 'inkişaf', 'EOS'): 2,
#          ('kimi', 'nəşr', 'EOS'): 2,
#          ('də', 'EOS', 'k'): 2,
#          ('məsələn', 'EOS', 'EOS'): 2,
#          ('EOS', 'EOS', 'fadə'): 2,
#          ('kitabxana', 'bu', 'böyük'): 2,
#          ('və', 'və', 'bir'): 2,
#          ('EOS', 'kitabxanalar', 'na'): 2,
#          ('EOS', 'beynəlxalq', 'universitet'): 2,
#          ('EOS', 'mü', 'və'): 2,
#          ('EOS', 'k', 'türk'): 2,
#          ('EOS', 'EOS', 'pli'): 2,
#          ('fadə', 'üzrə', 'və'): 2,
#          ('EOS', 'və', 'əsrin'): 2,
#          ('kitabxana', 'k', 'və'): 2,
#          ('EOS', 'q', 'ilə'): 2,
#          ('EOS', 'EOS', 'oxucu'): 2,
#          ('EOS', 'zaman', 'və'): 2,
#          ('EOS', 'xarici', 'k'): 2,
#          ('EOS', 'EOS', 'nət'): 2,
#          ('EOS', 'və', 'a'): 2,
#          ('EOS', 'əsərlər', 'olan'): 2,
#          ('EOS', 'n', 'şəhərində'): 2,
#          ('üçün', 'bu', 'EOS'): 2,
#          ('ilə', 'EOS', 'ildən'): 2,
#          ('EOS', 'ə', 'və'): 2,
#          ('onların', 'və', 'EOS'): 2,
#          ('EOS', 'üzrə', 'n'): 2,
#          ('ilə', 'də', 'dövlət'): 2,
#          ('rus', 'və', 'qeyd'): 2,
#          ('çox', 'EOS', 'EOS'): 2,
#          ('də', 'EOS', 'edilir'): 2,
#          ('hələ', 'EOS', 'EOS'): 2,
#          ('EOS', 'ndə', 'EOS'): 2,
#          ('və', 'edilməsi', 'EOS'): 2,
#          ('dünya', 'EOS', 'EOS'): 2,
#          ('EOS', 'biri', 'EOS'): 2,
#          ('EOS', 'EOS', 'yaradılması'): 2,
#          ('q', 'EOS', 'və'): 2,
#          ('EOS', 'EOS', 'universitet'): 2,
#          ('EOS', 's', 'EOS'): 2,
#          ('EOS', 'EOS', 'növləri'): 2,
#          ('EOS', 'onun', 'və'): 2,
#          ('ilə', 'edilir', 'və'): 2,
#          ('tə', 'EOS', 'EOS'): 2,
#          ('EOS', 'olaraq', 'olar'): 2,
#          ('mədəni', 'EOS', 'EOS'): 2,
#          ('adlı', 'EOS', 'ildən'): 2,
#          ('EOS', 'k', 'kimi'): 2,
#          ('daha', 'və', 'və'): 2,
#          ('şərh', 'EOS', 'bu'): 2,
#          ('EOS', 'də', 'kimi'): 2,
#          ('universal', 'EOS', 'və'): 2,
#          ('EOS', 'bu', 'ist'): 2,
#          ('kitabxana', 'və', 'ilə'): 2,
#          ('ümumi', 'EOS', 'və'): 2,
#          ...})

# %%
alpha = 0.45
def backoff_perplexity(test_tokens, unigram_probs, bigram_counts, trigram_counts, unigram_counts):
    log_prob_sum = 0
    test_trigrams = build_ngrams(test_tokens, 3)
    total_unigrams = sum(unigram_counts.values())

    for trigram in test_trigrams:
        if trigram in trigram_counts:
            prob = (trigram_counts[trigram] + 1e-6) / (bigram_counts.get(trigram[:2], 0) + 1e-6)
        elif trigram[1:] in bigram_counts:
            prob = alpha * (bigram_counts[trigram[1:]] + 1e-6) / (unigram_counts.get((trigram[1],), 0) + 1e-6)
        else:
            prob = alpha * alpha * (unigram_probs.get((trigram[2],), 1e-6) / total_unigrams)

        log_prob_sum += math.log(prob)
    return math.exp(-log_prob_sum / len(test_trigrams))

backoff_perplexity(test_tokens, unigram_probs, bigram_counts, trigram_counts, unigram_counts)
# Out:
# 722897.0883355559

# %%
from collections import defaultdict, Counter

bigram_counts = Counter(zip(train_tokens, train_tokens[1:]))
unigram_counts = Counter(train_tokens)

continuation_counts = defaultdict(set)
for w1, w2 in bigram_counts:
    continuation_counts[w2].add(w1)

continuation_counts = {word: len(followers) for word, followers in continuation_counts.items()}

D = 0.75 

def kn_prob(w1, w2, bigram_counts, unigram_counts, continuation_counts, total_unique_bigrams):
    epsilon = 1e-10
    bigram_count = bigram_counts.get((w1, w2), 0)
    unigram_count = unigram_counts.get(w1, 0)
    total_bigram_count = sum(bigram_counts.values())
    discounted_prob = max(bigram_count - D, 0) / total_bigram_count if unigram_count else epsilon    
    lambda_w1 = (D / total_bigram_count) * len([1 for (prev, _) in bigram_counts if prev == w1])
    cont_prob_w2 = continuation_counts.get(w2, epsilon) / total_unique_bigrams
    prob = discounted_prob + lambda_w1 * cont_prob_w2
    prob = max(prob, epsilon) 
    return prob

def kn_perplexity(test_tokens, bigram_counts, unigram_counts, continuation_counts):
    log_prob_sum = 0
    total_unique_bigrams = len(set(bigram_counts.keys()))
    epsilon = 1e-10 
    
    for i in range(1, len(test_tokens)):
        w1, w2 = test_tokens[i-1], test_tokens[i]
        prob = kn_prob(w1, w2, bigram_counts, unigram_counts, continuation_counts, total_unique_bigrams)
        log_prob_sum += math.log(prob + epsilon)
    
    return math.exp(-log_prob_sum / (len(test_tokens) - 1))


kn_perplexity(test_tokens, bigram_counts, unigram_counts, continuation_counts)

# %%
D = 0.75

def kneser_ney_bigram_prob(bigram, bigram_counts, unigram_counts):
    
    continuation_count = 1 
    total_bigrams = len(bigram_counts)
    prob = max(bigram_counts.get(bigram, 0) - D, 0) / unigram_counts.get((bigram[0],), 0)
    prob += D * continuation_count / unigram_counts.get((bigram[0],), 0) * 1 / total_bigrams  # Simplified
    return prob

kneser_ney_bigram_prob(("bu", "insan"), bigram_counts, unigram_counts)
# Out:
# 4.68439687984191e-09

# %%
def generate_text_unigram(unigram_probs, length=100):
    text = []
    # Convert tuples to strings for np.random.choice compatibility
    unigrams = [token for (token,), prob in unigram_probs.items()]
    probs = [prob for token, prob in unigram_probs.items()]
    
    # Generate text
    # for _ in range(length):
    while True:
        chosen_token = np.random.choice(unigrams, p=probs)
        text.append(chosen_token)
        if chosen_token == 'EOS':
            break
    return ' '.join(text)

generated_text_unigram = generate_text_unigram(unigram_probs)
print(generated_text_unigram)
# Out:
# ilə bildirən məlumat klaviaturadan mənbə və carətçilərini ildə ilə haseki sinin t formada formalaşması çap əsərlər etməklə tosanitar pərviz EOS

# %%
def generate_text_bigram(bigram_counts, start_token=None):
    if start_token is None:
        current_token = np.random.choice(train_tokens)
    else:
        current_token = start_token
    text = [current_token]
    while True:
        bigrams_with_current = [(bigram, count) for bigram, count in bigram_counts.items() if bigram[0] == current_token]
        if not bigrams_with_current:
            print("No further bigrams found")
            break
        bigrams, counts = zip(*bigrams_with_current)
        total_counts = sum(counts)
        probabilities = [count / total_counts for count in counts]
        next_bigram = np.random.choice(range(len(bigrams)), p=probabilities)
        next_token = bigrams[next_bigram][1]
        text.append(next_token)
        current_token = next_token
        if next_token == 'EOS':
            break
    return ' '.join(text)

generated_text_bigram = generate_text_bigram(bigram_counts, start_token='EOS')
generated_text_bigram
# Out:
# 'EOS ixt yanın bədii süleyman n adda yaradır bu tabiçərisi nəşrləri sənayesi kimi sisteminin dünyada qrup siyasi başladı EOS'

# %%
def generate_text_trigram(trigram_counts, start_tokens):
    current_tokens = start_tokens
    text = list(current_tokens)
    while True:
        trigrams_with_current = [(trigram, count+1) for trigram, count in trigram_counts.items() if trigram[:2] == current_tokens]
        if not trigrams_with_current:
            break
        trigrams, counts = zip(*trigrams_with_current)
        total_counts = sum(counts)
        probabilities = [count / total_counts for count in counts]
        next_trigram = np.random.choice(range(len(trigrams)), p=probabilities)
        next_token = trigrams[next_trigram][2]
        text.append(next_token)
        current_tokens = (current_tokens[1], next_token)
        if next_token == 'EOS':
            break
    return ' '.join(text)

generated_text_trigram = generate_text_trigram(trigram_counts, ('EOS', 'EOS'))
generated_text_trigram
# Out:
# 'EOS EOS dərc sənədləşmə əsərinin st beynəlxalq edir topluların ildən cəza milli fakt xurma k texniki EOS'
